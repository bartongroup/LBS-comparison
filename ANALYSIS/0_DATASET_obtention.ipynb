# %% [markdown]
# ## Imports

# %%
from JSU_lib import *

# %% [markdown]
# ## Functions

# %%
def get_chains(df):
    prot_rows = df.query('group_PDB == "ATOM"')
    chains = set(sorted(prot_rows.label_asym_id.unique().tolist()))
    return chains

def get_ligs(df): # equivalent to pockets in a single structure
    hetatm_df = df.query('group_PDB != "ATOM" & label_comp_id not in @exclude').drop_duplicates(["label_comp_id", "label_asym_id", "label_seq_id"]) # excluding crystal by-products
    hetatm_tuples = list(zip(hetatm_df['label_comp_id'], hetatm_df['label_asym_id'], hetatm_df['label_seq_id']))
    return hetatm_tuples

def get_chain_lengths(df, chains):
    chain_len_dict = {}
    for chain in chains:
        chain_df = df.query('label_asym_id == @chain & group_PDB == "ATOM"')
        n_ress = len(chain_df.drop_duplicates('label_seq_id'))
        chain_len_dict[chain] = n_ress
    return chain_len_dict

def extract_dataset_info(ds_dir, ds_name, struc_files = None, lig_tuples_dict = None, pdb_fmt_filt = True, threshold = 6, exclude_ligands = None, n_atoms_t = None):
    if struc_files == None:
        if pdb_fmt_filt:
            struc_files = [el for el in os.listdir(ds_dir) if el.endswith(".pdb")]
        else:
            struc_files = [el for el in os.listdir(ds_dir)]
    #print(len(struc_files))
    if exclude_ligands != None:
        print(f'Exluding: {exclude_ligands}')
    if n_atoms_t != None:
        print(f'Exluding ligands with less than {n_atoms_t} atoms')
    ds_data = []
    for i, struc in enumerate(struc_files):
        struc_name, _ = os.path.splitext(struc)
        struc_path = os.path.join(ds_dir, struc)
        df = PDBXreader(inputfile = struc_path).atoms(format_type = "pdb", excluded = ())
        
        if lig_tuples_dict == None:
            lig_tuples = get_ligs(df)
        else:
            lig_tuples = lig_tuples_dict[struc_name]
            
        if exclude_ligands != None:
            lig_tuples = [lig_tup for lig_tup in lig_tuples if lig_tup[0] not in exclude_ligands]
            
        if n_atoms_t != None:
            lig_tuples_filt = []
            for lig_tup in lig_tuples:
                try:
                    if lig_n_atoms_dict[lig_tup[0]] > n_atoms_t:
                        lig_tuples_filt.append(lig_tup)
                    else:
                        continue
                except:
                    print(f'{lig_tup[0]} not found in dictionary!')
                    continue
        else:
            lig_tuples_filt = lig_tuples
            #lig_tuples = [lig_tup for lig_tup in lig_tuples if lig_n_atoms_dict[lig_tup[0]] > n_atoms_t]

        #print(len(lig_tuples))
        ligs = []#[lig_tup[0] for lig_tup in lig_tuples]
        binding_ress = get_binding_ress(df, lig_tuples_filt, struc, threshold)
        if sum([len(v) for v in binding_ress.values()]) == 0:
            print(F"CAREFUL: NO INTERACTIONS AT ALL FOR {struc}")
        binding_chains = {k: set(sorted([res[1] for res in v])) for k,v in binding_ress.items()}
        n_binding_ress = {k: len(v) for k,v in binding_ress.items()}
        
        chains = []
        flat_chains = []
        n_ress = []
        for k, v in binding_chains.items():
            #print(v)
            if v != []: # this is to only use those ligands with residues within 6A
                chains.append(v)
                flat_chains.extend(v)
                ligs.append(k[0])
                n_ress.append(n_binding_ress[k])
        un_chains = sorted(list(set(flat_chains)))
        chain_lens = get_chain_lengths(df, un_chains)
        n_chains = [len(el) for el in chains]
        ds_data.append([ds_name, struc_name, chains, n_chains, n_ress, ligs, len(ligs), chain_lens])
    ds_df = pd.DataFrame(ds_data, columns = ["dataset", "ID", "chains", "n_chains", "n_ress", "ligs", "n_ligs", "chain_lens"])
    return ds_df

def filter_by_distance(df, ligand_tuple, ID, threshold = 6):
    # Filter the DataFrame to find rows matching the ligand tuple
    ligand_df = df[(df['label_comp_id'] == ligand_tuple[0]) &
                   (df['label_asym_id'] == ligand_tuple[1]) &
                   (df['label_seq_id'] == ligand_tuple[2])]
    
    # Filter the DataFrame for rows where label_comp_id is in the list of amino acids
    prot_df = df[df['label_comp_id'].isin(aas)]
    
    # If either DataFrame is empty, return an empty DataFrame
    if ligand_df.empty or prot_df.empty:
        #print(len(ligand_df))
        print(ID, ligand_tuple)
        print("LIGAND ATOMS NOT FOUND")
        return []
    
    # Get coordinates for ligand and protein
    lig_coords = ligand_df[['Cartn_x', 'Cartn_y', 'Cartn_z']]
    prot_coords = prot_df[['Cartn_x', 'Cartn_y', 'Cartn_z']]
    
    # Calculate the distance matrix between ligand and protein coordinates
    dist_matrix = cdist(lig_coords, prot_coords, 'euclidean')
    
    # Check if any distances are below the threshold
    if np.any(dist_matrix < threshold):
        # If so, return the rows from the protein DataFrame where the condition is met
        # Get indices where the condition is met
        prot_indices = np.where(dist_matrix < threshold)[1]  # Get column indices from distance matrix
        unique_ress = prot_df.iloc[prot_indices].drop_duplicates(["label_comp_id", "label_asym_id", "label_seq_id"])
        unique_ress_tuples = list(zip(unique_ress['label_comp_id'], unique_ress['label_asym_id'], unique_ress['label_seq_id']))
        return unique_ress_tuples
    
    # Return empty DataFrame if no distances meet the criteria
    print(f"NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for {ligand_tuple} of {ID}")
    return []

def get_binding_ress(df, ligand_tuples, ID, threshold = 6):
    binding_ress = {}
    for ligand_tuple in ligand_tuples:
        binding_ress_tuples = filter_by_distance(df, ligand_tuple, ID, threshold = threshold)
        #print(binding_ress_tuples)
        if binding_ress_tuples != []:
            binding_ress[ligand_tuple] = binding_ress_tuples
    return binding_ress
    
def get_scPDB_lig_name(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    for line in lines:
        if line.startswith('@<TRIPOS>MOLECULE'):
            next_line_index = lines.index(line) + 1
            molecule_line = lines[next_line_index].strip()
            parts = molecule_line.split('_')
            if len(parts) > 1:
                molecule_name = parts[1]  # Extract the second element
    return molecule_name

def get_scPDB_site_residues(filepath):
    # Flag to start capturing data after finding the target section
    start_capture = False
    residues = []
    
    with open(filepath, 'r') as file:
        for line in file:
            line = line.strip()
            # Check for the start of the target section
            if line.startswith("@<TRIPOS>SUBSTRUCTURE"):
                start_capture = True
                continue
            # Check for the end of the target section
            if line.startswith("@<TRIPOS>SET"):
                break

            # Start capturing data after the section header
            if start_capture:
                if line:
                    parts = line.split()
                    if len(parts) < 2:
                        print(filepath)
                        print(parts)
                        raise
                    # Extract fields
                    res_id = parts[1]
                    chain_id1 = parts[5]
                    res_name_1 = parts[6]
                    res_num_1 = res_id[len(res_name_1):]

                    # Append the tuple to the list
                    residues.append((chain_id1, res_num_1, res_name_1))
    
    return residues

def get_scPDB_chain_lens(filepath):
    # Prepare a dictionary to hold the counts per chain
    chain_lens = {}
    
    # Variable to track when to start and stop reading residue data
    read_data = False
    
    #try:
    with open(filepath, 'r') as file:
        for line in file:
            # Check if it's time to start reading data
            if "@<TRIPOS>SUBSTRUCTURE" in line:
                read_data = True
                continue
            
            # Check if it's time to stop reading data
            if "@<TRIPOS>SET" in line:
                break
            
            # Process the lines between start and stop markers
            if read_data:
                # Split line into components
                parts = line.split()
                residue = parts[6]
                # Ensure line is properly formatted
                if len(parts) >= 7 and residue in aas:
                    chain_id = parts[5]
                    # Initialize or increment the chain ID and residue count
                    if chain_id not in chain_lens:
                        chain_lens[chain_id] = 0
                    chain_lens[chain_id] += 1
    
    #except Exception as e:
        #print(f"An error occurred: {e}")
    
    return chain_lens

def get_pdbbind_pdb2lig(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()[1:]
    separator_index = lines.index('# ==============================================================================\n')
    data = lines[separator_index + 1:]
    df = pd.DataFrame([x.strip().split() for x in data if x.strip() != ''])
    df.drop(columns=[1, 2, 3, 4, 5, 6], inplace = True)
    df.columns = ["pdb_id", "ligand_name"]
    lig_names = df.ligand_name.tolist()
    lig_names_rf = [el.replace("(", '').replace(")", '') for el in lig_names]
    df.ligand_name = lig_names_rf
    pdb_to_lig = dict(zip(df.pdb_id, df.ligand_name))
    return pdb_to_lig

def parse_moad_csv(moad_csv):
    rows = []
    with open(moad_csv, "r") as f:
        for line in f:
            fields = line.strip().split(",")[:-1]
            f0 = fields[0]
            f2 = fields[2]
            f3 = fields[3]
            if f0 != '':
                FAM_ID = f0
                continue
            if f2 != '':
                REP_STRUC = f2
                continue
            if f3 != '':
                row = [FAM_ID, REP_STRUC,] + fields[3:]
                rows.append(row)
                
    columns = ["EC", "pdb_id", "lig", "validity", "aff_metric", "eqs", "aff_val", "aff_unit", "SMILES"]
    
    MOAD_leaders_df = pd.DataFrame(rows, columns = columns)
    MOAD_leaders_df.drop(columns= ["eqs", ], inplace = True)
    return MOAD_leaders_df

def parse_fasta(filename):
    with open(filename, 'r') as file:
        fasta_dict = {}
        current_id = ''
        for line in file:
            line = line.strip()
            if line.startswith('>'):
                current_id = line[1:]  # Remove the ">" character
                fasta_dict[current_id] = ''
            else:
                fasta_dict[current_id] += line
    return fasta_dict

def create_MOAD_lig_tuples_dict(df):
    grouped = df.groupby('pdb_id')
    ligand_dict = {pdb_id: list(zip(group['lig_resname'], group['lig_chain'], group['lig_resnum']))
                   for pdb_id, group in grouped}
    return ligand_dict

# %%
aas = [
    'ALA', 'ARG', 'ASN', 'ASP', 'CYS',
    'GLN', 'GLU', 'GLY', 'HIS', 'ILE',
    'LEU', 'LYS', 'MET', 'PHE', 'PRO',
    'SER', 'THR', 'TRP', 'TYR', 'VAL'
]

# %%
exclude = ["HOH", "SO4", "MSE", "GOL", "PO4", "EDO", "ACT", "DOD", "MES", "FMT", "DMS", "UNK", "ACY", "TRS"]

#HOH: 1,425,778
#SO4: 1,664
#MSE: 1,359
#GOL: 683
#PO4: 438
#EDO: 323
#PLP: 322
#ACT: 312
#DOD: 112
#MES: 92
#FMT: 91
#DMS: 80
#UNK: 79
#ACY: 65
#TRS: 56

# %%
ions = [
    "CA", "MG", "ZN", "CL", "MN", "NA", "K", "CD", "IOD", "CO", "FE",
    "CU", "FE2", "NI", "TL", "XE", "O", "LU", "CS", "BR", "OH", "TE",
    "GD", "AL", "YB", "SB", "PT", "F", "RB", "SM", "SR"]
#CA: 1,174
#MG: 1,087
#ZN: 1,033
#CL: 482
#MN: 319
#NA: 288
#K: 195
#CD: 178
#IOD: 113
#CO: 91
#FE: 72
#CU: 56
#FE2: 55
#NI: 50
#TL: 39
#XE: 22
#O: 19
#LU: 9
#CS: 8
#BR: 7
#OH: 7
#TE: 6
#GD: 5
#AL: 4
#YB: 4
#MO: 3
#SB: 3
#PT: 3
#F:2
#RB: 1
#SM: 1
#SR: 1

# %% [markdown]
# ## Input data

# %%
DATASETS_dir = "./../DATA/DATASETS/"

# %%
datasets = [
    "CHEN11", "COACH420", "fptrain", "HOLO4K",
    "JOINED/ASTEX", "JOINED/B210", "JOINED/BU48", "JOINED/DT198",
]

# %% [markdown]
# ## What do we want to know?
#
# For each dataset:
# 1. Number of chains per structure
# 2. Chain length
# 3. Ligands (pockets) per structure
# 4. Ligand types (need to save ligand names)

# %% [markdown]
# ## P2Rank datasets (folders containint PDB files)

# %%
lig_n_atoms_dict = read_from_pickle("./../DATA/lig_n_atoms_dict.pkl")

# %% [markdown]
# ### CHEN11

# %%
p2rank_exclude = ["HOH", "DOD", "WAT", "NAG", "MAN", "UNK", "GLC", "ABA", "MPD", "GOL", "SO4", "PO4"]

# %%
CHEN11_df = extract_dataset_info(os.path.join(DATASETS_dir, "CHEN11"), "CHEN11", threshold = 4, exclude_ligands = p2rank_exclude, n_atoms_t = 4)
# Out:
# Exluding: ['HOH', 'DOD', 'WAT', 'NAG', 'MAN', 'UNK', 'GLC', 'ABA', 'MPD', 'GOL', 'SO4', 'PO4']
# Exluding ligands with less than 4 atoms
# CAREFUL: NO INTERACTIONS AT ALL FOR b.002.003.005_1oioa.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR b.089.001.001_1iiya.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR b.029.001.010_6cela.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR c.055.001.003_1czan.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR b.077.003.001_2hyra.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR b.001.018.002_1uh4a.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR b.003.001.001_1d3ca.pdb

# %%
len(CHEN11_df.query('n_ligs == 0')) #7
# Out:
# 7

# %%
CHEN11_df.head(3)
# Out:
#   dataset                   ID      chains n_chains    n_ress        ligs  \
# 0  CHEN11  b.081.001.001_2jf2a       [{A}]      [1]      [17]       [U20]
# 1  CHEN11  d.142.001.009_2r84a  [{A}, {A}]   [1, 1]   [11, 4]  [AMP, AMZ]
# 2  CHEN11  c.037.001.001_1e2fa  [{A}, {A}]   [1, 1]  [12, 12]  [TMP, ADP]
#
#    n_ligs  chain_lens
# 0       1  {'A': 262}
# 1       2  {'A': 230}
# 2       2  {'A': 210}

# %%
CHEN11_df.query('n_ligs == 0')
# Out:
#     dataset                   ID chains n_chains n_ress ligs  n_ligs  \
# 21   CHEN11  b.002.003.005_1oioa     []       []     []   []       0
# 50   CHEN11  b.089.001.001_1iiya     []       []     []   []       0
# 120  CHEN11  b.029.001.010_6cela     []       []     []   []       0
# 152  CHEN11  c.055.001.003_1czan     []       []     []   []       0
# 164  CHEN11  b.077.003.001_2hyra     []       []     []   []       0
# 220  CHEN11  b.001.018.002_1uh4a     []       []     []   []       0
# 244  CHEN11  b.003.001.001_1d3ca     []       []     []   []       0
#
#     chain_lens
# 21          {}
# 50          {}
# 120         {}
# 152         {}
# 164         {}
# 220         {}
# 244         {}

# %%
CHEN11_df.shape
# Out:
# (251, 8)

# %%
CHEN11_df.to_pickle("./results/DATASETS/CHEN11_df.pkl")

# %% [markdown]
# ### B210

# %%
B210_df = extract_dataset_info(os.path.join(DATASETS_dir, "JOINED/B210"), "B210", threshold = 4, exclude_ligands = p2rank_exclude, n_atoms_t = 4)
# Out:
# Exluding: ['HOH', 'DOD', 'WAT', 'NAG', 'MAN', 'UNK', 'GLC', 'ABA', 'MPD', 'GOL', 'SO4', 'PO4']
# Exluding ligands with less than 4 atoms
# CAREFUL: NO INTERACTIONS AT ALL FOR 1ac0.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PGH', 'B', '249') of 7tim.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1anf.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('F89', 'B', '2') of 1tlc.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 4mbp.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PGH', '2', '250') of 1tph.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('2GP', 'B', '105') of 2aad.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('HAR', '', '1012') of 3nos.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('HEM', '', '1010') of 3nos.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1byb.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1lmo.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 2gbp.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 2msb.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('CB3', 'B', '2') of 2tsc.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1hew.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('AMP', '', '4') of 1frp.pdb

# %%
len(B210_df.query('n_ligs == 0')) #8
# Out:
# 8

# %%
B210_df.head(3)
# Out:
#   dataset    ID      chains n_chains    n_ress        ligs  n_ligs  chain_lens
# 0    B210  1hfc        [{}]      [1]      [15]       [HAP]       1   {'': 157}
# 1    B210  1a9u        [{}]      [1]      [14]       [SB2]       1   {'': 351}
# 2    B210  1aoe  [{A}, {A}]   [1, 1]  [24, 10]  [NDP, GW3]       2  {'A': 192}

# %%
B210_df.shape
# Out:
# (210, 8)

# %%
B210_df.to_pickle("./results/DATASETS/B210_df.pkl")

# %% [markdown]
# ### BU48

# %%
BU48_df = extract_dataset_info(os.path.join(DATASETS_dir, "JOINED/BU48"), "BU48", threshold = 4, exclude_ligands = p2rank_exclude, n_atoms_t = 4)
# Out:
# Exluding: ['HOH', 'DOD', 'WAT', 'NAG', 'MAN', 'UNK', 'GLC', 'ABA', 'MPD', 'GOL', 'SO4', 'PO4']
# Exluding ligands with less than 4 atoms
# CAREFUL: NO INTERACTIONS AT ALL FOR 1hel.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1apu.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 3app.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1bya.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1byb.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1hew.pdb

# %%
len(BU48_df.query('n_ligs == 0')) #6
# Out:
# 6

# %%
BU48_df.head(3)
# Out:
#   dataset    ID      chains n_chains    n_ress        ligs  n_ligs  \
# 0    BU48  1hfc        [{}]      [1]      [15]       [HAP]       1
# 1    BU48  1srf  [{A}, {B}]   [1, 1]  [16, 16]  [MTB, MTB]       2
# 2    BU48  5cpa        [{}]      [1]      [14]       [FVF]       1
#
#              chain_lens
# 0             {'': 157}
# 1  {'A': 116, 'B': 116}
# 2             {'': 307}

# %%
BU48_df.shape
# Out:
# (96, 8)

# %%
BU48_df.to_pickle("./results/DATASETS/BU48_df.pkl")

# %% [markdown]
# ### DT198

# %%
DT198_df = extract_dataset_info(os.path.join(DATASETS_dir, "JOINED/DT198"), "DT198", threshold = 4, exclude_ligands = p2rank_exclude, n_atoms_t = 4)
# Out:
# Exluding: ['HOH', 'DOD', 'WAT', 'NAG', 'MAN', 'UNK', 'GLC', 'ABA', 'MPD', 'GOL', 'SO4', 'PO4']
# Exluding ligands with less than 4 atoms
# CAREFUL: NO INTERACTIONS AT ALL FOR 1dp0_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1r6n_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1ltq_A.pdb
# DVV not found in dictionary!
# CAREFUL: NO INTERACTIONS AT ALL FOR 1pn3_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1q1c_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 2biu_X.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 3k4v_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 2ch5_A.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('GAI', 'A', '132') of 1rbw_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1kmv_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 2agd_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1tz8_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1tpf_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1lj5_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1c1p_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 2jhf_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 2of1_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1yki_B.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('GSH', 'A', '482') of 3dk8_A.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('GAI', 'A', '201') of 1jxm_A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1s2a_A.pdb

# %%
#DVV not found in dictionary!

# %%
len(DT198_df.query('n_ligs == 0')) #18
# Out:
# 18

# %%
DT198_df.head(3)
# Out:
#   dataset      ID chains n_chains n_ress   ligs  n_ligs  chain_lens
# 0   DT198  1dp0_A     []       []     []     []       0          {}
# 1   DT198  2ab2_A  [{A}]      [1]   [19]  [SNL]       1  {'A': 259}
# 2   DT198  1j3j_A  [{A}]      [1]   [12]  [CP6]       1  {'A': 221}

# %%
DT198_df.shape
# Out:
# (198, 8)

# %%
DT198_df.to_pickle("./results/DATASETS/DT198_df.pkl")

# %% [markdown]
# ### ASTEX

# %%
ASTEX_df = extract_dataset_info(os.path.join(DATASETS_dir, "JOINED/ASTEX"), "ASTEX", threshold = 4, exclude_ligands = p2rank_exclude, n_atoms_t = 4)
# Out:
# Exluding: ['HOH', 'DOD', 'WAT', 'NAG', 'MAN', 'UNK', 'GLC', 'ABA', 'MPD', 'GOL', 'SO4', 'PO4']
# Exluding ligands with less than 4 atoms
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('IOH', '', '502') of 1q1g.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '1202') of 1l7f.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'D', '1150') of 1n1m.pdb

# %%
len(ASTEX_df.query('n_ligs == 0')) #0
# Out:
# 0

# %%
ASTEX_df.head(3)
# Out:
#   dataset    ID           chains   n_chains        n_ress             ligs  \
# 0   ASTEX  1j3j  [{A}, {A}, {C}]  [1, 1, 1]  [12, 27, 11]  [CP6, NDP, UMP]
# 1   ASTEX  1n2j       [{A}, {A}]     [1, 1]       [10, 2]       [PAF, BAL]
# 2   ASTEX  1ia1       [{A}, {A}]     [1, 1]      [25, 13]       [NDP, TQ3]
#
#    n_ligs            chain_lens
# 0       3  {'A': 221, 'C': 326}
# 1       2            {'A': 287}
# 2       2            {'A': 192}

# %%
ASTEX_df.shape
# Out:
# (85, 8)

# %%
ASTEX_df.to_pickle("./results/DATASETS/ASTEX_df.pkl")

# %% [markdown]
# ### JOINED

# %%
JOINED_df = pd.concat(
    [
        B210_df, BU48_df, DT198_df, ASTEX_df
    ]
).reset_index(drop = True)

JOINED_df.dataset = "JOINED"

# %%
len(JOINED_df.query('n_ligs == 0')) #29
# Out:
# 32

# %%
JOINED_df.head(3)
# Out:
#   dataset    ID      chains n_chains    n_ress        ligs  n_ligs  chain_lens
# 0  JOINED  1hfc        [{}]      [1]      [15]       [HAP]       1   {'': 157}
# 1  JOINED  1a9u        [{}]      [1]      [14]       [SB2]       1   {'': 351}
# 2  JOINED  1aoe  [{A}, {A}]   [1, 1]  [24, 10]  [NDP, GW3]       2  {'A': 192}

# %%
JOINED_df.shape
# Out:
# (589, 8)

# %%
JOINED_df.to_pickle("./results/DATASETS/JOINED_df.pkl")

# %% [markdown]
# ### fptrain

# %%
fptrain_df = extract_dataset_info(os.path.join(DATASETS_dir, "fptrain"), "fptrain", threshold = 4, exclude_ligands = p2rank_exclude, n_atoms_t = 4) # what did they filter?
# Out:
# Exluding: ['HOH', 'DOD', 'WAT', 'NAG', 'MAN', 'UNK', 'GLC', 'ABA', 'MPD', 'GOL', 'SO4', 'PO4']
# Exluding ligands with less than 4 atoms
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('REA', '', '301') of 1K74.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1E8U.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1GUZ.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('ACO', '', '800') of 1P7T.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PYR', '', '810') of 1P7T.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PEG', '', '701') of 1P7T.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', '', '304') of 1AXZ.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('XYP', '', '305') of 1AXZ.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('SF4', '', '7290') of 1FP6.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('URE', '', '214') of 1DDR.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('URE', '', '215') of 1DDR.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1BD4.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1A4G.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1AOG.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PCP', '', '302') of 1A96.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BO3', '', '305') of 1A96.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BO3', '', '306') of 1A96.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1M6P.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1A50.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1DID.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1GZF.pdb
# CST not found in dictionary!
# CAREFUL: NO INTERACTIONS AT ALL FOR 1SGC.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1AIQ.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1B57.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1GQG.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1HA3.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1ADB.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1C3B.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('REA', '', '201') of 1FM9.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1H7F.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1AFL.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', '', '171') of 1DOG.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1GQT.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1H5X.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('SES', 'A', '700') of 1DZJ.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1OPB.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1PFK.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1JAY.pdb
# CBS not found in dictionary!
# CAREFUL: NO INTERACTIONS AT ALL FOR 1QBB.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('REA', '', '501') of 1FM6.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('REA', '', '502') of 1FM6.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1CEL.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1OH0.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1AD8.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1LCP.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1KEV.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1LBT.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('SIN', '', '535') of 2BIF.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('F6P', '', '550') of 2BIF.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1BAV.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1ADO.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1DLT.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1A0T.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1ALW.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1DQY.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('ATP', '', '1510') of 1J21.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('ATP', '', '2510') of 1J21.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('ATP', '', '3510') of 1J21.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1GT6.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1GN8.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1CTE.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1D1G.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1B02.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1BGG.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1BIL.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('CLF', 'C', '498') of 2MIN.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('CFM', 'C', '496') of 2MIN.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1B12.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1E4N.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1IWE.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1E6R.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1E7A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1GOY.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1DJW.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1XZK.pdb

# %%
len(fptrain_df.query('n_ligs == 0')) #51
# Out:
# 51

# %%
fptrain_df.head(3)
# Out:
#    dataset    ID chains n_chains n_ress   ligs  n_ligs  chain_lens
# 0  fptrain  1H0S  [{A}]      [1]   [13]  [FA6]       1  {'A': 137}
# 1  fptrain  1A9U  [{A}]      [1]   [14]  [SB2]       1  {'A': 351}
# 2  fptrain  1A80  [{A}]      [1]   [27]  [NAP]       1  {'A': 277}

# %%
fptrain_df.shape
# Out:
# (263, 8)

# %%
fptrain_df.to_pickle("./results/DATASETS/fptrain_df.pkl")

# %% [markdown]
# ### COACH420

# %%
COACH420_df = extract_dataset_info(os.path.join(DATASETS_dir, "COACH420"), "COACH420", threshold = 4, exclude_ligands = p2rank_exclude, n_atoms_t = 4)
# Out:
# Exluding: ['HOH', 'DOD', 'WAT', 'NAG', 'MAN', 'UNK', 'GLC', 'ABA', 'MPD', 'GOL', 'SO4', 'PO4']
# Exluding ligands with less than 4 atoms
# CAREFUL: NO INTERACTIONS AT ALL FOR 1teiA.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 2qwiA.pdb
# CBS not found in dictionary!
# CAREFUL: NO INTERACTIONS AT ALL FOR 1zu0A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 3ct5A.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BGC', 'A', '2299') of 2vu9A.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('GAL', 'A', '2300') of 2vu9A.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 2j72B.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 2v8lA.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1lzsA.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('GAL', 'A', '181') of 1cqfB.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BGC', 'A', '182') of 1cqfB.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BGC', 'B', '282') of 1cqfB.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BGC', 'B', '272') of 1cqfB.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 2rjcA.pdb

# %%
len(COACH420_df.query('n_ligs == 0')) #7
# Out:
# 7

# %%
COACH420_df.head(3)
# Out:
#     dataset     ID chains n_chains n_ress   ligs  n_ligs  chain_lens
# 0  COACH420  1ogoX  [{X}]      [1]    [4]  [BGC]       1  {'X': 572}
# 1  COACH420  830cA  [{A}]      [1]   [16]  [RS1]       1  {'A': 164}
# 2  COACH420  2e6uX  [{X}]      [1]   [22]  [COA]       1  {'X': 142}

# %%
COACH420_df.shape
# Out:
# (420, 8)

# %%
COACH420_df.to_pickle("./results/DATASETS/COACH420_df.pkl")

# %% [markdown]
# ### HOLO4K

# %%
HOLO4K_df = extract_dataset_info(os.path.join(DATASETS_dir, "HOLO4K"), "HOLO4K", threshold = 4, exclude_ligands = p2rank_exclude, n_atoms_t = 4)
# Out:
# Exluding: ['HOH', 'DOD', 'WAT', 'NAG', 'MAN', 'UNK', 'GLC', 'ABA', 'MPD', 'GOL', 'SO4', 'PO4']
# Exluding ligands with less than 4 atoms
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 2qwe.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PH1', 'A', '504') of 1qhj.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '605') of 1c8s.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '476') of 1inh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '476') of 1inh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '471') of 1inh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '304') of 1axz.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('XYP', 'A', '305') of 1axz.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '605') of 1c8r.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 2qwd.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 2qwf.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '303') of 1fiw.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '473') of 2bat.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('NGK', 'A', '476') of 2bat.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUL', 'A', '477') of 2bat.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '480') of 2bat.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '1203') of 1g6i.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PYE', 'A', '508') of 1kya.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PYE', 'A', '509') of 1kya.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PYE', 'B', '608') of 1kya.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PYE', 'B', '614') of 1kya.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PYE', 'D', '808') of 1kya.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PYE', 'D', '810') of 1kya.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FCA', 'C', '603') of 1b37.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 1bji.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 2qwg.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 2qwc.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '336') of 1fq5.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BGC', 'A', '698') of 1kck.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'M', '942') of 1e6x.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'M', '944') of 1e6x.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('XYP', 'M', '945') of 1e6x.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'M', '954') of 1e6x.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('XYP', 'M', '955') of 1e6x.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '474') of 1iny.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '474') of 1inx.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 2qwb.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('TRD', 'A', '612') of 1cwq.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UND', 'A', '624') of 1cwq.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('TRD', 'A', '1612') of 1cwq.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('TRD', 'A', '1615') of 1cwq.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('OCT', 'A', '1617') of 1cwq.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('OCT', 'A', '1621') of 1cwq.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('TRD', 'B', '615') of 1cwq.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('OCT', 'B', '621') of 1cwq.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '613') of 1gal.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '605') of 1p8i.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '605') of 1c3w.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '1202') of 1l7g.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'A', '502') of 1wbl.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'B', '602') of 1wbl.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'C', '502') of 1wbl.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'D', '602') of 1wbl.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '1202') of 1l7f.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '613') of 1iex.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'A', '614') of 1iex.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('NDG', 'A', '197') of 1l8j.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'A', '1132') of 1bcr.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('XYP', 'A', '510') of 1dbg.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('MXY', 'A', '511') of 1dbg.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('G4D', 'A', '512') of 1dbg.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BGC', 'A', '513') of 1dbg.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '605') of 1f50.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'C', '525') of 1f8r.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('GAL', 'A', '420') of 1dze.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BAM', 'A', '248') of 1tio.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('CHX', 'A', '255') of 1tio.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FCA', 'C', '603') of 1b5q.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'A', '2003') of 1fwv.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'A', '541') of 1ju2.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '542') of 1ju2.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'A', '546') of 1ju2.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '547') of 1ju2.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '548') of 1ju2.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'B', '541') of 1ju2.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '542') of 1ju2.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'B', '546') of 1ju2.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '547') of 1ju2.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('MOH', 'A', '2001') of 1q99.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('MOH', 'B', '2000') of 1q99.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '474') of 1dog.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '605') of 1kgb.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'A', '2003') of 1fwu.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '1399') of 1oke.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '1399') of 1oke.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1xgf.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FCA', 'C', '603') of 1h83.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '604') of 1kg9.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'E', '404') of 1ppg.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('GAL', 'E', '407') of 1ppg.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'E', '415') of 1ppg.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'A', '501') of 1m2t.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'B', '601') of 1m2t.pdb
# CBS not found in dictionary!
# CAREFUL: NO INTERACTIONS AT ALL FOR 1qbb.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FCA', 'C', '603') of 1h82.pdb
# FXP not found in dictionary!
# FXP not found in dictionary!
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('XYP', 'A', '510') of 1dbo.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('MXY', 'A', '511') of 1dbo.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('G4D', 'A', '512') of 1dbo.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BGC', 'A', '513') of 1dbo.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1nth.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FCA', 'C', '603') of 1h81.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('GAL', 'A', '420') of 1qm8.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '605') of 1m0l.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '612') of 1j8v.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '615') of 1j8v.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'A', '616') of 1j8v.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '1202') of 1l7h.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 1nnc.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BME', 'A', '902') of 225l.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '613') of 1cf3.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '603') of 1mgy.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '609') of 1mgy.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '610') of 1mgy.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FCA', 'C', '603') of 1h84.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '706') of 1jv7.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FCA', 'C', '603') of 1h86.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '303') of 1d7c.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('LI1', 'A', '605') of 1f4z.pdb
# SUM not found in dictionary!
# CAREFUL: NO INTERACTIONS AT ALL FOR 1iz2.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '476') of 1ivf.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '476') of 1ivf.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'B', '477') of 1ivf.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '486') of 1ivf.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BGC', 'A', '731') of 1mw0.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BGC', 'F', '107') of 1ct1.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BGC', 'G', '107') of 1ct1.pdb
# FXP not found in dictionary!
# FXP not found in dictionary!
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '476') of 1ivd.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '480') of 1ivd.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '476') of 1ivd.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'B', '477') of 1ivd.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '480') of 1ivd.pdb
# CBS not found in dictionary!
# CAREFUL: NO INTERACTIONS AT ALL FOR 1ljn.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('GAL', 'A', '420') of 1iw6.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('L3P', 'A', '300') of 1iw6.pdb
# CAREFUL: NO INTERACTIONS AT ALL FOR 1pbt.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('NDG', 'A', '768') of 1n1m.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'A', '772') of 1n1m.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '774') of 1n1m.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '777') of 1n1m.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '476') of 1ive.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '480') of 1ive.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('NDG', 'A', '485') of 1ive.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '476') of 1ive.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '480') of 1ive.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('NDG', 'B', '488') of 1ive.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 1mwe.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 2qwj.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('PAP', 'B', '601') of 1m4g.pdb
# CBS not found in dictionary!
# CAREFUL: NO INTERACTIONS AT ALL FOR 1c7s.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'M', '941') of 1e6q.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'M', '944') of 1e6q.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('XYP', 'M', '945') of 1e6q.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'M', '954') of 1e6q.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('XYP', 'M', '955') of 1e6q.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '476') of 1ing.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '480') of 1ing.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '476') of 1ing.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '480') of 1ing.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'A', '2020') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'A', '2026') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'A', '2029') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'A', '2034') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'A', '2040') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'A', '2041') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'A', '2042') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'A', '2047') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'A', '2050') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'B', '2016') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'B', '2027') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'B', '2028') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'B', '2031') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'B', '2044') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('UPL', 'B', '2049') of 1lsh.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 2qwk.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 2qwi.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '476') of 1ivc.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '480') of 1ivc.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '476') of 1ivc.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'B', '480') of 1ivc.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('FUC', 'M', '942') of 1e6s.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'M', '944') of 1e6s.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('XYP', 'M', '945') of 1e6s.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'M', '954') of 1e6s.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('XYP', 'M', '955') of 1e6s.pdb
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('BMA', 'A', '471') of 2qwh.pdb

# %%
len(HOLO4K_df.query('n_ligs == 0')) #7
# Out:
# 7

# %%
HOLO4K_df.head(3)
# Out:
#   dataset    ID                chains      n_chains        n_ress  \
# 0  HOLO4K  1drk                 [{A}]           [1]          [11]
# 1  HOLO4K  1dqp  [{A}, {A}, {B}, {B}]  [1, 1, 1, 1]  [6, 2, 6, 6]
# 2  HOLO4K  1qin      [{B, A}, {B, A}]        [2, 2]      [22, 19]
#
#                    ligs  n_ligs            chain_lens
# 0                 [RIP]       1            {'A': 271}
# 1  [IMG, IPA, IMG, IPA]       4  {'A': 230, 'B': 230}
# 2            [GIP, GIP]       2  {'A': 176, 'B': 176}

# %%
HOLO4K_df.shape
# Out:
# (4543, 8)

# %%
HOLO4K_df.to_pickle("./results/DATASETS/HOLO4K_df.pkl")

# %% [markdown]
# ## scPDB (one subfolder per entry with .mol2 files and .txt within)

# %%
scpdb_subset_dir = os.path.join(DATASETS_dir, "scPDB_2017_subset")

entries = os.listdir(scpdb_subset_dir)

ligs, error_ligs, sites, error_sites, chain_lens, error_chain_lens, scpdb_data = ([] for _ in range(7))

for i, entry in enumerate(entries):
    lig = site_ress = chain_len = None
    if i % 100 == 0:
       print(i)
    entry_dir = os.path.join(scpdb_subset_dir, entry)
    
    try:
        lig = get_scPDB_lig_name(os.path.join(entry_dir, "ligand.mol2"))
        ligs.append(lig)
    except:
        error_ligs.append(entry)
    try:
        site_ress = get_scPDB_site_residues(os.path.join(entry_dir, "site.mol2"))
        sites.append(site_ress)
    except:
        error_sites.append(entry)   
    try:
        chain_len = get_scPDB_chain_lens(os.path.join(entry_dir, "protein.mol2"))
        chain_lens.append(chain_len)
    except:
        error_chain_lens.append(entry) 
    if lig != None and site_ress != None and chain_len != None:
        n_ligs = 1
        prot_site_ress = [el for el in site_ress if el[2] in aas]
        n_ress = len(prot_site_ress)
        prot_site_chains = [set([el[0] for el in prot_site_ress]), ]
        n_chains = [len(el) for el in prot_site_chains]
        scpdb_data.append(["scPDB_filt", entry, prot_site_chains, n_chains, [n_ress, ], [lig,], n_ligs, chain_len])

scPDB_filt_df = pd.DataFrame(scpdb_data, columns = ["dataset", "ID", "chains", "n_chains", "n_ress", "ligs", "n_ligs", "chain_lens"])
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000

# %%
n_ress_lists = [[el, ] for el in scPDB_filt_df.n_ress.tolist()]

# %%
scPDB_filt_df.n_ress = n_ress_lists

# %%
scPDB_filt_df.head(3)
# Out:
#       dataset      ID chains n_chains n_ress   ligs  n_ligs  chain_lens
# 0  scPDB_filt  2zb4_1  [{A}]      [1]   [21]  [5OP]       1  {'A': 351}
# 1  scPDB_filt  4yfy_4  [{B}]      [1]   [31]  [1YJ]       1  {'B': 241}
# 2  scPDB_filt  4lt6_2  [{B}]      [1]   [33]  [3AT]       1  {'B': 462}

# %%
#scPDB_filt_df['pdb_id'] = scPDB_filt_df['ID'].apply(lambda x: x.split('_')[0])

# %%
scPDB_filt_df.to_pickle("./results/DATASETS/scPDB_filt_df.pkl")

# %%
scPDB_filt_df.shape
# Out:
# (5020, 8)

# %%
#len(scPDB_filt_df.drop_duplicates("pdb_id"))

# %% [markdown]
# ## scPDB (whole)

# %%
scpdb_full_dir = os.path.join(DATASETS_dir, "scPDB_2017_full")

entries_full = os.listdir(scpdb_full_dir)

ligs_full, error_ligs_full, sites_full, error_sites_full, chain_lens_full, error_chain_lens_full, scpdb_data_full = ([] for _ in range(7))

for i, entry in enumerate(entries_full):
    lig = site_ress = chain_len = None
    if i % 100 == 0:
       print(i)
    entry_dir = os.path.join(scpdb_full_dir, entry)
    
    try:
        lig = get_scPDB_lig_name(os.path.join(entry_dir, "ligand.mol2"))
        ligs_full.append(lig)
    except:
        error_ligs_full.append(entry)
    try:
        site_ress = get_scPDB_site_residues(os.path.join(entry_dir, "site.mol2"))
        sites_full.append(site_ress)
    except:
        error_sites_full.append(entry)   
    try:
        chain_len = get_scPDB_chain_lens(os.path.join(entry_dir, "protein.mol2"))
        chain_lens_full.append(chain_len)
    except:
        error_chain_lens_full.append(entry) 
    if lig != None and site_ress != None and chain_len != None:
        n_ligs = 1
        prot_site_ress = [el for el in site_ress if el[2] in aas]
        n_ress = len(prot_site_ress)
        prot_site_chains = [set([el[0] for el in prot_site_ress]), ]
        n_chains = [len(el) for el in prot_site_chains]
        scpdb_data_full.append(["scPDB_full", entry, prot_site_chains, n_chains, [n_ress, ], [lig,], n_ligs, chain_len])

scPDB_full_df = pd.DataFrame(scpdb_data_full, columns = ["dataset", "ID", "chains", "n_chains", "n_ress", "ligs", "n_ligs", "chain_lens"])
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500

# %%
#scPDB_full_df['pdb_id'] = scPDB_full_df['ID'].apply(lambda x: x.split('_')[0])

# %%
#scPDB_full_df.dataset = "scPDB_full"

# %%
scPDB_full_df.head(5)
# Out:
#       dataset      ID chains n_chains n_ress   ligs  n_ligs  chain_lens
# 0  scPDB_full  1iki_1  [{A}]      [1]   [39]  [REY]       1  {'A': 345}
# 1  scPDB_full  2zb4_1  [{A}]      [1]   [21]  [5OP]       1  {'A': 351}
# 2  scPDB_full  3gfe_1  [{A}]      [1]   [37]  [P37]       1  {'A': 352}
# 3  scPDB_full  3isj_2  [{B}]      [1]   [26]  [A8D]       1  {'B': 279}
# 4  scPDB_full  4bu9_2  [{B}]      [1]   [26]  [08C]       1  {'B': 211}

# %%
scPDB_full_df.head(5)
# Out:
#       dataset      ID chains n_chains   ligs  n_ligs  chain_lens pdb_id
# 0  scPDB_full  1iki_1  [{A}]      [1]  [REY]       1  {'A': 345}   1iki
# 1  scPDB_full  2zb4_1  [{A}]      [1]  [5OP]       1  {'A': 351}   2zb4
# 2  scPDB_full  3gfe_1  [{A}]      [1]  [P37]       1  {'A': 352}   3gfe
# 3  scPDB_full  3isj_2  [{B}]      [1]  [A8D]       1  {'B': 279}   3isj
# 4  scPDB_full  4bu9_2  [{B}]      [1]  [08C]       1  {'B': 211}   4bu9

# %%
scPDB_full_df.to_pickle("./results/DATASETS/scPDB_full_df.pkl")

# %%
scPDB_full_df.shape
# Out:
# (17594, 8)

# %%
#len(scPDB_full_df.drop_duplicates("pdb_id"))
# Out:
# 16612

# %% [markdown]
# ## PDBbind  v2020

# %%
pdb2lig_pdbbind = get_pdbbind_pdb2lig(os.path.join(DATASETS_dir, "INDEX_refined_data.2020"))

# %%
pdbbind_2020_dir = os.path.join(DATASETS_dir, "PDBbind_v2020_refined")

pdbbind_entries = os.listdir(pdbbind_2020_dir)

pdbbind_data = []
pdbbind_errors = []
for i, entry in enumerate(pdbbind_entries):
    if i % 100 == 0:
       print(i)
    try:
        entry_dir = os.path.join(pdbbind_2020_dir, entry)
        protein_path = os.path.join(entry_dir, f"{entry}_protein.pdb")
        protein_df = PDBXreader(inputfile = protein_path).atoms(format_type = "pdb", excluded = ())
        pocket_path = os.path.join(entry_dir, f"{entry}_pocket.pdb")
        pocket_df = PDBXreader(inputfile = pocket_path).atoms(format_type = "pdb", excluded = ())
        protein_pocket_df = pocket_df[pocket_df['label_comp_id'].isin(aas)]
        n_ress = len(protein_pocket_df.drop_duplicates(["label_comp_id", "label_asym_id", "label_seq_id"])) # number of unique protein ligand-binding residues
        chains = get_chains(protein_pocket_df)
        chain_lengths = get_chain_lengths(protein_df, chains)
        lig = pdb2lig_pdbbind[entry]
        n_ligs = 1
        pdbbind_data.append(["PDBbind", entry, [chains, ], [len(chains), ], [n_ress, ], [lig,], n_ligs, chain_lengths])
    except:
        pdbbind_errors.append(entry)
        print(f"There was an error with {entry}")

pdbbind2020_df = pd.DataFrame(pdbbind_data, columns = ["dataset", "ID", "chains", "n_chains", "n_ress", "ligs", "n_ligs", "chain_lens"])
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# There was an error with .DS_Store
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# There was an error with readme
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# There was an error with index
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300

# %%
pdbbind2020_df.head(3)
# Out:
#    dataset    ID chains n_chains n_ress   ligs  n_ligs  chain_lens
# 0  PDBbind  6ugp  [{A}]      [1]   [45]  [Q7A]       1  {'A': 257}
# 1  PDBbind  4rdn  [{A}]      [1]   [39]  [6MD]       1  {'A': 149}
# 2  PDBbind  4mo4  [{A}]      [1]   [43]  [ACP]       1  {'A': 345}

# %%
pdbbind2020_df.to_pickle("./results/DATASETS/pdbbind_refined_df.pkl")

# %%
pdbbind2020_df.shape #(5316, 7)
# Out:
# (5316, 8)

# %% [markdown]
# ## SC6K

# %%
sc6k_dir = os.path.join(DATASETS_dir, "SC6K_processed")

entries_sc6k = os.listdir(sc6k_dir)

ligs_sc6k, error_ligs_sc6k, sites_sc6k, error_sites_sc6k, chain_lens_sc6k, error_chain_lens_sc6k, sc6k_data = ([] for _ in range(7))

sc6k_errors = []
for i, entry in enumerate(entries_sc6k):
    lig = site_ress = chain_len = None
    if i % 100 == 0:
       print(i)
    entry_dir = os.path.join(sc6k_dir, entry)
    try:
        files = [f for f in os.listdir(entry_dir) if "CAVITY" not in f and f.endswith(".mol2")]
        subentries = sorted(list(set(["_".join(f.split(".")[0].split("_")[:3]) for f in files])))
    except:
        sc6k_errors.append(entry)
        print(f"There was an error with {entry}")
        #raise
    

    for subentry in subentries:
        ds = subentry.split("_")
        try:
            subentry_id = f'{ds[0]}_{ds[1]}'
        except:
            print(files)
            print(entry, subentry)
            raise
        lig = ds[2]
        ligs_sc6k.append(lig)
        
        try:
            site_ress = get_scPDB_site_residues(os.path.join(entry_dir, f"{subentry}_SITE.mol2"))
            sites_full.append(site_ress)
        except:
            error_sites_full.append(entry)   
        try:
            chain_len = get_scPDB_chain_lens(os.path.join(entry_dir, f"{subentry}_PROT.mol2"))
            chain_lens_full.append(chain_len)
        except:
            error_chain_lens_full.append(entry) 
        if lig != None and site_ress != None and chain_len != None:
            n_ligs = 1
            prot_site_ress = [el for el in site_ress if el[2] in aas]
            n_ress = len(prot_site_ress)
            prot_site_chains = [set([el[0] for el in prot_site_ress]), ]
            n_chains = [len(el) for el in prot_site_chains]
            sc6k_data.append(["SC6K", subentry_id, prot_site_chains, n_chains, [n_ress, ], [lig,], n_ligs, chain_len])
    #break
    
sc6k_data_df = pd.DataFrame(sc6k_data, columns = ["dataset", "ID", "chains", "n_chains", "n_ress", "ligs", "n_ligs", "chain_lens"])
# Out:
# 0
# 100
# 200
# 300
# There was an error with .DS_Store
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400

# %%
#sc6k_data_df['pdb_id'] = sc6k_data_df['ID'].apply(lambda x: x.split('_')[0])

# %%
sc6k_data_df.head(3)
# Out:
#   dataset      ID chains n_chains n_ress   ligs  n_ligs  chain_lens
# 0    SC6K  6pxs_1  [{A}]      [1]   [65]  [FAD]       1  {'A': 370}
# 1    SC6K  6pxs_2  [{B}]      [1]   [64]  [FAD]       1  {'B': 370}
# 2    SC6K  6pxs_4  [{D}]      [1]   [64]  [FAD]       1  {'D': 369}

# %%
sc6k_data_df.to_pickle("./results/DATASETS/SC6K_df.pkl")

# %% [markdown]
# ## Binding MOAD (leaders only, non-redundant)

# %%
moad_fasta = os.path.join(DATASETS_dir, "binding_MOAD_subset.fasta")

moad_csv = os.path.join(DATASETS_dir, "binding_MOAD_leaders.csv")

# %%
MOAD_leaders_df = parse_moad_csv(moad_csv)

MOAD_subset_seq_dict = parse_fasta(moad_fasta)
MOAD_subset_pdbs = list(MOAD_subset_seq_dict.keys())

# %%
len(MOAD_subset_pdbs)
# Out:
# 6650

# %%
print(len(MOAD_leaders_df))
print(len(MOAD_leaders_df.EC.unique()))
print(len(MOAD_leaders_df.pdb_id.unique()))
print(len(MOAD_leaders_df.drop_duplicates(["EC", "pdb_id"])))
# Out:
# 83526
# 1933
# 11058
# 11058

# %%
MOAD_leaders_df.validity.value_counts()
# Out:
# invalid            39242
# valid              28693
# Part of Protein    15591
# Name: validity, dtype: int64

# %%
MOAD_leaders_not_invalid_df = MOAD_leaders_df.query('validity != "invalid"').copy().reset_index(drop = True)

# %%
print(len(MOAD_leaders_not_invalid_df))
print(len(MOAD_leaders_not_invalid_df.EC.unique()))
print(len(MOAD_leaders_not_invalid_df.pdb_id.unique()))
print(len(MOAD_leaders_not_invalid_df.drop_duplicates(["EC", "pdb_id"])))
# Out:
# 44284
# 1933
# 11058
# 11058

# %%
MOAD_leaders_valid_df = MOAD_leaders_not_invalid_df.query('validity == "valid"').copy().reset_index(drop = True)

# %%
print(len(MOAD_leaders_valid_df))
print(len(MOAD_leaders_valid_df.EC.unique()))
print(len(MOAD_leaders_valid_df.pdb_id.unique()))
print(len(MOAD_leaders_valid_df.drop_duplicates(["EC", "pdb_id"])))
# Out:
# 28693
# 1933
# 11058
# 11058

# %%
MOAD_leaders_valid_df.head(3)
# Out:
#         EC pdb_id         lig validity aff_metric aff_val aff_unit  \
# 0  5.3.1.-   2PA7   TYD:A:141    valid
# 1  5.3.1.-   2PA7   TYD:B:140    valid
# 2  5.3.1.-   2HK1  FUD:A:1300    valid
#
#                                               SMILES
# 0  CC1=CN(C(=O)NC1=O)[C@H]2C[C@@H]([C@H](O2)CO[P@...
# 1  CC1=CN(C(=O)NC1=O)[C@H]2C[C@@H]([C@H](O2)CO[P@...
# 2               C([C@H]([C@H]([C@@H](C(=O)CO)O)O)O)O

# %%
MOAD_leaders_valid_df[['lig_resname', 'lig_chain', 'lig_resnum']] = MOAD_leaders_valid_df['lig'].str.split(':', expand=True)

# %%
MOAD_leaders_valid_df_rf = MOAD_leaders_valid_df[["EC", "pdb_id", "lig_resname", "lig_chain", "lig_resnum"]].drop_duplicates()

# %%
MOAD_subset_df = MOAD_leaders_valid_df_rf.query('pdb_id in @MOAD_subset_pdbs').copy().reset_index(drop = True)

# %%
print(len(MOAD_subset_df))
print(len(MOAD_subset_df.EC.unique()))
print(len(MOAD_subset_df.pdb_id.unique()))
print(len(MOAD_subset_df.drop_duplicates(["EC", "pdb_id"])))
# Out:
# 17246
# 1348
# 6650
# 6650

# %%
MOAD_subset_df.pdb_id = MOAD_subset_df.pdb_id.str.lower()

# %%
MOAD_lig_tuples_dict = create_MOAD_lig_tuples_dict(MOAD_subset_df)

# %%
MOAD_subset_df.head()
# Out:
#         EC pdb_id lig_resname lig_chain lig_resnum
# 0  5.3.1.-   2pa7         TYD         A        141
# 1  5.3.1.-   2pa7         TYD         B        140
# 2  5.3.1.-   2hk1         FUD         A       1300
# 3  5.3.1.-   2hk1         FUD         B       1301
# 4  5.3.1.-   2hk1         FUD         C       1302

# %%
MOAD_leaders_dir = os.path.join(DATASETS_dir, "BindingMOAD_2020")

# %%
moad_strucs = os.listdir(MOAD_leaders_dir)

# %%
len(moad_strucs)
# Out:
# 17068

# %%
MOAD_subset_pdbs = MOAD_subset_df.pdb_id.unique().tolist()

# %%
len(MOAD_subset_pdbs)
# Out:
# 6650

# %%
strucs_dict = {}
for subset_pdb in MOAD_subset_pdbs:
    strucs_dict[subset_pdb] = []
    for moad_struc in moad_strucs:
        if subset_pdb in moad_struc:
           strucs_dict[subset_pdb].append(moad_struc)
strucs_dict = {k: sorted(v) for k, v in strucs_dict.items()}

# %%
len(strucs_dict)
# Out:
# 6650

# %%
strucs_dict_filt = {}
for k, v in strucs_dict.items():
    if v == []:
        continue
    else:
        strucs_dict_filt[k] = v[0]

# %%
struc_files = list(strucs_dict_filt.values())

# %%
[el for el in struc_files if len(el) != 9]
# Out:
# []

# %%
for _, row in MOAD_subset_df.iterrows():
    if len(row.lig_resname) > 4:
        print(row)
        break
# Out:
# EC                            4.2.2.10
# pdb_id                            3njv
# lig_resname    GTR RAM GTR RAM GTR RAM
# lig_chain                            B
# lig_resnum                           1
# Name: 17, dtype: object

# %%
MOAD_subset_data_df = extract_dataset_info(
    ds_dir = os.path.join(DATASETS_dir, "BindingMOAD_2020"), ds_name = "bMOAD_filt",
    struc_files = struc_files, lig_tuples_dict = MOAD_lig_tuples_dict,
    pdb_fmt_filt = False, threshold = 5
)
# Out:
# 2qun.bio1 ('FUD', 'C', '291')
# LIGAND ATOMS NOT FOUND
# 2qun.bio1 ('FUD', 'D', '291')
# LIGAND ATOMS NOT FOUND
# 3njv.bio1 ('GTR RAM GTR RAM GTR RAM', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3njv.bio1
# 4rjk.bio1 ('PYR', 'F', '609')
# LIGAND ATOMS NOT FOUND
# 4rjk.bio1 ('PYR', 'F', '610')
# LIGAND ATOMS NOT FOUND
# 4rjk.bio1 ('PYR', 'G', '607')
# LIGAND ATOMS NOT FOUND
# 4rjk.bio1 ('PYR', 'H', '605')
# LIGAND ATOMS NOT FOUND
# 4rjk.bio1 ('PYR', 'G', '608')
# LIGAND ATOMS NOT FOUND
# 4rjk.bio1 ('TPP', 'F', '601')
# LIGAND ATOMS NOT FOUND
# 4rjk.bio1 ('TPP', 'E', '601')
# LIGAND ATOMS NOT FOUND
# 4rjk.bio1 ('TPP', 'G', '601')
# LIGAND ATOMS NOT FOUND
# 4rjk.bio1 ('TDL', 'H', '601')
# LIGAND ATOMS NOT FOUND
# 3h8c.bio1 ('NSZ', 'B', '400')
# LIGAND ATOMS NOT FOUND
# 1xon.bio1 ('PIL', 'B', '502')
# LIGAND ATOMS NOT FOUND
# 6c7d.bio1 ('EOJ', 'D', '2001')
# LIGAND ATOMS NOT FOUND
# 6c7d.bio1 ('EOJ', 'C', '2001')
# LIGAND ATOMS NOT FOUND
# 6c7d.bio1 ('EOJ', 'B', '2001')
# LIGAND ATOMS NOT FOUND
# 5c2h.bio1 ('4PX', 'A', '903')
# LIGAND ATOMS NOT FOUND
# 3ecn.bio1 ('IBM', 'B', '3')
# LIGAND ATOMS NOT FOUND
# 1xm4.bio1 ('PIL', 'B', '1003')
# LIGAND ATOMS NOT FOUND
# 5ede.bio1 ('5M6', 'D', '803')
# LIGAND ATOMS NOT FOUND
# 5ede.bio1 ('5M6', 'C', '803')
# LIGAND ATOMS NOT FOUND
# 5ede.bio1 ('5M6', 'B', '804')
# LIGAND ATOMS NOT FOUND
# 1xmu.bio1 ('ROF', 'B', '102')
# LIGAND ATOMS NOT FOUND
# 1xmy.bio1 ('ROL', 'B', '102')
# LIGAND ATOMS NOT FOUND
# 5b25.bio1 ('4QJ', 'D', '603')
# LIGAND ATOMS NOT FOUND
# 5b25.bio1 ('4QJ', 'C', '603')
# LIGAND ATOMS NOT FOUND
# 5b25.bio1 ('4QJ', 'B', '603')
# LIGAND ATOMS NOT FOUND
# 1so2.bio1 ('666', 'C', '463')
# LIGAND ATOMS NOT FOUND
# 1so2.bio1 ('666', 'D', '464')
# LIGAND ATOMS NOT FOUND
# 3g4g.bio1 ('D71', 'B', '902')
# LIGAND ATOMS NOT FOUND
# 3g4g.bio1 ('D71', 'C', '903')
# LIGAND ATOMS NOT FOUND
# 3g4g.bio1 ('D71', 'D', '904')
# LIGAND ATOMS NOT FOUND
# 5xij.bio1 ('873', 'D', '1004')
# LIGAND ATOMS NOT FOUND
# 5xij.bio1 ('873', 'C', '1004')
# LIGAND ATOMS NOT FOUND
# 5xij.bio1 ('ANP', 'C', '1001')
# LIGAND ATOMS NOT FOUND
# 5xij.bio1 ('ANP', 'D', '1001')
# LIGAND ATOMS NOT FOUND
# 2i4o.bio1 ('ATP', 'C', '441')
# LIGAND ATOMS NOT FOUND
# 5yjw.bio1 ('SMA', 'A', '625')
# LIGAND ATOMS NOT FOUND
# 5yjw.bio1 ('SMA', 'A', '626')
# LIGAND ATOMS NOT FOUND
# 5yjw.bio1 ('FAD', 'A', '601')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5yjw.bio1
# 1m32.bio1 ('PLP', 'C', '4403')
# LIGAND ATOMS NOT FOUND
# 1m32.bio1 ('PLP', 'D', '4404')
# LIGAND ATOMS NOT FOUND
# 1m32.bio1 ('PLP', 'E', '4405')
# LIGAND ATOMS NOT FOUND
# 1m32.bio1 ('PLP', 'F', '4406')
# LIGAND ATOMS NOT FOUND
# 1m32.bio1 ('POA', 'C', '4603')
# LIGAND ATOMS NOT FOUND
# 1r4w.bio1 ('GSH', 'C', '801')
# LIGAND ATOMS NOT FOUND
# 1r4w.bio1 ('GSH', 'D', '901')
# LIGAND ATOMS NOT FOUND
# 3vwx.bio1 ('GSH', 'C', '700')
# LIGAND ATOMS NOT FOUND
# 3vwx.bio1 ('GSH', 'B', '600')
# LIGAND ATOMS NOT FOUND
# 4yh2.bio1 ('GSH', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 4yh2.bio1 ('GSH', 'D', '301')
# LIGAND ATOMS NOT FOUND
# 1v2a.bio1 ('GTS', 'C', '3001')
# LIGAND ATOMS NOT FOUND
# 1v2a.bio1 ('GTS', 'D', '4001')
# LIGAND ATOMS NOT FOUND
# 1jlv.bio1 ('GSH', 'C', '703')
# LIGAND ATOMS NOT FOUND
# 1jlv.bio1 ('GSH', 'D', '706')
# LIGAND ATOMS NOT FOUND
# 1jlv.bio1 ('GSH', 'E', '705')
# LIGAND ATOMS NOT FOUND
# 1jlv.bio1 ('GSH', 'F', '704')
# LIGAND ATOMS NOT FOUND
# 2c3q.bio1 ('GTX', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 2c3q.bio1 ('GTX', 'D', '301')
# LIGAND ATOMS NOT FOUND
# 6fs8.bio1 ('E4Z', 'A', '201')
# LIGAND ATOMS NOT FOUND
# 6ap6.bio1 ('TLF', 'B', '300')
# LIGAND ATOMS NOT FOUND
# 6o7b.bio1 ('A   A   A   A  ', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 6o7b.bio1 ('A   A   A   A  ', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6o7b.bio1
# 6xb3.bio1 ('9BG', 'F', '301')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'G', '302')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'I', '301')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'K', '301')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'J', '301')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'M', '302')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'E', '301')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'P', '301')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'M', '301')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'P', '302')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'C', '302')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'K', '302')
# LIGAND ATOMS NOT FOUND
# 6xb3.bio1 ('9BG', 'G', '301')
# LIGAND ATOMS NOT FOUND
# 6tug.bio1 ('AF2 AF2 AF2 AF2 AF2 AF2', 'A', '502')
# LIGAND ATOMS NOT FOUND
# 6tug.bio1 ('AF2 AF2 AF2 AF2 AF2 AF2', 'E', '502')
# LIGAND ATOMS NOT FOUND
# 6tug.bio1 ('AF2 AF2 AF2 AF2 AF2 AF2', 'C', '502')
# LIGAND ATOMS NOT FOUND
# 6tug.bio1 ('AF2 AF2 AF2 AF2 AF2 AF2', 'G', '502')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6tug.bio1
# 6n6a.bio1 ('G   G  ', 'D', '603')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6n6a.bio1
# 6ap8.bio1 ('BNY', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 2djh.bio1 ('3PD UM3', 'A', '117')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2djh.bio1
# 3bf8.bio1 ('MLA', 'B', '4892')
# LIGAND ATOMS NOT FOUND
# 6n6j.bio1 ('A   A  ', 'C', '603')
# LIGAND ATOMS NOT FOUND
# 6n6j.bio1 ('A   A  ', 'D', '603')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6n6j.bio1
# 4k49.bio1 ('HFQ', 'A', '201')
# LIGAND ATOMS NOT FOUND
# 4k49.bio1 ('HFQ', 'D', '201')
# LIGAND ATOMS NOT FOUND
# 6ur1.bio1 ('AT3', 'B', '402')
# LIGAND ATOMS NOT FOUND
# 6w01.bio1 ('CIT', 'A', '412')
# LIGAND ATOMS NOT FOUND
# 6w01.bio1 ('CIT', 'B', '408')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6w01.bio1
# 2d7d.bio1 ('DT  DT  DT', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 6rcl.bio1 ('A   A  ', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6rcl.bio1
# 5ark.bio1 ('UMP', 'B', '1120')
# LIGAND ATOMS NOT FOUND
# 5ark.bio1 ('UMP', 'C', '1120')
# LIGAND ATOMS NOT FOUND
# 5ark.bio1 ('UMP', 'D', '1120')
# LIGAND ATOMS NOT FOUND
# 2rnf.bio1 ('UM3', 'B', '302')
# LIGAND ATOMS NOT FOUND
# 1brn.bio1 ('DC  DG  DA  DC', 'A', '1')
# LIGAND ATOMS NOT FOUND
# 1brn.bio1 ('DC  DG  DA  DC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 1brn.bio1
# 6m8q.bio1 ('JBG', 'B', '503')
# LIGAND ATOMS NOT FOUND
# 2fli.bio1 ('DX5', 'G', '1911')
# LIGAND ATOMS NOT FOUND
# 2fli.bio1 ('DX5', 'H', '1912')
# LIGAND ATOMS NOT FOUND
# 2fli.bio1 ('DX5', 'I', '1913')
# LIGAND ATOMS NOT FOUND
# 2fli.bio1 ('DX5', 'J', '1914')
# LIGAND ATOMS NOT FOUND
# 2fli.bio1 ('DX5', 'K', '1915')
# LIGAND ATOMS NOT FOUND
# 2fli.bio1 ('DX5', 'L', '1916')
# LIGAND ATOMS NOT FOUND
# 2wcv.bio1 ('FUC', 'F', '1141')
# LIGAND ATOMS NOT FOUND
# 2wcv.bio1 ('FUC', 'G', '1141')
# LIGAND ATOMS NOT FOUND
# 2wcv.bio1 ('FUC', 'H', '1141')
# LIGAND ATOMS NOT FOUND
# 2wcv.bio1 ('FUC', 'I', '1141')
# LIGAND ATOMS NOT FOUND
# 2wcv.bio1 ('FUC', 'J', '1141')
# LIGAND ATOMS NOT FOUND
# 2wet.bio1 ('FAD', 'B', '1652')
# LIGAND ATOMS NOT FOUND
# 2wet.bio1 ('FAD', 'C', '1513')
# LIGAND ATOMS NOT FOUND
# 2wet.bio1 ('TRP', 'B', '650')
# LIGAND ATOMS NOT FOUND
# 4p8k.bio1 ('FAD', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 4p8k.bio1 ('38C', 'B', '502')
# LIGAND ATOMS NOT FOUND
# 3dje.bio1 ('FSA', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 4yry.bio1 ('FAD', 'C', '502')
# LIGAND ATOMS NOT FOUND
# 4yry.bio1 ('FAD', 'D', '503')
# LIGAND ATOMS NOT FOUND
# 4yry.bio1 ('NAD', 'D', '504')
# LIGAND ATOMS NOT FOUND
# 6nkm.bio1 ('NAP', 'E', '801')
# LIGAND ATOMS NOT FOUND
# 6nkm.bio1 ('NAP', 'F', '801')
# LIGAND ATOMS NOT FOUND
# 6zxx.bio1 ('QSB', 'C', '806')
# LIGAND ATOMS NOT FOUND
# 6zxx.bio1 ('QSB', 'B', '706')
# LIGAND ATOMS NOT FOUND
# 6zxx.bio1 ('QSH', 'B', '705')
# LIGAND ATOMS NOT FOUND
# 6zxx.bio1 ('QSH', 'C', '805')
# LIGAND ATOMS NOT FOUND
# 6kji.bio1 ('SAH', 'B', '1001')
# LIGAND ATOMS NOT FOUND
# 6kji.bio1 ('SAH', 'C', '1001')
# LIGAND ATOMS NOT FOUND
# 4k28.bio1 ('NAD', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 4z3x.bio1 ('MTE', 'C', '703')
# LIGAND ATOMS NOT FOUND
# 4z3x.bio1 ('MTE', 'D', '703')
# LIGAND ATOMS NOT FOUND
# 4z3x.bio1 ('MTE', 'D', '704')
# LIGAND ATOMS NOT FOUND
# 4z3x.bio1 ('MTE', 'C', '702')
# LIGAND ATOMS NOT FOUND
# 4z3x.bio1 ('4KX', 'C', '707')
# LIGAND ATOMS NOT FOUND
# 4z3x.bio1 ('4KX', 'D', '709')
# LIGAND ATOMS NOT FOUND
# 3r5w.bio1 ('F42', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 3r5w.bio1 ('F42', 'C', '201')
# LIGAND ATOMS NOT FOUND
# 3r5w.bio1 ('F42', 'D', '201')
# LIGAND ATOMS NOT FOUND
# 3r5w.bio1 ('F42', 'E', '201')
# LIGAND ATOMS NOT FOUND
# 3r5w.bio1 ('F42', 'K', '201')
# LIGAND ATOMS NOT FOUND
# 3r5w.bio1 ('F42', 'L', '201')
# LIGAND ATOMS NOT FOUND
# 3r5w.bio1 ('F42', 'M', '201')
# LIGAND ATOMS NOT FOUND
# 3r5w.bio1 ('F42', 'N', '201')
# LIGAND ATOMS NOT FOUND
# 3r5w.bio1 ('F42', 'O', '201')
# LIGAND ATOMS NOT FOUND
# 3q9t.bio1 ('FAY', 'B', '600')
# LIGAND ATOMS NOT FOUND
# 3q9t.bio1 ('FAY', 'C', '600')
# LIGAND ATOMS NOT FOUND
# 5umw.bio1 ('RBF', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 6vgc.bio1 ('QY1', 'E', '201')
# LIGAND ATOMS NOT FOUND
# 6vgc.bio1 ('QY1', 'F', '201')
# LIGAND ATOMS NOT FOUND
# 6vgc.bio1 ('QY1', 'D', '201')
# LIGAND ATOMS NOT FOUND
# 6vgc.bio1 ('BOG', 'F', '202')
# LIGAND ATOMS NOT FOUND
# 5u97.bio1 ('PIT', 'B', '604')
# LIGAND ATOMS NOT FOUND
# 5u97.bio1 ('PIT', 'B', '602')
# LIGAND ATOMS NOT FOUND
# 5u97.bio1 ('PIT', 'C', '604')
# LIGAND ATOMS NOT FOUND
# 5u97.bio1 ('PIT', 'C', '602')
# LIGAND ATOMS NOT FOUND
# 5aci.bio1 ('BGC BGC BGC BGC BGC BGC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5aci.bio1
# 5awv.bio1 ('GHP 3MY 3FG GHP GHP OMY 3FG NAG MAN', 'I', '1')
# LIGAND ATOMS NOT FOUND
# 5awv.bio1 ('GHP 3MY 3FG GHP GHP OMY 3FG NAG MAN', 'J', '1')
# LIGAND ATOMS NOT FOUND
# 5awv.bio1 ('GHP 3MY 3FG GHP GHP OMY 3FG', 'M', '1')
# LIGAND ATOMS NOT FOUND
# 5awv.bio1 ('GHP 3MY 3FG GHP GHP OMY 3FG', 'J', '1')
# LIGAND ATOMS NOT FOUND
# 5awv.bio1 ('GHP 3MY 3FG GHP GHP OMY 3FG', 'L', '1')
# LIGAND ATOMS NOT FOUND
# 5awv.bio1 ('GHP 3MY 3FG GHP GHP OMY 3FG', 'I', '1')
# LIGAND ATOMS NOT FOUND
# 5awv.bio1 ('GHP 3MY 3FG GHP GHP OMY 3FG', 'N', '1')
# LIGAND ATOMS NOT FOUND
# 5awv.bio1 ('GHP 3MY 3FG GHP GHP OMY 3FG', 'K', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5awv.bio1
# 5k53.bio1 ('STE', 'B', '502')
# LIGAND ATOMS NOT FOUND
# 3kji.bio1 ('ADP', 'B', '256')
# LIGAND ATOMS NOT FOUND
# 6nor.bio1 ('NAD', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 6nor.bio1 ('NAD', 'F', '401')
# LIGAND ATOMS NOT FOUND
# 6nor.bio1 ('NAD', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 6nor.bio1 ('NAD', 'E', '401')
# LIGAND ATOMS NOT FOUND
# 3gmb.bio1 ('FAD', 'B', '400')
# LIGAND ATOMS NOT FOUND
# 5mst.bio1 ('FUM', 'B', '1203')
# LIGAND ATOMS NOT FOUND
# 5mst.bio1 ('AMP', 'B', '1204')
# LIGAND ATOMS NOT FOUND
# 4e5n.bio1 ('NAD', 'B', '800')
# LIGAND ATOMS NOT FOUND
# 4e5n.bio1 ('NAD', 'D', '800')
# LIGAND ATOMS NOT FOUND
# 4e5n.bio1 ('NAD', 'E', '800')
# LIGAND ATOMS NOT FOUND
# 4e5n.bio1 ('NAD', 'F', '800')
# LIGAND ATOMS NOT FOUND
# 4e5n.bio1 ('NAD', 'G', '800')
# LIGAND ATOMS NOT FOUND
# 4e5n.bio1 ('NAD', 'H', '800')
# LIGAND ATOMS NOT FOUND
# 4f07.bio1 ('FAD', 'H', '201')
# LIGAND ATOMS NOT FOUND
# 4f07.bio1 ('FAD', 'E', '201')
# LIGAND ATOMS NOT FOUND
# 4f07.bio1 ('FAD', 'G', '201')
# LIGAND ATOMS NOT FOUND
# 4f07.bio1 ('FAD', 'I', '201')
# LIGAND ATOMS NOT FOUND
# 4f07.bio1 ('FAD', 'K', '500')
# LIGAND ATOMS NOT FOUND
# 4f07.bio1 ('FAD', 'J', '201')
# LIGAND ATOMS NOT FOUND
# 4f07.bio1 ('FAD', 'F', '500')
# LIGAND ATOMS NOT FOUND
# 4f07.bio1 ('FAD', 'C', '201')
# LIGAND ATOMS NOT FOUND
# 4f07.bio1 ('FAD', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 4f07.bio1 ('FAD', 'L', '201')
# LIGAND ATOMS NOT FOUND
# 2yp6.bio1 ('C6W', 'D', '1186')
# LIGAND ATOMS NOT FOUND
# 2yp6.bio1 ('C6W', 'B', '1186')
# LIGAND ATOMS NOT FOUND
# 2yp6.bio1 ('C6W', 'C', '1186')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('HP7', 'I', '550')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('HP7', 'J', '550')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('HP7', 'K', '550')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('HP7', 'L', '550')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('HP7', 'M', '550')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('HP7', 'N', '550')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('HP7', 'O', '550')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('HP7', 'P', '550')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('NAI', 'I', '500')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('NAI', 'O', '500')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('NAI', 'K', '500')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('NAI', 'L', '500')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('NAI', 'M', '500')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('NAI', 'N', '500')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('NAI', 'J', '500')
# LIGAND ATOMS NOT FOUND
# 3q2k.bio1 ('NAI', 'P', '500')
# LIGAND ATOMS NOT FOUND
# 1rz0.bio1 ('FAD', 'C', '3200')
# LIGAND ATOMS NOT FOUND
# 1rz0.bio1 ('FAD', 'D', '4200')
# LIGAND ATOMS NOT FOUND
# 1rz0.bio1 ('FAD', 'E', '5200')
# LIGAND ATOMS NOT FOUND
# 1rz0.bio1 ('FAD', 'F', '6200')
# LIGAND ATOMS NOT FOUND
# 1rz0.bio1 ('FAD', 'G', '7200')
# LIGAND ATOMS NOT FOUND
# 1rz0.bio1 ('FAD', 'H', '8200')
# LIGAND ATOMS NOT FOUND
# 6l86.bio1 ('LMR', 'B', '302')
# LIGAND ATOMS NOT FOUND
# 6l86.bio1 ('LMR', 'B', '303')
# LIGAND ATOMS NOT FOUND
# 6l86.bio1 ('LMR', 'D', '302')
# LIGAND ATOMS NOT FOUND
# 6ydc.bio1 ('BGC BGC BGC', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 6ydc.bio1 ('BGC BGC BGC BGC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 6ydc.bio1 ('BGC BGC BGC BGC', 'F', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6ydc.bio1
# 6smt.bio1 ('NDP', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 6smt.bio1 ('NDP', 'E', '301')
# LIGAND ATOMS NOT FOUND
# 6smt.bio1 ('NDP', 'D', '301')
# LIGAND ATOMS NOT FOUND
# 6qx6.bio1 ('DBV', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 5z75.bio1 ('NAD', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 3pqb.bio1 ('VGP', 'B', '500')
# LIGAND ATOMS NOT FOUND
# 3pqb.bio1 ('VGP', 'C', '500')
# LIGAND ATOMS NOT FOUND
# 6on3.bio1 ('DAH', 'F', '203')
# LIGAND ATOMS NOT FOUND
# 6on3.bio1 ('DAH', 'D', '202')
# LIGAND ATOMS NOT FOUND
# 6on3.bio1 ('DAH', 'E', '202')
# LIGAND ATOMS NOT FOUND
# 6on3.bio1 ('DAH', 'C', '202')
# LIGAND ATOMS NOT FOUND
# 6er9.bio1 ('NAP', 'B', '602')
# LIGAND ATOMS NOT FOUND
# 6er9.bio1 ('FAD', 'B', '601')
# LIGAND ATOMS NOT FOUND
# 5k0a.bio1 ('FAD', 'D', '402')
# LIGAND ATOMS NOT FOUND
# 5k0a.bio1 ('FAD', 'C', '401')
# LIGAND ATOMS NOT FOUND
# 5k0a.bio1 ('FAD', 'C', '402')
# LIGAND ATOMS NOT FOUND
# 5k0a.bio1 ('FAD', 'D', '403')
# LIGAND ATOMS NOT FOUND
# 6kia.bio1 ('NAI', 'C', '501')
# LIGAND ATOMS NOT FOUND
# 6kia.bio1 ('NAI', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 6vch.bio1 ('QVM', 'B', '503')
# LIGAND ATOMS NOT FOUND
# 6vch.bio1 ('QVM', 'C', '502')
# LIGAND ATOMS NOT FOUND
# 6vch.bio1 ('QVM', 'D', '502')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('FAD', 'C', '3200')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('FAD', 'D', '4200')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('FAD', 'E', '5200')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('FAD', 'F', '6200')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('FAD', 'G', '7200')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('FAD', 'H', '8200')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('NAD', 'C', '3201')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('NAD', 'D', '4201')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('NAD', 'E', '5201')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('NAD', 'F', '6201')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('NAD', 'G', '7201')
# LIGAND ATOMS NOT FOUND
# 1rz1.bio1 ('NAD', 'H', '8201')
# LIGAND ATOMS NOT FOUND
# 3w54.bio1 ('RNB', 'B', '504')
# LIGAND ATOMS NOT FOUND
# 3w54.bio1 ('RNB', 'D', '504')
# LIGAND ATOMS NOT FOUND
# 3w54.bio1 ('RNB', 'C', '504')
# LIGAND ATOMS NOT FOUND
# 5ocm.bio1 ('NAP', 'E', '301')
# LIGAND ATOMS NOT FOUND
# 5ocm.bio1 ('NAP', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 5ocm.bio1 ('NAP', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 5ocm.bio1 ('NAP', 'D', '301')
# LIGAND ATOMS NOT FOUND
# 5ocm.bio1 ('9RH', 'E', '302')
# LIGAND ATOMS NOT FOUND
# 5ocm.bio1 ('9RH', 'D', '302')
# LIGAND ATOMS NOT FOUND
# 5ocm.bio1 ('9RH', 'C', '302')
# LIGAND ATOMS NOT FOUND
# 5ocm.bio1 ('9RH', 'B', '302')
# LIGAND ATOMS NOT FOUND
# 3uoy.bio1 ('FAD', 'B', '551')
# LIGAND ATOMS NOT FOUND
# 3uoy.bio1 ('NAP', 'B', '552')
# LIGAND ATOMS NOT FOUND
# 4om8.bio1 ('NAD', 'B', '402')
# LIGAND ATOMS NOT FOUND
# 5u5g.bio1 ('7VD', 'C', '302')
# LIGAND ATOMS NOT FOUND
# 5u5g.bio1 ('7VD', 'D', '302')
# LIGAND ATOMS NOT FOUND
# 5u5g.bio1 ('NAP', 'D', '301')
# LIGAND ATOMS NOT FOUND
# 5u5g.bio1 ('NAP', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 6yde.bio1 ('BGC BGC BGC BGC BGC BGC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6yde.bio1
# 4d7e.bio1 ('FAD', 'C', '500')
# LIGAND ATOMS NOT FOUND
# 4d7e.bio1 ('FAD', 'A', '500')
# LIGAND ATOMS NOT FOUND
# 3tl1.bio1 ('JRO', 'B', '160')
# LIGAND ATOMS NOT FOUND
# 4b7x.bio1 ('NAP', 'D', '400')
# LIGAND ATOMS NOT FOUND
# 4b7x.bio1 ('NAP', 'E', '400')
# LIGAND ATOMS NOT FOUND
# 4b7x.bio1 ('NAP', 'C', '400')
# LIGAND ATOMS NOT FOUND
# 4b7x.bio1 ('NAP', 'B', '400')
# LIGAND ATOMS NOT FOUND
# 4b7x.bio1 ('NAP', 'A', '400')
# LIGAND ATOMS NOT FOUND
# 4b7x.bio1 ('NAP', 'F', '400')
# LIGAND ATOMS NOT FOUND
# 4b7x.bio1 ('NAP', 'K', '400')
# LIGAND ATOMS NOT FOUND
# 4b7x.bio1 ('NAP', 'L', '400')
# LIGAND ATOMS NOT FOUND
# 4b7x.bio1 ('NAP', 'I', '400')
# LIGAND ATOMS NOT FOUND
# 4b7x.bio1 ('NAP', 'J', '400')
# LIGAND ATOMS NOT FOUND
# 5jfl.bio1 ('NAD', 'G', '600')
# LIGAND ATOMS NOT FOUND
# 5jfl.bio1 ('NAD', 'F', '600')
# LIGAND ATOMS NOT FOUND
# 5jfl.bio1 ('NAD', 'H', '600')
# LIGAND ATOMS NOT FOUND
# 5jfl.bio1 ('NAD', 'E', '600')
# LIGAND ATOMS NOT FOUND
# 5gsn.bio1 ('NAP', 'D', '501')
# LIGAND ATOMS NOT FOUND
# 5gsn.bio1 ('NAP', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 5gsn.bio1 ('FAD', 'D', '502')
# LIGAND ATOMS NOT FOUND
# 5gsn.bio1 ('FAD', 'B', '502')
# LIGAND ATOMS NOT FOUND
# 4m26.bio1 ('SIN', 'C', '402')
# LIGAND ATOMS NOT FOUND
# 4m26.bio1 ('SIN', 'D', '402')
# LIGAND ATOMS NOT FOUND
# 4m26.bio1 ('ZZU', 'D', '403')
# LIGAND ATOMS NOT FOUND
# 4m26.bio1 ('ZZU', 'C', '403')
# LIGAND ATOMS NOT FOUND
# 1z2i.bio1 ('NAD', 'C', '702')
# LIGAND ATOMS NOT FOUND
# 1z2i.bio1 ('NAD', 'D', '703')
# LIGAND ATOMS NOT FOUND
# 4r1s.bio1 ('NAP', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 5c3r.bio1 ('HMU', 'D', '403')
# LIGAND ATOMS NOT FOUND
# 5c3r.bio1 ('HMU', 'B', '403')
# LIGAND ATOMS NOT FOUND
# 5c3r.bio1 ('HMU', 'C', '403')
# LIGAND ATOMS NOT FOUND
# 5c3r.bio1 ('AKG', 'D', '402')
# LIGAND ATOMS NOT FOUND
# 5c3r.bio1 ('AKG', 'C', '402')
# LIGAND ATOMS NOT FOUND
# 5c3r.bio1 ('AKG', 'B', '402')
# LIGAND ATOMS NOT FOUND
# 5nmx.bio1 ('FAD', 'D', '501')
# LIGAND ATOMS NOT FOUND
# 5nmx.bio1 ('FAD', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 5nmx.bio1 ('NAP', 'B', '502')
# LIGAND ATOMS NOT FOUND
# 5nmx.bio1 ('NAP', 'D', '502')
# LIGAND ATOMS NOT FOUND
# 4n82.bio1 ('FMN', 'A', '201')
# LIGAND ATOMS NOT FOUND
# 5ag3.bio1 ('3EB', 'B', '1341')
# LIGAND ATOMS NOT FOUND
# 4r81.bio1 ('FMN', 'C', '300')
# LIGAND ATOMS NOT FOUND
# 4r81.bio1 ('FMN', 'D', '300')
# LIGAND ATOMS NOT FOUND
# 3s2y.bio1 ('FMN', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 3s2y.bio1 ('FMN', 'C', '200')
# LIGAND ATOMS NOT FOUND
# 3s2y.bio1 ('FMN', 'D', '200')
# LIGAND ATOMS NOT FOUND
# 7bvj.bio1 ('NAD', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 7bvj.bio1 ('NAD', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 7bvj.bio1 ('NAD', 'C', '401')
# LIGAND ATOMS NOT FOUND
# 5ko8.bio1 ('FMN', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 5ko8.bio1 ('IYR', 'B', '302')
# LIGAND ATOMS NOT FOUND
# 1oj7.bio1 ('NZQ', 'B', '1388')
# LIGAND ATOMS NOT FOUND
# 6b9r.bio1 ('2HE', 'B', '502')
# LIGAND ATOMS NOT FOUND
# 6b9r.bio1 ('2HE', 'C', '502')
# LIGAND ATOMS NOT FOUND
# 1xdy.bio1 ('MTE', 'B', '302')
# LIGAND ATOMS NOT FOUND
# 1xdy.bio1 ('MTE', 'C', '303')
# LIGAND ATOMS NOT FOUND
# 1xdy.bio1 ('MTE', 'D', '304')
# LIGAND ATOMS NOT FOUND
# 1xdy.bio1 ('MTE', 'E', '305')
# LIGAND ATOMS NOT FOUND
# 1xdy.bio1 ('MTE', 'F', '306')
# LIGAND ATOMS NOT FOUND
# 1xdy.bio1 ('MTE', 'G', '307')
# LIGAND ATOMS NOT FOUND
# 1xdy.bio1 ('MTE', 'H', '308')
# LIGAND ATOMS NOT FOUND
# 1xdy.bio1 ('MTE', 'I', '309')
# LIGAND ATOMS NOT FOUND
# 1xdy.bio1 ('MTE', 'J', '310')
# LIGAND ATOMS NOT FOUND
# 1g8k.bio1 ('MGD', 'C', '5101')
# LIGAND ATOMS NOT FOUND
# 1g8k.bio1 ('MGD', 'C', '5102')
# LIGAND ATOMS NOT FOUND
# 1g8k.bio1 ('MGD', 'E', '5201')
# LIGAND ATOMS NOT FOUND
# 1g8k.bio1 ('MGD', 'E', '5202')
# LIGAND ATOMS NOT FOUND
# 1g8k.bio1 ('MGD', 'G', '5301')
# LIGAND ATOMS NOT FOUND
# 1g8k.bio1 ('MGD', 'G', '5302')
# LIGAND ATOMS NOT FOUND
# 2biw.bio1 ('3ON', 'B', '1491')
# LIGAND ATOMS NOT FOUND
# 2biw.bio1 ('3ON', 'C', '1491')
# LIGAND ATOMS NOT FOUND
# 2biw.bio1 ('3ON', 'D', '1491')
# LIGAND ATOMS NOT FOUND
# 1oqc.bio1 ('FAD', 'B', '126')
# LIGAND ATOMS NOT FOUND
# 1oqc.bio1 ('FAD', 'D', '126')
# LIGAND ATOMS NOT FOUND
# 2zyi.bio1 ('STE', 'B', '500')
# LIGAND ATOMS NOT FOUND
# 1hmu.bio1 ('ASG GCD', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 1hmu.bio1
# 1rwh.bio1 ('ASG GCT ASG GAD', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 1rwh.bio1
# 6jtc.bio1 ('C8O', 'B', '801')
# LIGAND ATOMS NOT FOUND
# 6sud.bio1 ('XYP', 'B', '510')
# LIGAND ATOMS NOT FOUND
# 1wu6.bio1 ('XYP XYP', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 1wu6.bio1
# 4gv8.bio1 ('DUP', 'E', '201')
# LIGAND ATOMS NOT FOUND
# 4gv8.bio1 ('DUP', 'F', '201')
# LIGAND ATOMS NOT FOUND
# 4gv8.bio1 ('DUP', 'D', '201')
# LIGAND ATOMS NOT FOUND
# 5myd.bio1 ('DUP', 'C', '201')
# LIGAND ATOMS NOT FOUND
# 5myd.bio1 ('DUP', 'A', '201')
# LIGAND ATOMS NOT FOUND
# 5myd.bio1 ('DUP', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 5myd.bio1 ('DUP', 'D', '201')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5myd.bio1
# 1f7k.bio1 ('UMP', 'B', '703')
# LIGAND ATOMS NOT FOUND
# 4dl8.bio1 ('UMP AF3 PO4', 'A', '301')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4dl8.bio1
# 3exh.bio1 ('TPP', 'E', '1502')
# LIGAND ATOMS NOT FOUND
# 3exh.bio1 ('TPP', 'G', '1502')
# LIGAND ATOMS NOT FOUND
# 3dva.bio1 ('TPW', 'E', '1370')
# LIGAND ATOMS NOT FOUND
# 3dva.bio1 ('TPW', 'G', '1370')
# LIGAND ATOMS NOT FOUND
# 1d8t.bio1 ('GDP', 'B', '999')
# LIGAND ATOMS NOT FOUND
# 3ilr.bio1 ('SGN IXD', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 3ilr.bio1 ('IXD SGN', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3ilr.bio1
# 5e70.bio1 ('GLC GLC GLC GLC GLC GLC GLC GLC', 'F', '5')
# LIGAND ATOMS NOT FOUND
# 5e70.bio1 ('GLC GLC GLC GLC GLC GLC GLC GLC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 5e70.bio1 ('GLC GLC GLC GLC GLC GLC GLC GLC', 'H', '1')
# LIGAND ATOMS NOT FOUND
# 5e70.bio1 ('GLC GLC GLC GLC GLC GLC GLC GLC', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 5e70.bio1 ('GLC GLC GLC GLC GLC GLC GLC GLC', 'I', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5e70.bio1
# 5gqx.bio1 ('GLC GLC GLC GLC GLC GLC GLC', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 5gqx.bio1 ('GLC GLC GLC GLC GLC GLC GLC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# 5gqx.bio1 ('GLC GLC GLC GLC GLC GLC GLC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 5gqx.bio1 ('GLC GLC GLC GLC', 'H', '1')
# LIGAND ATOMS NOT FOUND
# 5gqx.bio1 ('GLC GLC GLC GLC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 5gqx.bio1 ('GLC GLC GLC GLC', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 5gqx.bio1 ('GLC GLC GLC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 5gqx.bio1 ('GLC GLC GLC', 'I', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5gqx.bio1
# 3vu2.bio1 ('GLC GLC GLC GLC GLC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 3vu2.bio1 ('GLC GLC GLC GLC GLC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3vu2.bio1
# 6om8.bio1 ('UDX', 'G', '500')
# LIGAND ATOMS NOT FOUND
# 6om8.bio1 ('UDX', 'L', '500')
# LIGAND ATOMS NOT FOUND
# 6om8.bio1 ('UDX', 'L', '501')
# LIGAND ATOMS NOT FOUND
# 6om8.bio1 ('UDX', 'K', '500')
# LIGAND ATOMS NOT FOUND
# 6om8.bio1 ('UDX', 'I', '501')
# LIGAND ATOMS NOT FOUND
# 6om8.bio1 ('UDX', 'H', '501')
# LIGAND ATOMS NOT FOUND
# 6om8.bio1 ('UDX', 'K', '501')
# LIGAND ATOMS NOT FOUND
# 6om8.bio1 ('UDX', 'H', '500')
# LIGAND ATOMS NOT FOUND
# 6om8.bio1 ('UDX', 'J', '500')
# LIGAND ATOMS NOT FOUND
# 6om8.bio1 ('UDX', 'G', '501')
# LIGAND ATOMS NOT FOUND
# 6om8.bio1 ('UDX', 'J', '501')
# LIGAND ATOMS NOT FOUND
# 6om8.bio1 ('UDX', 'I', '500')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('DZ4', 'F', '706')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('DZ4', 'F', '705')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('DZ4', 'E', '708')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('DZ4', 'G', '706')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('DZ4', 'H', '701')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('DZ4', 'H', '706')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('DZ4', 'E', '705')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('DZ4', 'G', '701')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('GTP', 'H', '707')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('GTP', 'G', '707')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('GTP', 'E', '706')
# LIGAND ATOMS NOT FOUND
# 6xu1.bio1 ('GTP', 'E', '707')
# LIGAND ATOMS NOT FOUND
# 4rrg.bio1 ('A3T', 'C', '201')
# LIGAND ATOMS NOT FOUND
# 4rdh.bio1 ('AMP', 'D', '301')
# LIGAND ATOMS NOT FOUND
# 4rdh.bio1 ('AMP', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 4d79.bio1 ('ATP', 'C', '401')
# LIGAND ATOMS NOT FOUND
# 4d79.bio1 ('ATP', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 4rdi.bio1 ('ATP', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 4rdi.bio1 ('ATP', 'D', '301')
# LIGAND ATOMS NOT FOUND
# 6u9n.bio1 ('Q34', 'B', '4001')
# LIGAND ATOMS NOT FOUND
# 3hna.bio1 ('SAH', 'B', '102')
# LIGAND ATOMS NOT FOUND
# 5mw4.bio1 ('5JU', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 6ict.bio1 ('SAH', 'C', '601')
# LIGAND ATOMS NOT FOUND
# 6ict.bio1 ('SAH', 'B', '1001')
# LIGAND ATOMS NOT FOUND
# 6ict.bio1 ('SAH', 'D', '601')
# LIGAND ATOMS NOT FOUND
# 6box.bio1 ('SAH', 'B', '505')
# LIGAND ATOMS NOT FOUND
# 6kqq.bio1 ('SAM', 'B', '2101')
# LIGAND ATOMS NOT FOUND
# 5vah.bio1 ('SAH', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 5vbc.bio1 ('SAH', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 5hq8.bio1 ('SAH', 'B', '508')
# LIGAND ATOMS NOT FOUND
# 5va6.bio1 ('SAH', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 4ynm.bio1 ('SAM', 'B', '2304')
# LIGAND ATOMS NOT FOUND
# NO PROTEIN ATOMS WITHIN DISTANCE THRESHOLD for ('SAH', 'A', '102') of 2rfi.bio1
# 1u2z.bio1 ('SAH', 'B', '802')
# LIGAND ATOMS NOT FOUND
# 1u2z.bio1 ('SAH', 'C', '803')
# LIGAND ATOMS NOT FOUND
# 6r0p.bio1 ('JNT', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 4u60.bio1 ('BGC GAL SIA NGA GAL', 'I', '1')
# LIGAND ATOMS NOT FOUND
# 4u60.bio1 ('BGC GAL SIA NGA GAL', 'H', '1')
# LIGAND ATOMS NOT FOUND
# 4u60.bio1 ('GAL SIA NGA', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 4u60.bio1 ('GAL SIA NGA', 'G', '3')
# LIGAND ATOMS NOT FOUND
# 5zqk.bio1 ('SAM', 'B', '1001')
# LIGAND ATOMS NOT FOUND
# 2wa2.bio1 ('SAM', 'B', '1267')
# LIGAND ATOMS NOT FOUND
# 4ri1.bio1 ('ACO', 'B', '1301')
# LIGAND ATOMS NOT FOUND
# 4ri1.bio1 ('ACO', 'C', '1301')
# LIGAND ATOMS NOT FOUND
# 4r3u.bio1 ('3KK', 'B', '802')
# LIGAND ATOMS NOT FOUND
# 4r3u.bio1 ('3HC', 'B', '801')
# LIGAND ATOMS NOT FOUND
# 3l24.bio1 ('GOA', 'B', '522')
# LIGAND ATOMS NOT FOUND
# 3l24.bio1 ('GOA', 'C', '521')
# LIGAND ATOMS NOT FOUND
# 5cuq.bio1 ('NSC', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 6nya.bio1 ('ATP', 'D', '1202')
# LIGAND ATOMS NOT FOUND
# 3ngz.bio1 ('DG  DC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 3ngz.bio1 ('DG  DC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3ngz.bio1
# 4iae.bio1 ('1DX', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 6zgp.bio1 ('QKQ', 'I', '403')
# LIGAND ATOMS NOT FOUND
# 6zgp.bio1 ('QKQ', 'G', '403')
# LIGAND ATOMS NOT FOUND
# 6zgp.bio1 ('QKQ', 'J', '403')
# LIGAND ATOMS NOT FOUND
# 6zgp.bio1 ('QKQ', 'L', '403')
# LIGAND ATOMS NOT FOUND
# 6zgp.bio1 ('QKQ', 'K', '403')
# LIGAND ATOMS NOT FOUND
# 6zgp.bio1 ('QKQ', 'D', '403')
# LIGAND ATOMS NOT FOUND
# 6zgp.bio1 ('QKQ', 'F', '403')
# LIGAND ATOMS NOT FOUND
# 6zgp.bio1 ('QKQ', 'E', '403')
# LIGAND ATOMS NOT FOUND
# 6zgp.bio1 ('QKQ', 'H', '403')
# LIGAND ATOMS NOT FOUND
# 4pyh.bio1 ('GLC GLC GLC GLC GLC GLC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4pyh.bio1
# 4rkk.bio1 ('GLC GLC GLC GLC GLC GLC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 4rkk.bio1 ('GLC GLC GLC GLC GLC GLC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# 4rkk.bio1 ('GLC GLC GLC GLC GLC GLC', 'F', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4rkk.bio1
# 5df1.bio1 ('58X', 'B', '901')
# LIGAND ATOMS NOT FOUND
# 5df1.bio1 ('NAP', 'B', '900')
# LIGAND ATOMS NOT FOUND
# 6cd1.bio1 ('PLG', 'F', '601')
# LIGAND ATOMS NOT FOUND
# 1dfo.bio1 ('FFO', 'C', '3002')
# LIGAND ATOMS NOT FOUND
# 1dfo.bio1 ('FFO', 'D', '4002')
# LIGAND ATOMS NOT FOUND
# 1dfo.bio1 ('PLG', 'C', '3001')
# LIGAND ATOMS NOT FOUND
# 1dfo.bio1 ('PLG', 'D', '4001')
# LIGAND ATOMS NOT FOUND
# 5i7a.bio1 ('68Q', 'C', '401')
# LIGAND ATOMS NOT FOUND
# 5i7a.bio1 ('68Q', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 4kgd.bio1 ('TDP', 'A', '704')
# LIGAND ATOMS NOT FOUND
# 4kgd.bio1 ('TDP', 'B', '703')
# LIGAND ATOMS NOT FOUND
# 5uxh.bio1 ('GFB', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 5kxq.bio1 ('GDP', 'D', '403')
# LIGAND ATOMS NOT FOUND
# 5kxq.bio1 ('GDP', 'C', '403')
# LIGAND ATOMS NOT FOUND
# 5foe.bio1 ('GDP', 'B', '1426')
# LIGAND ATOMS NOT FOUND
# 1ak0.bio1 ('ADS THS THS THS', 'A', '292')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 1ak0.bio1
# 7bys.bio1 ('CIT', 'B', '506')
# LIGAND ATOMS NOT FOUND
# 4cdn.bio1 ('FAD', 'B', '998')
# LIGAND ATOMS NOT FOUND
# 4cdn.bio1 ('FO1', 'B', '999')
# LIGAND ATOMS NOT FOUND
# 3umv.bio1 ('FAD', 'B', '801')
# LIGAND ATOMS NOT FOUND
# 1a8r.bio1 ('GTP', 'F', '406')
# LIGAND ATOMS NOT FOUND
# 1a8r.bio1 ('GTP', 'G', '407')
# LIGAND ATOMS NOT FOUND
# 1a8r.bio1 ('GTP', 'H', '408')
# LIGAND ATOMS NOT FOUND
# 1a8r.bio1 ('GTP', 'I', '409')
# LIGAND ATOMS NOT FOUND
# 1a8r.bio1 ('GTP', 'J', '410')
# LIGAND ATOMS NOT FOUND
# 1a8r.bio1 ('GTP', 'K', '411')
# LIGAND ATOMS NOT FOUND
# 1a8r.bio1 ('GTP', 'L', '412')
# LIGAND ATOMS NOT FOUND
# 1a8r.bio1 ('GTP', 'M', '413')
# LIGAND ATOMS NOT FOUND
# 1a8r.bio1 ('GTP', 'N', '414')
# LIGAND ATOMS NOT FOUND
# 1a8r.bio1 ('GTP', 'O', '415')
# LIGAND ATOMS NOT FOUND
# 6z86.bio1 ('QBQ', 'M', '302')
# LIGAND ATOMS NOT FOUND
# 6z86.bio1 ('QBQ', 'H', '302')
# LIGAND ATOMS NOT FOUND
# 6z86.bio1 ('QBQ', 'I', '302')
# LIGAND ATOMS NOT FOUND
# 6z86.bio1 ('QBQ', 'L', '302')
# LIGAND ATOMS NOT FOUND
# 6z86.bio1 ('QBQ', 'E', '302')
# LIGAND ATOMS NOT FOUND
# 6z86.bio1 ('QBQ', 'J', '302')
# LIGAND ATOMS NOT FOUND
# 6z86.bio1 ('QBQ', 'N', '302')
# LIGAND ATOMS NOT FOUND
# 6z86.bio1 ('QBQ', 'G', '302')
# LIGAND ATOMS NOT FOUND
# 6z86.bio1 ('QBQ', 'F', '302')
# LIGAND ATOMS NOT FOUND
# 6z86.bio1 ('QBQ', 'K', '302')
# LIGAND ATOMS NOT FOUND
# 2o2c.bio1 ('G6Q', 'B', '5002')
# LIGAND ATOMS NOT FOUND
# 2o2c.bio1 ('G6Q', 'C', '5003')
# LIGAND ATOMS NOT FOUND
# 5zic.bio1 ('BMA Z4Y NAG', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 5zic.bio1 ('BMA Z4Y NAG', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5zic.bio1
# 1djx.bio1 ('I3P', 'B', '1')
# LIGAND ATOMS NOT FOUND
# 5hw4.bio1 ('SAM', 'C', '801')
# LIGAND ATOMS NOT FOUND
# 5utq.bio1 ('OAN', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 5abh.bio1 ('YWN', 'B', '1717')
# LIGAND ATOMS NOT FOUND
# 1now.bio1 ('IFG', 'B', '558')
# LIGAND ATOMS NOT FOUND
# 2chn.bio1 ('NGT', 'B', '1717')
# LIGAND ATOMS NOT FOUND
# 4gvf.bio1 ('NAG', 'B', '402')
# LIGAND ATOMS NOT FOUND
# 4gvf.bio1 ('NDG', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 5g3r.bio1 ('89A', 'B', '1336')
# LIGAND ATOMS NOT FOUND
# 5g3r.bio1 ('NAG', 'B', '1335')
# LIGAND ATOMS NOT FOUND
# 4azi.bio1 ('OAN', 'B', '2040')
# LIGAND ATOMS NOT FOUND
# 3nvd.bio1 ('OAN', 'B', '646')
# LIGAND ATOMS NOT FOUND
# 1qmg.bio1 ('APX', 'C', '600')
# LIGAND ATOMS NOT FOUND
# 1qmg.bio1 ('APX', 'D', '600')
# LIGAND ATOMS NOT FOUND
# 1qmg.bio1 ('DMV', 'C', '620')
# LIGAND ATOMS NOT FOUND
# 1qmg.bio1 ('DMV', 'D', '620')
# LIGAND ATOMS NOT FOUND
# 3ulk.bio1 ('NDP', 'B', '492')
# LIGAND ATOMS NOT FOUND
# 4lzj.bio1 ('22H', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 2qjy.bio1 ('SMA', 'G', '1003')
# LIGAND ATOMS NOT FOUND
# 2qjy.bio1 ('SMA', 'J', '1004')
# LIGAND ATOMS NOT FOUND
# 2qjy.bio1 ('SMA', 'M', '1005')
# LIGAND ATOMS NOT FOUND
# 2qjy.bio1 ('SMA', 'P', '1006')
# LIGAND ATOMS NOT FOUND
# 2qjy.bio1 ('UQ2', 'G', '1103')
# LIGAND ATOMS NOT FOUND
# 2qjy.bio1 ('UQ2', 'J', '1104')
# LIGAND ATOMS NOT FOUND
# 2qjy.bio1 ('UQ2', 'M', '1105')
# LIGAND ATOMS NOT FOUND
# 2qjy.bio1 ('UQ2', 'P', '1106')
# LIGAND ATOMS NOT FOUND
# 2bw7.bio1 ('APC', 'C', '2200')
# LIGAND ATOMS NOT FOUND
# 2bw7.bio1 ('APC', 'D', '2200')
# LIGAND ATOMS NOT FOUND
# 1ybu.bio1 ('APC', 'D', '602')
# LIGAND ATOMS NOT FOUND
# 5nna.bio1 ('BZM', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 5nna.bio1 ('BZM', 'D', '301')
# LIGAND ATOMS NOT FOUND
# 5nns.bio1 ('AKR', 'B', '313')
# LIGAND ATOMS NOT FOUND
# 5nns.bio1 ('AKR', 'B', '314')
# LIGAND ATOMS NOT FOUND
# 5nns.bio1 ('AKR', 'B', '315')
# LIGAND ATOMS NOT FOUND
# 5exw.bio1 ('7DT', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 4ag5.bio1 ('ADP', 'B', '1589')
# LIGAND ATOMS NOT FOUND
# 5swi.bio1 ('BMA', 'C', '703')
# LIGAND ATOMS NOT FOUND
# 5swi.bio1 ('BMA', 'A', '708')
# LIGAND ATOMS NOT FOUND
# 1szo.bio1 ('CAX', 'D', '5004')
# LIGAND ATOMS NOT FOUND
# 1szo.bio1 ('CAX', 'E', '5005')
# LIGAND ATOMS NOT FOUND
# 1szo.bio1 ('CAX', 'F', '5006')
# LIGAND ATOMS NOT FOUND
# 1szo.bio1 ('CAX', 'G', '5007')
# LIGAND ATOMS NOT FOUND
# 1szo.bio1 ('CAX', 'H', '5008')
# LIGAND ATOMS NOT FOUND
# 1szo.bio1 ('CAX', 'I', '5009')
# LIGAND ATOMS NOT FOUND
# 1szo.bio1 ('CAX', 'J', '5010')
# LIGAND ATOMS NOT FOUND
# 1szo.bio1 ('CAX', 'K', '5011')
# LIGAND ATOMS NOT FOUND
# 1szo.bio1 ('CAX', 'L', '5012')
# LIGAND ATOMS NOT FOUND
# 3og9.bio1 ('MLT', 'B', '500')
# LIGAND ATOMS NOT FOUND
# 5mwk.bio1 ('RAM 8OQ GAL 8PK ARA RAM', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5mwk.bio1
# 6vjf.bio1 ('GCP', 'D', '701')
# LIGAND ATOMS NOT FOUND
# 6vjf.bio1 ('GCP', 'C', '701')
# LIGAND ATOMS NOT FOUND
# 6g14.bio1 ('G4P', 'A', '301')
# LIGAND ATOMS NOT FOUND
# 2gj8.bio1 ('ALF GDP', 'A', '601')
# LIGAND ATOMS NOT FOUND
# 2gj8.bio1 ('ALF GDP', 'B', '611')
# LIGAND ATOMS NOT FOUND
# 2gj8.bio1 ('ALF GDP', 'C', '621')
# LIGAND ATOMS NOT FOUND
# 2gj8.bio1 ('ALF GDP', 'D', '631')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2gj8.bio1
# 6ub1.bio1 ('BGC BGC', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 6ub1.bio1 ('BGC BGC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 6ub1.bio1 ('BGC BGC', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 6ub1.bio1 ('BGC', 'B', '301')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6ub1.bio1
# 1qxa.bio1 ('GLY GLY GLY', 'B', '245')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 1qxa.bio1
# 5c5t.bio1 ('AKG', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 6r3u.bio1 ('FRU FRU FRU FRU', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6r3u.bio1
# 2cdo.bio1 ('GAL AAL GAL AAL GAL AAL', 'H', '1')
# LIGAND ATOMS NOT FOUND
# 2cdo.bio1 ('GAL AAL GAL AAL GAL AAL', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 2cdo.bio1 ('GAL AAL GAL AAL GAL AAL', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 2cdo.bio1 ('GAL AAL GAL AAL GAL AAL', 'F', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2cdo.bio1
# 6exo.bio1 ('C3E', 'B', '303')
# LIGAND ATOMS NOT FOUND
# 6pku.bio1 ('M6P', 'B', '403')
# LIGAND ATOMS NOT FOUND
# 6pku.bio1 ('M6P', 'D', '402')
# LIGAND ATOMS NOT FOUND
# 6pku.bio1 ('NDG', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 6pku.bio1 ('NDG', 'B', '402')
# LIGAND ATOMS NOT FOUND
# 1oj8.bio1 ('DA  DC  DG  DA', 'B', '301')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 1oj8.bio1
# 3e7j.bio1 ('NAG GCU NAG GCD', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 3e7j.bio1 ('NAG GCU NAG GCD', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3e7j.bio1
# 2c3w.bio1 ('GLC GLC GLC', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 2c3w.bio1 ('GLC GLC GLC GLC', 'J', '1')
# LIGAND ATOMS NOT FOUND
# 2c3w.bio1 ('GLC GLC GLC GLC', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 2c3w.bio1 ('GLC GLC GLC GLC', 'L', '1')
# LIGAND ATOMS NOT FOUND
# 2c3w.bio1 ('GLC GLC GLC GLC', 'I', '1')
# LIGAND ATOMS NOT FOUND
# 2c3w.bio1 ('GLC GLC GLC GLC', 'M', '1')
# LIGAND ATOMS NOT FOUND
# 2c3w.bio1 ('GLC GLC GLC GLC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 2c3w.bio1 ('GLC GLC GLC GLC', 'K', '1')
# LIGAND ATOMS NOT FOUND
# 2c3w.bio1 ('GLC GLC GLC GLC', 'H', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2c3w.bio1
# 4qpw.bio1 ('XYP XYP XYP', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4qpw.bio1
# 1uyy.bio1 ('BGC BGC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 1uyy.bio1 ('BGC BGC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 1uyy.bio1 ('BGC BGC BGC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 1uyy.bio1
# 4fdu.bio1 ('IHS', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 2wvz.bio1 ('KIF', 'B', '801')
# LIGAND ATOMS NOT FOUND
# 2wvz.bio1 ('KIF', 'C', '801')
# LIGAND ATOMS NOT FOUND
# 2wvz.bio1 ('KIF', 'D', '801')
# LIGAND ATOMS NOT FOUND
# 4g9e.bio1 ('C4L', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 1uoz.bio1 ('SSG SGC SSG GLC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 1uoz.bio1
# 5gln.bio1 ('XYP XYP XYP', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 5gln.bio1 ('XYP XYP XYP', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 5gln.bio1 ('XYP XYP', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 5gln.bio1 ('XYP XYP', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 5gln.bio1 ('XYS', 'B', '500')
# LIGAND ATOMS NOT FOUND
# 6p2l.bio1 ('GLC BGC BGC XYS BGC XYS XYS GAL', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6p2l.bio1
# 6r5r.bio1 ('BGC BGC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 6r5r.bio1 ('BGC BGC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6r5r.bio1
# 1pu7.bio1 ('39A', 'B', '220')
# LIGAND ATOMS NOT FOUND
# 5fpe.bio1 ('3TR', 'B', '1386')
# LIGAND ATOMS NOT FOUND
# 5fpe.bio1 ('3TR', 'B', '1385')
# LIGAND ATOMS NOT FOUND
# 7jwf.bio1 ('GAL GLA', 'H', '1')
# LIGAND ATOMS NOT FOUND
# 7jwf.bio1 ('GAL GLA', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 7jwf.bio1 ('GAL GLA', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 7jwf.bio1 ('GAL GLA', 'E', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 7jwf.bio1
# 6n9r.bio1 ('OHN', 'A', '303')
# LIGAND ATOMS NOT FOUND
# 3zvs.bio1 ('MLI', 'B', '1163')
# LIGAND ATOMS NOT FOUND
# 3zvs.bio1 ('MLI', 'C', '1161')
# LIGAND ATOMS NOT FOUND
# 1w1a.bio1 ('NDG', '2', '1261')
# LIGAND ATOMS NOT FOUND
# 4uap.bio1 ('NGA', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 3ebl.bio1 ('GA4', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 3ebl.bio1 ('GA4', 'C', '401')
# LIGAND ATOMS NOT FOUND
# 3ebl.bio1 ('GA4', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 3ebl.bio1 ('GA4', 'E', '401')
# LIGAND ATOMS NOT FOUND
# 3ebl.bio1 ('GA4', 'F', '401')
# LIGAND ATOMS NOT FOUND
# 3fe1.bio1 ('ADP MG', 'A', '386')
# LIGAND ATOMS NOT FOUND
# 3fe1.bio1 ('ADP MG', 'B', '386')
# LIGAND ATOMS NOT FOUND
# 3fe1.bio1 ('ADP MG', 'C', '386')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3fe1.bio1
# 4mln.bio1 ('ODV', 'B', '203')
# LIGAND ATOMS NOT FOUND
# 3f5o.bio1 ('UOC COA', 'A', '149')
# LIGAND ATOMS NOT FOUND
# 3f5o.bio1 ('UOC COA', 'B', '149')
# LIGAND ATOMS NOT FOUND
# 3f5o.bio1 ('UOC COA', 'C', '149')
# LIGAND ATOMS NOT FOUND
# 3f5o.bio1 ('UOC COA', 'D', '149')
# LIGAND ATOMS NOT FOUND
# 3f5o.bio1 ('UOC COA', 'E', '149')
# LIGAND ATOMS NOT FOUND
# 3f5o.bio1 ('UOC COA', 'F', '149')
# LIGAND ATOMS NOT FOUND
# 3f5o.bio1 ('UOC COA', 'G', '149')
# LIGAND ATOMS NOT FOUND
# 3f5o.bio1 ('UOC COA', 'H', '149')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3f5o.bio1
# 4wuj.bio1 ('FMN', 'B', '5201')
# LIGAND ATOMS NOT FOUND
# 4wuj.bio1 ('FMN', 'D', '5201')
# LIGAND ATOMS NOT FOUND
# 6g1p.bio1 ('CIT', 'B', '402')
# LIGAND ATOMS NOT FOUND
# 6bqk.bio1 ('Z1E', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 6hf4.bio1 ('BMA BMA BMA BMA GLA', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6hf4.bio1
# 3ec1.bio1 ('GDP', 'B', '900')
# LIGAND ATOMS NOT FOUND
# 5ao7.bio1 ('AH0 NAG', 'A', '1422')
# LIGAND ATOMS NOT FOUND
# 4kfu.bio1 ('ACP', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 4kfu.bio1 ('ACP', 'B', '302')
# LIGAND ATOMS NOT FOUND
# 4kfu.bio1 ('ACP', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 4kfu.bio1 ('ACP', 'D', '301')
# LIGAND ATOMS NOT FOUND
# 6ll8.bio1 ('2PN', 'B', '406')
# LIGAND ATOMS NOT FOUND
# 6ll8.bio1 ('F', 'B', '410')
# LIGAND ATOMS NOT FOUND
# 4zl4.bio1 ('4PK', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 6aek.bio1 ('A   G  ', 'A', '1007')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6aek.bio1
# 6uar.bio1 ('BGC BGC BGC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6uar.bio1
# 1uy4.bio1 ('XYP XYP XYP XYP', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 1uy4.bio1
# 4di8.bio1 ('0GY', 'B', '405')
# LIGAND ATOMS NOT FOUND
# 4di8.bio1 ('0GZ', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 3i7v.bio1 ('ATP', 'B', '135')
# LIGAND ATOMS NOT FOUND
# 3a23.bio1 ('GAL', 'B', '851')
# LIGAND ATOMS NOT FOUND
# 3a23.bio1 ('GAL', 'B', '881')
# LIGAND ATOMS NOT FOUND
# 2cdp.bio1 ('GAL AAL GAL AAL GAL AAL', 'H', '1')
# LIGAND ATOMS NOT FOUND
# 2cdp.bio1 ('GAL AAL GAL AAL GAL AAL', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 2cdp.bio1 ('GAL AAL GAL AAL GAL AAL', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 2cdp.bio1 ('GAL AAL GAL AAL GAL AAL', 'F', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2cdp.bio1
# 4mpo.bio1 ('AMP', 'E', '204')
# LIGAND ATOMS NOT FOUND
# 4mpo.bio1 ('AMP', 'C', '204')
# LIGAND ATOMS NOT FOUND
# 4mpo.bio1 ('AMP', 'F', '201')
# LIGAND ATOMS NOT FOUND
# 4mpo.bio1 ('AMP', 'D', '202')
# LIGAND ATOMS NOT FOUND
# 4mpo.bio1 ('AMP', 'H', '201')
# LIGAND ATOMS NOT FOUND
# 4mpo.bio1 ('AMP', 'G', '201')
# LIGAND ATOMS NOT FOUND
# 4mpo.bio1 ('AMP', 'B', '202')
# LIGAND ATOMS NOT FOUND
# 5zmy.bio1 ('TAR', 'H', '401')
# LIGAND ATOMS NOT FOUND
# 5zmy.bio1 ('TAR', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 5zmy.bio1 ('TAR', 'F', '401')
# LIGAND ATOMS NOT FOUND
# 5zmy.bio1 ('TAR', 'E', '401')
# LIGAND ATOMS NOT FOUND
# 5zmy.bio1 ('TAR', 'G', '401')
# LIGAND ATOMS NOT FOUND
# 5zmy.bio1 ('TAR', 'C', '401')
# LIGAND ATOMS NOT FOUND
# 6gxv.bio1 ('GLC GLC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 6gxv.bio1 ('GLC GLC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 6gxv.bio1 ('BGC', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 6gxv.bio1 ('BGC', 'B', '505')
# LIGAND ATOMS NOT FOUND
# 6gxv.bio1 ('GLC', 'B', '512')
# LIGAND ATOMS NOT FOUND
# 6gxv.bio1 ('GLC', 'B', '504')
# LIGAND ATOMS NOT FOUND
# 6gxv.bio1 ('GLC AC1 GLC AC1', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 6gxv.bio1 ('GLC AC1 GLC AC1', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 5l44.bio1 ('K26', 'B', '1005')
# LIGAND ATOMS NOT FOUND
# 6orh.bio1 ('NDG FUC GAL FUC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 6orh.bio1 ('NDG FUC GAL FUC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6orh.bio1
# 5a7v.bio1 ('BMA', 'B', '1385')
# LIGAND ATOMS NOT FOUND
# 5a7v.bio1 ('MAN', 'B', '1485')
# LIGAND ATOMS NOT FOUND
# 5a7v.bio1 ('MAN', 'B', '1386')
# LIGAND ATOMS NOT FOUND
# 6g1i.bio1 ('BGC BGC BGC BGC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 6g1i.bio1 ('BGC BGC BGC BGC', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 6g1i.bio1 ('FRU BGC BGC BGC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 6g1i.bio1 ('FRU BGC BGC BGC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6g1i.bio1
# 6fyz.bio1 ('EBE', 'C', '2001')
# LIGAND ATOMS NOT FOUND
# 6fyz.bio1 ('EBE', 'B', '2001')
# LIGAND ATOMS NOT FOUND
# 2xcm.bio1 ('ADP', 'B', '1211')
# LIGAND ATOMS NOT FOUND
# 5ofl.bio1 ('BGC BGC BGC BGC BGC BGC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5ofl.bio1
# 2oua.bio1 ('AES', 'B', '9002')
# LIGAND ATOMS NOT FOUND
# 6k0p.bio1 ('GLC GLC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# 6k0p.bio1 ('GLC GLC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 6k0p.bio1 ('GLC GLC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6k0p.bio1
# 4kpm.bio1 ('NAG NAG NAG', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 4kpm.bio1 ('BEN', 'B', '701')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4kpm.bio1
# 1zy7.bio1 ('IHP', 'B', '902')
# LIGAND ATOMS NOT FOUND
# 2j1e.bio1 ('NDG GAL', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2j1e.bio1
# 2qs8.bio1 ('MET', 'B', '700')
# LIGAND ATOMS NOT FOUND
# 2qyk.bio1 ('NPV', 'B', '3')
# LIGAND ATOMS NOT FOUND
# 4njs.bio1 ('G08', 'D', '500')
# LIGAND ATOMS NOT FOUND
# 6p2o.bio1 ('BGC BGC BGC XYS BGC XYS XYS GAL GAL', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 6p2o.bio1 ('BGC BGC BGC XYS BGC XYS XYS GAL GAL', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 6p2o.bio1 ('BGC BGC BGC XYS BGC XYS XYS', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 6p2o.bio1 ('BGC BGC BGC XYS BGC XYS XYS', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6p2o.bio1
# 6o5x.bio1 ('0Q4', 'D', '101')
# LIGAND ATOMS NOT FOUND
# 6kqs.bio1 ('NAG GAL', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6kqs.bio1
# 5nbp.bio1 ('BGC BGC BGC BGC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 5nbp.bio1 ('BGC BGC BGC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5nbp.bio1
# 4nzf.bio1 ('ARB', 'F', '502')
# LIGAND ATOMS NOT FOUND
# 4nzf.bio1 ('ARB', 'G', '502')
# LIGAND ATOMS NOT FOUND
# 4nzf.bio1 ('ARB', 'E', '505')
# LIGAND ATOMS NOT FOUND
# 4nzf.bio1 ('ARB', 'H', '503')
# LIGAND ATOMS NOT FOUND
# 4p3h.bio1 ('25G', 'B', '205')
# LIGAND ATOMS NOT FOUND
# 4p3h.bio1 ('25G', 'B', '204')
# LIGAND ATOMS NOT FOUND
# 1ynh.bio1 ('SUO', 'B', '1002')
# LIGAND ATOMS NOT FOUND
# 1ynh.bio1 ('SUO', 'C', '1003')
# LIGAND ATOMS NOT FOUND
# 2oz5.bio1 ('7XY', 'B', '277')
# LIGAND ATOMS NOT FOUND
# 2oz5.bio1 ('7XY', 'B', '278')
# LIGAND ATOMS NOT FOUND
# 6tcw.bio1 ('NAG BMA MAN MAN MAN MAN', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6tcw.bio1
# 6mgl.bio1 ('BGC BGC BGC XYS BGC XYS XYS GAL', 'B', '1')
# LIGAND ATOMS NOT FOUND
# 6mgl.bio1 ('BGC BGC XYS BGC XYS BGC GAL XYS BGC BGC XYS', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6mgl.bio1
# 4mlm.bio1 ('TLA', 'B', '204')
# LIGAND ATOMS NOT FOUND
# 4jym.bio1 ('KKN', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 2vzr.bio1 ('GCU', 'B', '1129')
# LIGAND ATOMS NOT FOUND
# 3k4z.bio1 ('XGP', 'B', '3')
# LIGAND ATOMS NOT FOUND
# 3k4z.bio1 ('BGC XGP', 'B', '2')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3k4z.bio1
# 2efx.bio1 ('NFA', 'B', '2002')
# LIGAND ATOMS NOT FOUND
# 2efx.bio1 ('NFA', 'C', '2003')
# LIGAND ATOMS NOT FOUND
# 2efx.bio1 ('NFA', 'D', '2004')
# LIGAND ATOMS NOT FOUND
# 2efx.bio1 ('NFA', 'E', '2005')
# LIGAND ATOMS NOT FOUND
# 2efx.bio1 ('NFA', 'F', '2006')
# LIGAND ATOMS NOT FOUND
# 6cgz.bio1 ('HL6', 'C', '304')
# LIGAND ATOMS NOT FOUND
# 3v0h.bio1 ('I3P', 'B', '3')
# LIGAND ATOMS NOT FOUND
# 3v0h.bio1 ('I3P', 'B', '4')
# LIGAND ATOMS NOT FOUND
# 6pki.bio1 ('M6P', 'D', '404')
# LIGAND ATOMS NOT FOUND
# 6pki.bio1 ('M6P', 'C', '404')
# LIGAND ATOMS NOT FOUND
# 6pki.bio1 ('NDG', 'C', '403')
# LIGAND ATOMS NOT FOUND
# 6pki.bio1 ('NDG', 'D', '403')
# LIGAND ATOMS NOT FOUND
# 5i0f.bio1 ('GLC GLC', 'A', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5i0f.bio1
# 2zey.bio1 ('BMA BMA BMA BMA BMA', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 2zey.bio1 ('MAN BMA BMA BMA BMA', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2zey.bio1
# 6kj0.bio1 ('XYP', 'B', '920')
# LIGAND ATOMS NOT FOUND
# 6kj0.bio1 ('BKR', 'B', '919')
# LIGAND ATOMS NOT FOUND
# 6ub6.bio1 ('BGC BGC BGC BGC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# 6ub6.bio1 ('BGC BGC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6ub6.bio1
# 2c3h.bio1 ('GLC GLC', 'J', '1')
# LIGAND ATOMS NOT FOUND
# 2c3h.bio1 ('GLC GLC', 'P', '1')
# LIGAND ATOMS NOT FOUND
# 2c3h.bio1 ('GLC GLC', 'M', '1')
# LIGAND ATOMS NOT FOUND
# 2c3h.bio1 ('GLC GLC', 'I', '1')
# LIGAND ATOMS NOT FOUND
# 2c3h.bio1 ('GLC GLC', 'N', '1')
# LIGAND ATOMS NOT FOUND
# 2c3h.bio1 ('GLC GLC', 'O', '1')
# LIGAND ATOMS NOT FOUND
# 2c3h.bio1 ('GLC GLC', 'L', '1')
# LIGAND ATOMS NOT FOUND
# 2c3h.bio1 ('GLC GLC', 'K', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2c3h.bio1
# 3mkk.bio1 ('GLC BGC', 'A', '801')
# LIGAND ATOMS NOT FOUND
# 3mkk.bio1 ('BGC GLC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3mkk.bio1
# 6mds.bio1 ('NAG BMA MAN MAN NAG GAL NAG GAL', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 6mds.bio1 ('NAG BMA MAN MAN NAG GAL NAG GAL', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6mds.bio1
# 4rlq.bio1 ('3SK', 'B', '1000')
# LIGAND ATOMS NOT FOUND
# 2far.bio1 ('DTP', 'B', '1302')
# LIGAND ATOMS NOT FOUND
# 2x05.bio1 ('X05', 'B', '1900')
# LIGAND ATOMS NOT FOUND
# 3pf7.bio1 ('MLA', 'B', '1004')
# LIGAND ATOMS NOT FOUND
# 1vj7.bio1 ('GDP', 'B', '1998')
# LIGAND ATOMS NOT FOUND
# 1vj7.bio1 ('GPX', 'B', '1999')
# LIGAND ATOMS NOT FOUND
# 4bqs.bio1 ('ADP', 'C', '1171')
# LIGAND ATOMS NOT FOUND
# 4bqs.bio1 ('ADP', 'B', '1171')
# LIGAND ATOMS NOT FOUND
# 4bqs.bio1 ('K2Q', 'B', '1172')
# LIGAND ATOMS NOT FOUND
# 4bqs.bio1 ('K2Q', 'C', '1172')
# LIGAND ATOMS NOT FOUND
# 1l7n.bio1 ('AF3', 'B', '719')
# LIGAND ATOMS NOT FOUND
# 1l7n.bio1 ('ALF', 'B', '720')
# LIGAND ATOMS NOT FOUND
# 1l7p.bio1 ('SEP', 'B', '270')
# LIGAND ATOMS NOT FOUND
# 4ap9.bio1 ('1PS', 'C', '201')
# LIGAND ATOMS NOT FOUND
# 4ap9.bio1 ('1PS', 'C', '202')
# LIGAND ATOMS NOT FOUND
# 4ap9.bio1 ('1PS', 'D', '202')
# LIGAND ATOMS NOT FOUND
# 2vk4.bio1 ('TPP', 'C', '600')
# LIGAND ATOMS NOT FOUND
# 2vk4.bio1 ('TPP', 'D', '600')
# LIGAND ATOMS NOT FOUND
# 2dwu.bio1 ('DGL', 'C', '278')
# LIGAND ATOMS NOT FOUND
# 1zuw.bio1 ('DGL', 'B', '2301')
# LIGAND ATOMS NOT FOUND
# 2gzm.bio1 ('DGL', 'C', '503')
# LIGAND ATOMS NOT FOUND
# 2gzm.bio1 ('DGL', 'D', '504')
# LIGAND ATOMS NOT FOUND
# 4a69.bio1 ('I0P', 'D', '501')
# LIGAND ATOMS NOT FOUND
# 1w22.bio1 ('NHB', 'B', '1378')
# LIGAND ATOMS NOT FOUND
# 6xdm.bio1 ('V1D', 'C', '410')
# LIGAND ATOMS NOT FOUND
# 6xdm.bio1 ('V1D', 'B', '408')
# LIGAND ATOMS NOT FOUND
# 5tvf.bio1 ('PUT', 'E', '401')
# LIGAND ATOMS NOT FOUND
# 5tvf.bio1 ('PUT', 'D', '403')
# LIGAND ATOMS NOT FOUND
# 5tvf.bio1 ('CGQ', 'D', '402')
# LIGAND ATOMS NOT FOUND
# 4qxb.bio1 ('OGA', 'C', '600')
# LIGAND ATOMS NOT FOUND
# 3pur.bio1 ('2HG', 'C', '1000')
# LIGAND ATOMS NOT FOUND
# 1v97.bio1 ('20161_20162_20163_20164_ FYX', 'A', '3004')
# LIGAND ATOMS NOT FOUND
# 1v97.bio1 ('20298_20299_20300_20301_ FYX', 'B', '4004')
# LIGAND ATOMS NOT FOUND
# 5th5.bio1 ('MET', 'C', '303')
# LIGAND ATOMS NOT FOUND
# 5th5.bio1 ('MET', 'B', '303')
# LIGAND ATOMS NOT FOUND
# 5th5.bio1 ('7C5', 'B', '302')
# LIGAND ATOMS NOT FOUND
# 5th5.bio1 ('7C5', 'C', '302')
# LIGAND ATOMS NOT FOUND
# 6uiq.bio1 ('G6P', 'A', '601')
# LIGAND ATOMS NOT FOUND
# 2i7c.bio1 ('AAT', 'B', '802')
# LIGAND ATOMS NOT FOUND
# 2i7c.bio1 ('AAT', 'C', '803')
# LIGAND ATOMS NOT FOUND
# 6o65.bio1 ('S4M', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 6o65.bio1 ('S4M', 'E', '401')
# LIGAND ATOMS NOT FOUND
# ...
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4mby.bio1
# 4r9f.bio1 ('BMA BMA', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4r9f.bio1
# 6l1q.bio1 ('ADP', 'A', '301')
# LIGAND ATOMS NOT FOUND
# 6l1q.bio1 ('ADP', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 3dy0.bio1 ('IDS SGN IDS SGN IDS', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3dy0.bio1
# 4odv.bio1 ('GP1 Z9M', 'A', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4odv.bio1
# 5vom.bio1 ('9GY', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 2zhp.bio1 ('BY6 CU', 'A', '301')
# LIGAND ATOMS NOT FOUND
# 2zhp.bio1 ('BY6 CU', 'B', '401')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2zhp.bio1
# 6h9y.bio1 ('NAG GAL', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6h9y.bio1
# 5vmc.bio1 ('NAG GAL SIA', 'J', '1')
# LIGAND ATOMS NOT FOUND
# 5vmc.bio1 ('NAG GAL SIA', 'H', '1')
# LIGAND ATOMS NOT FOUND
# 5vmc.bio1 ('NAG GAL SIA', 'L', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5vmc.bio1
# 1pk8.bio1 ('ATP', 'E', '804')
# LIGAND ATOMS NOT FOUND
# 1pk8.bio1 ('ATP', 'F', '805')
# LIGAND ATOMS NOT FOUND
# 1pk8.bio1 ('ATP', 'G', '806')
# LIGAND ATOMS NOT FOUND
# 1pk8.bio1 ('ATP', 'H', '807')
# LIGAND ATOMS NOT FOUND
# 4rsz.bio1 ('CPT', 'F', '203')
# LIGAND ATOMS NOT FOUND
# 4rsz.bio1 ('CPT', 'D', '202')
# LIGAND ATOMS NOT FOUND
# 4rsz.bio1 ('CPT', 'B', '203')
# LIGAND ATOMS NOT FOUND
# 5iqt.bio1 ('6CU', 'B', '304')
# LIGAND ATOMS NOT FOUND
# 5iqt.bio1 ('AKG', 'B', '303')
# LIGAND ATOMS NOT FOUND
# 5iqt.bio1 ('AKG', 'C', '303')
# LIGAND ATOMS NOT FOUND
# 5f7r.bio1 ('GLC GLC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 5f7r.bio1 ('GLC GLC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5f7r.bio1
# 4z7x.bio1 ('3CX', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 5yri.bio1 ('GLC GLC', 'A', '201')
# LIGAND ATOMS NOT FOUND
# 5yri.bio1 ('GLC GLC', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5yri.bio1
# 1bwo.bio1 ('LPC', 'B', '91')
# LIGAND ATOMS NOT FOUND
# 1bwo.bio1 ('LPC', 'B', '92')
# LIGAND ATOMS NOT FOUND
# 3qxv.bio1 ('MTX', 'B', '2000')
# LIGAND ATOMS NOT FOUND
# 3qxv.bio1 ('MTX', 'C', '2000')
# LIGAND ATOMS NOT FOUND
# 3qxv.bio1 ('MTX', 'D', '2000')
# LIGAND ATOMS NOT FOUND
# 3qxv.bio1 ('MTX', 'E', '2000')
# LIGAND ATOMS NOT FOUND
# 4bqo.bio1 ('COA', 'B', '1312')
# LIGAND ATOMS NOT FOUND
# 6is5.bio1 ('GLC GAL FUC A2G', 'H', '1')
# LIGAND ATOMS NOT FOUND
# 6is5.bio1 ('GLC GAL FUC A2G', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 6is5.bio1 ('GLC GAL FUC A2G', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 6is5.bio1 ('GLC GAL FUC A2G', 'F', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6is5.bio1
# 2f2g.bio1 ('HMH', 'B', '1301')
# LIGAND ATOMS NOT FOUND
# 4p25.bio1 ('NAG FUC GAL FUC', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 4p25.bio1 ('NAG FUC GAL FUC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 4p25.bio1 ('NAG FUC GAL FUC', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 4p25.bio1 ('NAG FUC GAL FUC', 'H', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4p25.bio1
# 1ocu.bio1 ('PIB', 'B', '1164')
# LIGAND ATOMS NOT FOUND
# 3rlb.bio1 ('VIB', 'B', '187')
# LIGAND ATOMS NOT FOUND
# 4gc1.bio1 ('MAN MAN', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 4gc1.bio1 ('MAN MAN', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4gc1.bio1
# 6rs9.bio1 ('XYP XYP XYP XYP', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6rs9.bio1
# 6f9g.bio1 ('PUT', 'C', '401')
# LIGAND ATOMS NOT FOUND
# 6f9g.bio1 ('PUT', 'E', '401')
# LIGAND ATOMS NOT FOUND
# 6f9g.bio1 ('PUT', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 6f9g.bio1 ('PUT', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 3jqm.bio1 ('GTP', 'C', '158')
# LIGAND ATOMS NOT FOUND
# 3jqm.bio1 ('GTP', 'D', '158')
# LIGAND ATOMS NOT FOUND
# 3jqm.bio1 ('GTP', 'F', '158')
# LIGAND ATOMS NOT FOUND
# 3jqm.bio1 ('GTP', 'G', '158')
# LIGAND ATOMS NOT FOUND
# 3jqm.bio1 ('GTP', 'H', '158')
# LIGAND ATOMS NOT FOUND
# 3jqm.bio1 ('GTP', 'I', '158')
# LIGAND ATOMS NOT FOUND
# 5dyo.bio1 ('FLU', 'H', '901')
# LIGAND ATOMS NOT FOUND
# 5fpn.bio1 ('KYD', 'B', '1385')
# LIGAND ATOMS NOT FOUND
# 5fpn.bio1 ('KYD', 'B', '1386')
# LIGAND ATOMS NOT FOUND
# 6ea9.bio1 ('9BG', 'E', '301')
# LIGAND ATOMS NOT FOUND
# 6ea9.bio1 ('9BG', 'D', '301')
# LIGAND ATOMS NOT FOUND
# 6ea9.bio1 ('9BG', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 4xiz.bio1 ('LPP', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 3v0w.bio1 ('KDO KDO GM0 GM0 GLC GMH GLC GLA GLC PA1', 'A', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3v0w.bio1
# 4yhb.bio1 ('FAD', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 5h1w.bio1 ('LER', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 4gcs.bio1 ('1RG', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 5lv1.bio1 ('78T', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 5lv1.bio1 ('78T', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 5j75.bio1 ('6GQ', 'B', '303')
# LIGAND ATOMS NOT FOUND
# 5mdr.bio1 ('NAG NAG NAG NAG NAG NAG', 'L', '1')
# LIGAND ATOMS NOT FOUND
# 5mdr.bio1 ('NAG NAG NAG NAG NAG NAG', 'I', '1')
# LIGAND ATOMS NOT FOUND
# 5mdr.bio1 ('NAG NAG NAG NAG NAG NAG', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 5mdr.bio1 ('NAG NAG NAG NAG NAG NAG', 'K', '1')
# LIGAND ATOMS NOT FOUND
# 5mdr.bio1 ('NAG NAG NAG NAG NAG NAG', 'J', '1')
# LIGAND ATOMS NOT FOUND
# 5mdr.bio1 ('NAG NAG NAG NAG NAG NAG', 'H', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5mdr.bio1
# 2vyt.bio1 ('MLZ', 'B', '1244')
# LIGAND ATOMS NOT FOUND
# 4omj.bio1 ('2TX', 'B', '308')
# LIGAND ATOMS NOT FOUND
# 6ff8.bio1 ('GTP', 'B', '900')
# LIGAND ATOMS NOT FOUND
# 6ipw.bio1 ('AO6', 'C', '300')
# LIGAND ATOMS NOT FOUND
# 6ipw.bio1 ('AO6', 'D', '300')
# LIGAND ATOMS NOT FOUND
# 4e03.bio1 ('ADP', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 6i20.bio1 ('FMN', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 6i20.bio1 ('FMN', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 6i20.bio1 ('FMN', 'C', '401')
# LIGAND ATOMS NOT FOUND
# 5h5a.bio1 ('6OU', 'D', '301')
# LIGAND ATOMS NOT FOUND
# 5h5a.bio1 ('6OU', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 5h5a.bio1 ('6OU', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 1yre.bio1 ('COA', 'C', '603')
# LIGAND ATOMS NOT FOUND
# 1yre.bio1 ('COA', 'D', '604')
# LIGAND ATOMS NOT FOUND
# 3rsc.bio1 ('C0T', 'B', '398')
# LIGAND ATOMS NOT FOUND
# 3rsc.bio1 ('TYD', 'B', '397')
# LIGAND ATOMS NOT FOUND
# 3r5y.bio1 ('F42', 'B', '147')
# LIGAND ATOMS NOT FOUND
# 3r5y.bio1 ('F42', 'C', '147')
# LIGAND ATOMS NOT FOUND
# 3r5y.bio1 ('F42', 'D', '147')
# LIGAND ATOMS NOT FOUND
# 5ixb.bio1 ('LGA', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 3qmk.bio1 ('SGN IDS SGN IDS', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3qmk.bio1
# 5t0b.bio1 ('NAG GAL SIA', 'G', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5t0b.bio1
# 2r09.bio1 ('4IP', 'B', '400')
# LIGAND ATOMS NOT FOUND
# 2gvc.bio1 ('FAD', 'D', '500')
# LIGAND ATOMS NOT FOUND
# 2gvc.bio1 ('FAD', 'E', '500')
# LIGAND ATOMS NOT FOUND
# 2gvc.bio1 ('MMZ', 'D', '501')
# LIGAND ATOMS NOT FOUND
# 2gvc.bio1 ('MMZ', 'E', '501')
# LIGAND ATOMS NOT FOUND
# 5f7v.bio1 ('GLC GLC GLC GLC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5f7v.bio1
# 4zh7.bio1 ('GAL NAG GAL FUC FUC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4zh7.bio1
# 4ojp.bio1 ('GLC GLC', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 4ojp.bio1 ('GLC GLC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 4ojp.bio1 ('GLC GLC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4ojp.bio1
# 4p6a.bio1 ('MAN MAN MAN', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 4p6a.bio1 ('MAN MAN MAN', 'B', '1')
# LIGAND ATOMS NOT FOUND
# 4p6a.bio1 ('MAN MAN MAN', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4p6a.bio1
# 4r0m.bio1 ('FA5', 'A', '701')
# LIGAND ATOMS NOT FOUND
# 5ufc.bio1 ('NAG GAL FUC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 5ufc.bio1 ('NAG GAL FUC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 5ufc.bio1 ('NAG GAL FUC', 'F', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5ufc.bio1
# 6tr4.bio1 ('FUC', 'B', '701')
# LIGAND ATOMS NOT FOUND
# 3h9a.bio1 ('PPY', 'B', '246')
# LIGAND ATOMS NOT FOUND
# 6w9r.bio1 ('FLC', 'W', '101')
# LIGAND ATOMS NOT FOUND
# 6w9r.bio1 ('FLC', 'T', '101')
# LIGAND ATOMS NOT FOUND
# 6w9r.bio1 ('FLC', 'X', '101')
# LIGAND ATOMS NOT FOUND
# 6w9r.bio1 ('FLC', 'R', '101')
# LIGAND ATOMS NOT FOUND
# 6w9r.bio1 ('FLC', 'N', '101')
# LIGAND ATOMS NOT FOUND
# 6w9r.bio1 ('FLC', 'P', '101')
# LIGAND ATOMS NOT FOUND
# 6w9r.bio1 ('FLC', 'O', '101')
# LIGAND ATOMS NOT FOUND
# 6w9r.bio1 ('FLC', 'Q', '101')
# LIGAND ATOMS NOT FOUND
# 6w9r.bio1 ('FLC', 'U', '101')
# LIGAND ATOMS NOT FOUND
# 6w9r.bio1 ('FLC', 'S', '101')
# LIGAND ATOMS NOT FOUND
# 6w9r.bio1 ('FLC', 'V', '101')
# LIGAND ATOMS NOT FOUND
# 6rqk.bio1 ('MVL', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 6rqk.bio1 ('MVL', 'B', '502')
# LIGAND ATOMS NOT FOUND
# 6g47.bio1 ('SIA SIA', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 6yud.bio1 ('A   A   A   A  ', 'M', '1')
# LIGAND ATOMS NOT FOUND
# 6yud.bio1 ('A   A   A   A  ', 'P', '1')
# LIGAND ATOMS NOT FOUND
# 6yud.bio1 ('A   A   A   A  ', 'O', '1')
# LIGAND ATOMS NOT FOUND
# 6yud.bio1 ('A   A   A   A  ', 'Q', '1')
# LIGAND ATOMS NOT FOUND
# 6yud.bio1 ('A   A   A   A  ', 'K', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6yud.bio1
# 5y0t.bio1 ('TAT', 'C', '1001')
# LIGAND ATOMS NOT FOUND
# 5y0t.bio1 ('TAT', 'D', '1001')
# LIGAND ATOMS NOT FOUND
# 5ahw.bio1 ('CMP', 'C', '1148')
# LIGAND ATOMS NOT FOUND
# 5ahw.bio1 ('CMP', 'D', '1148')
# LIGAND ATOMS NOT FOUND
# 5ahw.bio1 ('CMP', 'E', '1148')
# LIGAND ATOMS NOT FOUND
# 5ahw.bio1 ('CMP', 'F', '1148')
# LIGAND ATOMS NOT FOUND
# 3hgm.bio1 ('ATP', 'C', '148')
# LIGAND ATOMS NOT FOUND
# 3hgm.bio1 ('ATP', 'D', '148')
# LIGAND ATOMS NOT FOUND
# 4twl.bio1 ('ASC', 'B', '304')
# LIGAND ATOMS NOT FOUND
# 6uaw.bio1 ('BGC BGC BGC', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6uaw.bio1
# 2wr9.bio1 ('MAN MAN', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 2wr9.bio1 ('MAN MAN', 'E', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2wr9.bio1
# 5eb4.bio1 ('FAD', 'B', '610')
# LIGAND ATOMS NOT FOUND
# 3zqe.bio1 ('DXC', 'B', '1079')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3zqe.bio1
# 3hp8.bio1 ('GLC FRU', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 3hp8.bio1 ('GLC FRU', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 3hp8.bio1 ('GLC FRU', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 3hp8.bio1 ('GLC FRU', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3hp8.bio1
# 2rdk.bio1 ('MAN MAN', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 2rdk.bio1 ('MAN MAN', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2rdk.bio1
# 2mpr.bio1 ('BGC GLC GLC', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 2mpr.bio1 ('BGC GLC GLC', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 2mpr.bio1 ('BGC GLC GLC', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2mpr.bio1
# 5cs2.bio1 ('54C WLU ALA WPA VAL MLE WVL', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5cs2.bio1
# 5thz.bio1 ('SAH', 'A', '501')
# LIGAND ATOMS NOT FOUND
# 6czi.bio1 ('38E', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 4a3x.bio1 ('BGC GAL', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4a3x.bio1
# 6fpg.bio1 ('CIT', 'G', '301')
# LIGAND ATOMS NOT FOUND
# 6fpg.bio1 ('CIT', 'F', '301')
# LIGAND ATOMS NOT FOUND
# 3jwh.bio1 ('SAH', 'B', '1')
# LIGAND ATOMS NOT FOUND
# 6koj.bio1 ('I35', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 6cz7.bio1 ('MGD', 'C', '902')
# LIGAND ATOMS NOT FOUND
# 6cz7.bio1 ('MGD', 'C', '903')
# LIGAND ATOMS NOT FOUND
# 6hdu.bio1 ('GTP', 'C', '900')
# LIGAND ATOMS NOT FOUND
# 6hdu.bio1 ('GTP', 'B', '900')
# LIGAND ATOMS NOT FOUND
# 6hdu.bio1 ('GTP', 'D', '900')
# LIGAND ATOMS NOT FOUND
# 6peu.bio1 ('ATP', 'B', '500')
# LIGAND ATOMS NOT FOUND
# 6peu.bio1 ('ATP', 'D', '500')
# LIGAND ATOMS NOT FOUND
# 6peu.bio1 ('ATP', 'C', '500')
# LIGAND ATOMS NOT FOUND
# 4m44.bio1 ('GAL NAG GAL SIA', 'R', '1')
# LIGAND ATOMS NOT FOUND
# 4m44.bio1 ('GAL NAG GAL SIA', 'N', '1')
# LIGAND ATOMS NOT FOUND
# 4m44.bio1 ('GAL NAG GAL SIA', 'J', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4m44.bio1
# 3mtx.bio1 ('PGT', 'B', '300')
# LIGAND ATOMS NOT FOUND
# 5vlq.bio1 ('ANP', 'B', '601')
# LIGAND ATOMS NOT FOUND
# 5hca.bio1 ('BGC', 'A', '407')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5hca.bio1
# 3lsj.bio1 ('COA PLM', 'B', '222')
# LIGAND ATOMS NOT FOUND
# 3lsj.bio1 ('PLM COA', 'A', '221')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 3lsj.bio1
# 5x5m.bio1 ('7YU', 'B', '302')
# LIGAND ATOMS NOT FOUND
# 2hyq.bio1 ('MAN MAN', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 2hyq.bio1 ('MAN MAN', 'H', '1')
# LIGAND ATOMS NOT FOUND
# 2hyq.bio1 ('MAN MAN', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 2hyq.bio1 ('MAN MAN', 'G', '1')
# LIGAND ATOMS NOT FOUND
# 2hyq.bio1 ('MAN MAN', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 2hyq.bio1 ('MAN MAN', 'E', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2hyq.bio1
# 6xb4.bio1 ('9BG', 'D', '201')
# LIGAND ATOMS NOT FOUND
# 6xb4.bio1 ('9BG', 'C', '201')
# LIGAND ATOMS NOT FOUND
# 1oh2.bio1 ('GLC FRU', 'B', '1')
# LIGAND ATOMS NOT FOUND
# 1oh2.bio1 ('GLC FRU', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 1oh2.bio1 ('GLC FRU', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 1oh2.bio1 ('GLC FRU', 'D', '1')
# LIGAND ATOMS NOT FOUND
# 1oh2.bio1 ('GLC FRU', 'C', '1')
# LIGAND ATOMS NOT FOUND
# 1oh2.bio1 ('GLC FRU', 'A', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 1oh2.bio1
# 5vl2.bio1 ('9EG', 'E', '201')
# LIGAND ATOMS NOT FOUND
# 5vl2.bio1 ('9EG', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 5vl2.bio1 ('9EG', 'G', '201')
# LIGAND ATOMS NOT FOUND
# 5vl2.bio1 ('9EG', 'D', '201')
# LIGAND ATOMS NOT FOUND
# 4dw4.bio1 ('U5P', 'B', '1114')
# LIGAND ATOMS NOT FOUND
# 4dw4.bio1 ('U5P', 'B', '1115')
# LIGAND ATOMS NOT FOUND
# 6rzq.bio1 ('ANP', 'B', '502')
# LIGAND ATOMS NOT FOUND
# 4odt.bio1 ('GP1 Z9M', 'A', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 4odt.bio1
# 5ulj.bio1 ('0WD', 'B', '402')
# LIGAND ATOMS NOT FOUND
# 4i53.bio1 ('1C1', 'B', '501')
# LIGAND ATOMS NOT FOUND
# 5v8e.bio1 ('CIT', 'B', '401')
# LIGAND ATOMS NOT FOUND
# 2wn2.bio1 ('A2G GAL', 'A', '301')
# LIGAND ATOMS NOT FOUND
# 2wn2.bio1 ('A2G GAL', 'B', '301')
# LIGAND ATOMS NOT FOUND
# 2wn2.bio1 ('A2G GAL', 'C', '301')
# LIGAND ATOMS NOT FOUND
# 2wn2.bio1 ('NGA GAL', 'F', '1')
# LIGAND ATOMS NOT FOUND
# 2wn2.bio1 ('NGA GAL', 'E', '1')
# LIGAND ATOMS NOT FOUND
# 2wn2.bio1 ('NGA GAL', 'D', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2wn2.bio1
# 6haj.bio1 ('EVB', 'B', '101')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 6haj.bio1
# 6top.bio1 ('MLD', 'C', '701')
# LIGAND ATOMS NOT FOUND
# 6top.bio1 ('MLD', 'D', '701')
# LIGAND ATOMS NOT FOUND
# 6top.bio1 ('MLD', 'B', '701')
# LIGAND ATOMS NOT FOUND
# 2obt.bio1 ('GAL FUC GLA', 'B', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 2obt.bio1
# 5t2y.bio1 ('753', 'B', '201')
# LIGAND ATOMS NOT FOUND
# 5xnc.bio1 ('MTA', 'F', '401')
# LIGAND ATOMS NOT FOUND
# 5xnc.bio1 ('MTA', 'E', '401')
# LIGAND ATOMS NOT FOUND
# 5xnc.bio1 ('MTA', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 5xnc.bio1 ('MTA', 'C', '401')
# LIGAND ATOMS NOT FOUND
# 5xnc.bio1 ('MTA', 'G', '401')
# LIGAND ATOMS NOT FOUND
# 5xnc.bio1 ('N4P', 'E', '402')
# LIGAND ATOMS NOT FOUND
# 5xnc.bio1 ('N4P', 'C', '402')
# LIGAND ATOMS NOT FOUND
# 5xnc.bio1 ('N4P', 'G', '402')
# LIGAND ATOMS NOT FOUND
# 5xnc.bio1 ('N4P', 'D', '402')
# LIGAND ATOMS NOT FOUND
# 5xnc.bio1 ('N4P', 'F', '402')
# LIGAND ATOMS NOT FOUND
# 6j27.bio1 ('MTA', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 6j27.bio1 ('MTA', 'C', '402')
# LIGAND ATOMS NOT FOUND
# 6j27.bio1 ('N4P', 'C', '403')
# LIGAND ATOMS NOT FOUND
# 6j27.bio1 ('N4P', 'D', '402')
# LIGAND ATOMS NOT FOUND
# 4r5z.bio1 ('PMP', 'D', '402')
# LIGAND ATOMS NOT FOUND
# 4r5z.bio1 ('PMP', 'C', '402')
# LIGAND ATOMS NOT FOUND
# 4r5z.bio1 ('SIN', 'D', '401')
# LIGAND ATOMS NOT FOUND
# 4r5z.bio1 ('SIN', 'C', '401')
# LIGAND ATOMS NOT FOUND
# 5oca.bio1 ('TWD TWA', 'C', '1')
# LIGAND ATOMS NOT FOUND
# CAREFUL: NO INTERACTIONS AT ALL FOR 5oca.bio1
# 6n4n.bio1 ('TSV', 'B', '1202')
# LIGAND ATOMS NOT FOUND
# 5exk.bio1 ('5AD', 'G', '403')
# LIGAND ATOMS NOT FOUND
# 5exk.bio1 ('5AD', 'C', '403')
# LIGAND ATOMS NOT FOUND
# 5exk.bio1 ('5AD', 'K', '403')
# LIGAND ATOMS NOT FOUND
# 5exk.bio1 ('5AD', 'E', '403')
# LIGAND ATOMS NOT FOUND
# 5exk.bio1 ('5AD', 'I', '403')
# LIGAND ATOMS NOT FOUND
# 5exk.bio1 ('MET', 'C', '404')
# LIGAND ATOMS NOT FOUND
# 5exk.bio1 ('MET', 'G', '404')
# LIGAND ATOMS NOT FOUND
# 5exk.bio1 ('MET', 'K', '404')
# LIGAND ATOMS NOT FOUND
# 5exk.bio1 ('MET', 'E', '404')
# LIGAND ATOMS NOT FOUND
# 5exk.bio1 ('MET', 'I', '404')
# LIGAND ATOMS NOT FOUND
# 5j6d.bio1 ('6H5', 'B', '504')
# LIGAND ATOMS NOT FOUND

# %%
missing_lig_pdbs = MOAD_subset_data_df.query('n_ligs < 1').ID.unique().tolist()

# %%
for k in missing_lig_pdbs:
    print(k, MOAD_lig_tuples_dict[k])
# Out:
# 3njv [('GTR RAM GTR RAM GTR RAM', 'B', '1')]
# 5yjw [('SMA', 'A', '625'), ('SMA', 'A', '626'), ('FAD', 'A', '601')]
# 6o7b [('A   A   A   A  ', 'D', '1'), ('A   A   A   A  ', 'C', '1')]
# 6tug [('AF2 AF2 AF2 AF2 AF2 AF2', 'A', '502'), ('AF2 AF2 AF2 AF2 AF2 AF2', 'E', '502'), ('AF2 AF2 AF2 AF2 AF2 AF2', 'C', '502'), ('AF2 AF2 AF2 AF2 AF2 AF2', 'G', '502')]
# 6n6a [('G   G  ', 'D', '603')]
# 2djh [('3PD UM3', 'A', '117')]
# 6n6j [('A   A  ', 'C', '603'), ('A   A  ', 'D', '603')]
# 6w01 [('CIT', 'A', '412'), ('CIT', 'B', '408')]
# 6rcl [('A   A  ', 'C', '1')]
# 1brn [('DC  DG  DA  DC', 'A', '1'), ('DC  DG  DA  DC', 'B', '1')]
# 5aci [('BGC BGC BGC BGC BGC BGC', 'B', '1')]
# 5awv [('GHP 3MY 3FG GHP GHP OMY 3FG NAG MAN', 'I', '1'), ('GHP 3MY 3FG GHP GHP OMY 3FG NAG MAN', 'J', '1'), ('GHP 3MY 3FG GHP GHP OMY 3FG', 'M', '1'), ('GHP 3MY 3FG GHP GHP OMY 3FG', 'J', '1'), ('GHP 3MY 3FG GHP GHP OMY 3FG', 'L', '1'), ('GHP 3MY 3FG GHP GHP OMY 3FG', 'I', '1'), ('GHP 3MY 3FG GHP GHP OMY 3FG', 'N', '1'), ('GHP 3MY 3FG GHP GHP OMY 3FG', 'K', '1')]
# 6ydc [('BGC BGC BGC', 'G', '1'), ('BGC BGC BGC BGC', 'E', '1'), ('BGC BGC BGC BGC', 'F', '1')]
# 6yde [('BGC BGC BGC BGC BGC BGC', 'B', '1')]
# 1hmu [('ASG GCD', 'D', '1')]
# 1rwh [('ASG GCT ASG GAD', 'B', '1')]
# 1wu6 [('XYP XYP', 'B', '1')]
# 5myd [('DUP', 'C', '201'), ('DUP', 'A', '201'), ('DUP', 'B', '201'), ('DUP', 'D', '201')]
# 4dl8 [('UMP AF3 PO4', 'A', '301')]
# 3ilr [('SGN IXD', 'C', '1'), ('IXD SGN', 'B', '1')]
# 5e70 [('GLC GLC GLC GLC GLC GLC GLC GLC', 'F', '5'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'E', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'H', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'G', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'I', '1')]
# 5gqx [('GLC GLC GLC GLC GLC GLC GLC', 'G', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'B', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'E', '1'), ('GLC GLC GLC GLC', 'H', '1'), ('GLC GLC GLC GLC', 'C', '1'), ('GLC GLC GLC GLC', 'F', '1'), ('GLC GLC GLC', 'D', '1'), ('GLC GLC GLC', 'I', '1')]
# 3vu2 [('GLC GLC GLC GLC GLC', 'C', '1'), ('GLC GLC GLC GLC GLC', 'D', '1')]
# 3ngz [('DG  DC', 'C', '1'), ('DG  DC', 'D', '1')]
# 4pyh [('GLC GLC GLC GLC GLC GLC', 'B', '1')]
# 4rkk [('GLC GLC GLC GLC GLC GLC', 'E', '1'), ('GLC GLC GLC GLC GLC GLC', 'B', '1'), ('GLC GLC GLC GLC GLC GLC', 'F', '1')]
# 1ak0 [('ADS THS THS THS', 'A', '292')]
# 5zic [('BMA Z4Y NAG', 'C', '1'), ('BMA Z4Y NAG', 'D', '1')]
# 5mwk [('RAM 8OQ GAL 8PK ARA RAM', 'B', '1')]
# 2gj8 [('ALF GDP', 'A', '601'), ('ALF GDP', 'B', '611'), ('ALF GDP', 'C', '621'), ('ALF GDP', 'D', '631')]
# 6ub1 [('BGC BGC', 'G', '1'), ('BGC BGC', 'E', '1'), ('BGC BGC', 'F', '1'), ('BGC', 'B', '301')]
# 1qxa [('GLY GLY GLY', 'B', '245')]
# 6r3u [('FRU FRU FRU FRU', 'B', '1')]
# 2cdo [('GAL AAL GAL AAL GAL AAL', 'H', '1'), ('GAL AAL GAL AAL GAL AAL', 'E', '1'), ('GAL AAL GAL AAL GAL AAL', 'G', '1'), ('GAL AAL GAL AAL GAL AAL', 'F', '1')]
# 1oj8 [('DA  DC  DG  DA', 'B', '301')]
# 3e7j [('NAG GCU NAG GCD', 'C', '1'), ('NAG GCU NAG GCD', 'D', '1')]
# 2c3w [('GLC GLC GLC', 'G', '1'), ('GLC GLC GLC GLC', 'J', '1'), ('GLC GLC GLC GLC', 'F', '1'), ('GLC GLC GLC GLC', 'L', '1'), ('GLC GLC GLC GLC', 'I', '1'), ('GLC GLC GLC GLC', 'M', '1'), ('GLC GLC GLC GLC', 'E', '1'), ('GLC GLC GLC GLC', 'K', '1'), ('GLC GLC GLC GLC', 'H', '1')]
# 4qpw [('XYP XYP XYP', 'B', '1')]
# 1uyy [('BGC BGC', 'E', '1'), ('BGC BGC', 'D', '1'), ('BGC BGC BGC', 'C', '1')]
# 1uoz [('SSG SGC SSG GLC', 'B', '1')]
# 6p2l [('GLC BGC BGC XYS BGC XYS XYS GAL', 'B', '1')]
# 6r5r [('BGC BGC', 'C', '1'), ('BGC BGC', 'D', '1')]
# 7jwf [('GAL GLA', 'H', '1'), ('GAL GLA', 'G', '1'), ('GAL GLA', 'F', '1'), ('GAL GLA', 'E', '1')]
# 3fe1 [('ADP MG', 'A', '386'), ('ADP MG', 'B', '386'), ('ADP MG', 'C', '386')]
# 3f5o [('UOC COA', 'A', '149'), ('UOC COA', 'B', '149'), ('UOC COA', 'C', '149'), ('UOC COA', 'D', '149'), ('UOC COA', 'E', '149'), ('UOC COA', 'F', '149'), ('UOC COA', 'G', '149'), ('UOC COA', 'H', '149')]
# 6hf4 [('BMA BMA BMA BMA GLA', 'B', '1')]
# 6aek [('A   G  ', 'A', '1007')]
# 6uar [('BGC BGC BGC', 'B', '1')]
# 1uy4 [('XYP XYP XYP XYP', 'B', '1')]
# 2cdp [('GAL AAL GAL AAL GAL AAL', 'H', '1'), ('GAL AAL GAL AAL GAL AAL', 'E', '1'), ('GAL AAL GAL AAL GAL AAL', 'G', '1'), ('GAL AAL GAL AAL GAL AAL', 'F', '1')]
# 6orh [('NDG FUC GAL FUC', 'C', '1'), ('NDG FUC GAL FUC', 'D', '1')]
# 6g1i [('BGC BGC BGC BGC', 'D', '1'), ('BGC BGC BGC BGC', 'F', '1'), ('FRU BGC BGC BGC', 'E', '1'), ('FRU BGC BGC BGC', 'C', '1')]
# 5ofl [('BGC BGC BGC BGC BGC BGC', 'B', '1')]
# 6k0p [('GLC GLC', 'B', '1'), ('GLC GLC', 'D', '1'), ('GLC GLC', 'C', '1')]
# 4kpm [('NAG NAG NAG', 'E', '1'), ('BEN', 'B', '701')]
# 2j1e [('NDG GAL', 'B', '1')]
# 6p2o [('BGC BGC BGC XYS BGC XYS XYS GAL GAL', 'E', '1'), ('BGC BGC BGC XYS BGC XYS XYS GAL GAL', 'C', '1'), ('BGC BGC BGC XYS BGC XYS XYS', 'F', '1'), ('BGC BGC BGC XYS BGC XYS XYS', 'D', '1')]
# 6kqs [('NAG GAL', 'B', '1')]
# 5nbp [('BGC BGC BGC BGC', 'C', '1'), ('BGC BGC BGC', 'D', '1')]
# 6tcw [('NAG BMA MAN MAN MAN MAN', 'B', '1')]
# 6mgl [('BGC BGC BGC XYS BGC XYS XYS GAL', 'B', '1'), ('BGC BGC XYS BGC XYS BGC GAL XYS BGC BGC XYS', 'C', '1')]
# 3k4z [('XGP', 'B', '3'), ('BGC XGP', 'B', '2')]
# 5i0f [('GLC GLC', 'A', '1')]
# 2zey [('BMA BMA BMA BMA BMA', 'C', '1'), ('MAN BMA BMA BMA BMA', 'D', '1')]
# 6ub6 [('BGC BGC BGC BGC', 'B', '1'), ('BGC BGC', 'C', '1')]
# 2c3h [('GLC GLC', 'J', '1'), ('GLC GLC', 'P', '1'), ('GLC GLC', 'M', '1'), ('GLC GLC', 'I', '1'), ('GLC GLC', 'N', '1'), ('GLC GLC', 'O', '1'), ('GLC GLC', 'L', '1'), ('GLC GLC', 'K', '1')]
# 3mkk [('GLC BGC', 'A', '801'), ('BGC GLC', 'C', '1')]
# 6mds [('NAG BMA MAN MAN NAG GAL NAG GAL', 'C', '1'), ('NAG BMA MAN MAN NAG GAL NAG GAL', 'D', '1')]
# 5e4f [('ALF ADP', 'B', '701'), ('ALF ADP', 'A', '701')]
# 6bu0 [('IHP', 'C', '1702'), ('IHP', 'B', '1702'), ('IHP', 'C', '1701'), ('IHP', 'B', '1701')]
# 4u31 [('GPM GLC', 'D', '1'), ('GPM GLC', 'C', '1')]
# 5cgm [('GLC GLC', 'C', '1'), ('GLC GLC', 'D', '1')]
# 4a15 [('DT  DA  DC  DG', 'E', '1')]
# 2x8s [('AHR AHR AHR', 'D', '1'), ('AHR AHR AHR', 'C', '1')]
# 6a8h [('AHR AHR AHR', 'C', '1'), ('AHR AHR AHR', 'B', '1')]
# 1gye [('AHR AHR AHR AHR AHR AHR', 'A', '1')]
# 1qgi [('NAG GCS GCS', 'B', '1')]
# 4olt [('GCS GCS GCS GCS GCS GCS', 'D', '1'), ('GCS GCS GCS GCS GCS GCS', 'C', '1')]
# 2c0u [('FAD NBT', 'A', '1432'), ('FAD NBT', 'B', '1432'), ('FAD NBT', 'C', '1432'), ('FAD NBT', 'D', '1432')]
# 3hnt [('AXR BXY BXY BXX', 'A', '1')]
# 4hor [('CTP C   C   C   C  ', 'X', '1')]
# 1mfa [('MMA GLA ABE', 'A', '1')]
# 2ok0 [('DT  DC', 'D', '1')]
# 1s3k [('NDG FUC GAL FUC', 'A', '1')]
# 4tuo [('GLC GAL SIA NGA SIA', 'F', '1'), ('BGC GAL SIA NGA SIA', 'E', '1')]
# 1mfd [('MMA GLA ABE', 'A', '1')]
# 3c6s [('RAM NAG RAM RAM RAM NAG RAM RAM RAM GLC GLC', 'L', '1'), ('RAM NAG RAM RAM RAM NAG RAM RAM RAM GLC GLC', 'K', '1'), ('RAM NAG RAM RAM RAM NAG RAM RAM RAM GLC GLC', 'J', '1'), ('RAM NAG RAM RAM RAM NAG RAM RAM RAM GLC GLC', 'I', '1')]
# 1m7d [('MAG RAE RAM', 'C', '1')]
# 1g1t [('MAG FUC GAL SIA', 'B', '1')]
# 4l4j [('NAG NAG BMA MAN NAG', 'D', '1')]
# 1keg [('DT  64T DT  DT', 'A', '1')]
# 1cly [('NAG NON FUC GAL FUC', 'A', '1')]
# 2rdg [('NDG FUC GAL SIA', 'B', '1')]
# 6idg [('64T 5PY', 'A', '1')]
# 1uz8 [('MAG FUC GAL', 'C', '1'), ('MAG FUC GAL', 'D', '1')]
# 5y34 [('3NI O FCO ', 'C', '702'), ('3NI O FCO ', 'A', '601')]
# 6d30 [('U   U  ', 'C', '1')]
# 5a57 [('5G0 GAL', 'A', '2433')]
# 1jdc [('GLC GLC GLC GLC', 'B', '1')]
# 6rv8 [('XYP XYP', 'D', '1')]
# 1lxm [('NAG BDP NAG BDP NAG BDP', 'B', '1')]
# 2wda [('ASG GCD', 'B', '1')]
# 2wnf [('A2G CG3 GAL', 'B', '1')]
# 1ur4 [('GAL GAL', 'C', '1'), ('GAL GAL', 'D', '1')]
# 3dhv [('DAL AMP', 'A', '701')]
# 3a2q [('ACA ACA', 'A', '601')]
# 3wkg [('BMA BGC', 'B', '1')]
# 5h0u [('HIS HIS HIS HIS HIS HIS', 'B', '28')]
# 2dqa [('NAG NAG NAG', 'C', '1'), ('NAG NAG NAG', 'D', '1')]
# 4hp0 [('NAG NOJ NAG NAG', 'B', '1')]
# 1lzr [('NAG NAG NAG NAG', 'B', '1')]
# 6t6c [('NAG NAG NAG NAG', 'B', '1')]
# 1lsz [('NDG NAG NAG NAG', 'B', '1')]
# 1eom [('NAG MAN MAN MAN NAG GAL NAG GAL', 'B', '1')]
# 3fhq [('BMA NGT MAN MAN', 'C', '1'), ('BMA NGT MAN MAN', 'E', '1'), ('BMA NGT MAN MAN', 'G', '1'), ('BMA NGT MAN MAN', 'H', '1')]
# 2inv [('FRU FRU', 'F', '1'), ('FRU FRU', 'E', '1'), ('FRU FRU', 'D', '1')]
# 6kaj [('CDP RB0', 'C', '504'), ('CDP RB0', 'B', '504'), ('CDP RB0', 'D', '504'), ('CDP RB0', 'A', '504')]
# 2x2e [('GDP ALF', 'A', '1744'), ('GDP ALF', 'D', '1744')]
# 6jtg [('GDP BEF', 'A', '401')]
# 1w7j [('ADP BEF', 'A', '1794')]
# 1kk8 [('BEF ADP', 'A', '995')]
# 4zg4 [('VO4 ADP', 'E', '802'), ('VO4 ADP', 'B', '802')]
# 4z3e [('BGC GAL GLA NGA GAL', 'B', '1')]
# 5i0h [('ADP BEF', 'B', '801'), ('ADP BEF', 'A', '801')]
# 2vb6 [('ADP BEF', 'A', '998')]
# 1awi [('PRO PRO PRO PRO PRO PRO PRO PRO PRO PRO', 'P', '1')]
# 1lvk [('MNT BEF', 'A', '999')]
# 1rhc [('F42 ACN', 'A', '351')]
# 4yz0 [('ADA ADA ADA', 'B', '210'), ('X0X ADA ADA', 'D', '1'), ('GTR ADA ADA', 'A', '215'), ('GTR ADA ADA', 'B', '213'), ('X1X ADA ADA', 'C', '1')]
# 2ewe [('ADA ADA ADA ADA', 'B', '1')]
# 3vmw [('ADA ADA ADA', 'B', '1')]
# 5amv [('ADA ADA ADA', 'B', '1')]
# 6ojl [('GTR ADA ADA ADA ADA', 'B', '1')]
# 1gxo [('ADA ADA ADA', 'B', '1')]
# 3b8y [('ADA ADA ADA ADA', 'C', '1'), ('ADA ADA ADA ADA', 'D', '1')]
# 4cp8 [('MLI', 'C', '1466'), ('MLI', 'D', '1465'), ('MLI', 'A', '1466'), ('MLI', 'B', '1465')]
# 1wyv [('PLP AOA', 'B', '1475'), ('PLP AOA', 'D', '2475'), ('PLP AOA', 'F', '3475'), ('PLP AOA', 'H', '4475')]
# 4b9q [('ATP', 'B', '700'), ('ATP', 'D', '700')]
# 2whl [('MAN BMA BMA', 'B', '1')]
# 1odz [('MAN BMA', 'D', '1'), ('MAN BMA', 'C', '1')]
# 3man [('MAN BMA BMA', 'B', '1')]
# 4cd6 [('IFM BMA', 'A', '500')]
# 5jug [('MAN BMA BMA BMA BMA', 'A', '202'), ('BMA BMA BMA BMA BMA', 'B', '1')]
# 3wdr [('MAN BGC', 'C', '1'), ('MAN BGC BMA BMA', 'B', '1'), ('BMA BGC BGC BMA', 'A', '407')]
# 1pmh [('MAN BMA BMA BMA BMA BMA', 'A', '1')]
# 1qnr [('BMA BMA', 'B', '1')]
# 5zhw [('DAL DAL', 'A', '302'), ('DAL DAL', 'B', '302')]
# 4kxv [('TDP DX5', 'A', '1011')]
# 2f6d [('GLC GLC AC1', 'B', '1'), ('GLC GLC AC1', 'C', '1')]
# 2v8l [('GLC GLC GLC GLC GLC GLC GLC', 'B', '1')]
# 1gah [('GLC GLC AC1', 'D', '1')]
# 1lf9 [('GLC GLC AC1', 'C', '1'), ('GLC GLC AC1', 'D', '1')]
# 6czs [('GLC GLC', 'D', '1'), ('GLC GLC', 'C', '1')]
# 7buj [('GTP 5GP', 'A', '602'), ('GTP 5GP', 'B', '602')]
# 1y1p [('NMN AMP PO4', 'A', '1001'), ('NMN AMP PO4', 'B', '2001')]
# 5e1q [('BGC GLA GAL', 'D', '1'), ('BGC GLA GAL', 'C', '1')]
# 4lyq [('MAN BMA BMA', 'B', '1')]
# 1krp [('DT  DT  PST', 'B', '1001')]
# 1xi1 [('DT  DT  DT  DT  DT', 'C', '3'), ('DT  DT  DT  DT  DT', 'D', '3')]
# 3wqd [('PLP 999', 'A', '401'), ('PLP 999', 'B', '402')]
# 1umd [('TDP COI', 'A', '1402'), ('TDP COI', 'C', '2402')]
# 1hv6 [('GCU MAV MAW', 'B', '1')]
# 1pt2 [('GLC FRU', 'B', '1')]
# 6rv5 [('FRU FRU', 'B', '1')]
# 1ulv [('GLC AC1', 'B', '1')]
# 1zm1 [('BGC BGC BGC', 'C', '1'), ('BGC BGC BGC', 'D', '1')]
# 5a95 [('BGC BGC BGC', 'D', '1'), ('BGC BGC BGC', 'F', '1'), ('BGC BGC BGC', 'E', '1')]
# 1u0a [('BGC BGC BGC BGC', 'H', '1'), ('BGC BGC BGC BGC', 'E', '1'), ('BGC BGC BGC BGC', 'G', '1'), ('BGC BGC BGC BGC', 'F', '1')]
# 3wdx [('BGC BGC BGC', 'C', '1'), ('BGC BGC BGC', 'E', '1'), ('GLC BGC BGC', 'F', '1'), ('GLC BGC BGC', 'D', '1')]
# 4i67 [('G   G   G   RPC', 'B', '1')]
# 6qns [('BGC GAL NGA GAL SIA SIA', 'B', '1')]
# 5tpc [('GAL SIA NGA GAL SIA', 'B', '1')]
# 4kbb [('BGC GAL SIA NGA GAL SIA', 'F', '1'), ('BGC GAL SIA NGA GAL SIA', 'E', '1')]
# 5ayc [('BGC BMA', 'B', '1')]
# 3was [('BGC BMA', 'D', '1'), ('BGC BMA', 'C', '1')]
# 5awq [('GLC GLC', 'C', '1'), ('GLC GLC GLC', 'B', '1')]
# 4uz3 [('NAG NAG NAG NAG NAG NAG', 'E', '1'), ('NAG NAG NAG NAG NAG NAG', 'D', '1'), ('NAG NAG NAG NAG NAG NAG', 'F', '1'), ('NDG NAG NAG NAG NAG NAG', 'D', '1'), ('NDG NAG NAG NAG NAG NAG', 'F', '1'), ('NDG NAG NAG NAG NAG NAG', 'A', '1112')]
# 5muj [('XXM RAM 8OQ GAL 8PK ARA RAM RAM', 'B', '1')]
# 6ffl [('GLC GLC GLC', 'B', '1')]
# 6gxa [('TB8', 'B', '504'), ('TB8', 'D', '504'), ('TB8', 'C', '504')]
# 5m77 [('7K2 7K3', 'D', '1'), ('7K2 7K3', 'C', '1')]
# 5z4t [('BMA BMA', 'C', '1'), ('BMA BMA', 'D', '1')]
# 5fre [('GAL SIA', 'E', '1'), ('GAL SIA', 'F', '1'), ('GAL SIA', 'D', '1')]
# 5o58 [('A   G  ', 'B', '1')]
# 5ngl [('NOJ BGC', 'B', '501'), ('NOJ BGC', 'A', '501'), ('NOJ BGC', 'C', '501')]
# 6m6p [('GLC BGC BGC BGC', 'B', '1')]
# 1ux7 [('XYP XYP XYP', 'B', '1')]
# 5xsp [('A   A  ', 'A', '703'), ('A   A  ', 'B', '703')]
# 5j7z [('BGC 18C GAL SIA NGA GAL', 'C', '1')]
# 5e8b [('BEN', 'B', '201')]
# 5h4r [('BGC BGC BGC BGC', 'B', '1')]
# 5d4y [('XYP XYP', 'C', '1'), ('XYP XYP', 'D', '1')]
# 5e62 [('Z3Q GAL 5N6', 'M', '1'), ('Z3Q GAL 5N6', 'H', '1')]
# 5i79 [('BGC BGC BGC BGC', 'C', '1'), ('BGC BGC BGC BGC', 'D', '1')]
# 5hqa [('GLC GLC AC1', 'B', '1')]
# 4w8b [('BGC BGC BGC XYS XYS', 'C', '1'), ('GLC BGC BGC XYS BGC XYS XYS GAL', 'B', '1')]
# 2uvf [('ADA ADA', 'C', '1')]
# 4znl [('BEF ADP', 'C', '302'), ('BEF ADP', 'B', '302'), ('BEF ADP', 'A', '302')]
# 5d9o [('BGC BGC BGC BGC', 'D', '1'), ('BGC BGC BGC BGC', 'C', '1')]
# 6r2j [('BGC BGC', 'E', '1'), ('BGC BGC', 'F', '1')]
# 4pmz [('XYP XYP', 'C', '1'), ('XYP XYP', 'D', '1')]
# 4c1w [('GLC GAL SIA', 'B', '1')]
# 5e65 [('GAL 5N6', 'M', '1'), ('GAL 5N6', 'H', '1')]
# 6hpf [('MAN BMA GLA BMA GLA', 'B', '1')]
# 1tb6 [('GU4 GU6 GU0 GU5 GU8 GU9 GU8 GU9 GU8 GU9 GU8 GU5 GU1 GU6 GU2 GU3', 'I', '433')]
# 2ntb [('ADA ADA ADA ADA ADA ADA', 'C', '1'), ('ADA ADA ADA ADA ADA ADA', 'D', '1')]
# 6ld3 [('G8O FB2', 'A', '903')]
# 1umz [('BGC BGC BGC XYS XYS GAL', 'F', '1'), ('BGC BGC BGC XYS XYS GAL', 'D', '1')]
# 4w88 [('BGC BGC BGC XYS XYS GAL', 'D', '1'), ('BGC BGC XYS GAL', 'C', '1')]
# 2jeq [('BGC BGC BGC XYS BGC XYS GAL', 'B', '1')]
# 5oye [('BGC BGC BGC XYS BGC XYS', 'D', '1'), ('BGC BGC BGC XYS BGC XYS GAL', 'C', '1')]
# 3zmr [('GLO BGC BGC XYS BGC XYS XYS', 'D', '1'), ('BGC BGC GLC BGC XYS BGC XYS XYS', 'C', '1')]
# 2cn3 [('GLC BGC BGC XYS BGC XYS XYS GAL', 'F', '1'), ('GLC BGC BGC XYS BGC XYS XYS GAL', 'E', '1'), ('GLC BGC BGC XYS BGC XYS XYS GAL', 'C', '1'), ('GLC BGC BGC XYS BGC XYS XYS GAL GAL', 'D', '1')]
# 2vh9 [('BGC BGC BGC XYS GAL BGC XYS GAL XYS', 'C', '1'), ('BGC BGC BGC XYS GAL BGC XYS GAL XYS', 'F', '1')]
# 4jaw [('GAL NGT', 'A', '701'), ('NGT GAL', 'B', '702')]
# 5gqf [('NAG GAL', 'D', '1'), ('NAG GAL', 'C', '1')]
# 4wtr [('BGC BGC', 'B', '1'), ('BGC BGC', 'C', '1')]
# 6hq8 [('BGC BGC BGC BGC BGC BGC', 'C', '1'), ('BGC BGC BGC BGC BGC BGC', 'D', '1')]
# 5lyr [('MAN MNM', 'A', '403')]
# 2r68 [('GLC F6P', 'B', '1')]
# 2w5f [('XYP XYP XYP', 'C', '1'), ('XYP XYP XYP', 'D', '1')]
# 1v0l [('XIF XYP', 'A', '1304')]
# 3w25 [('XYP XYP', 'B', '1')]
# 6jwb [('XYP XYP XYP', 'B', '1')]
# 1b3x [('XYP XYP XYP', 'B', '1')]
# 2vgd [('XYP XYP', 'C', '1'), ('XYP XYP FX3 XYP', 'B', '1')]
# 2d24 [('XYS XYS', 'G', '1'), ('XYS XYS', 'E', '1'), ('XYS XYS XYS XYS', 'D', '1'), ('XYS XYS XYS XYS XYS', 'F', '1'), ('XYS XYS XYS XYS XYS', 'C', '1')]
# 1od3 [('BGC BGC', 'B', '1'), ('BGC BGC', 'C', '1')]
# 5a6m [('XYP XYP', 'C', '1'), ('XYS XYP XYP', 'B', '1')]
# 1h4h [('XYS XYP XYP', 'H', '1'), ('XYS XYP XYP', 'E', '1'), ('XYS XYP XYP', 'G', '1'), ('XYS XYP XYP', 'F', '1')]
# 2fgl [('XYS XYS', 'A', '703'), ('XYS XYS XYS', 'D', '1'), ('XYS XYS XYS', 'C', '1')]
# 1vbr [('XYP XYS', 'C', '1'), ('XYP XYS', 'D', '1')]
# 4xur [('XYP XYP XYP XYP', 'D', '1'), ('XYP XYP XYP XYP', 'F', '1'), ('XYP XYP XYP', 'E', '1')]
# 2wze [('XYP XYP XYP', 'D', '1'), ('XYP XYP XYP', 'C', '1')]
# 1knm [('BGC GAL', 'C', '1'), ('BGC GAL', 'B', '1')]
# 6sgf [('XYP XYP XYP XYP', 'L', '1'), ('XYP XYP XYP XYP', 'J', '1'), ('XYP XYP XYP XYP', 'I', '1'), ('XYP XYP XYP XYP', 'H', '1'), ('XYP XYP XYP XYP', 'K', '1'), ('XYP XYP XYP XYP', 'G', '1')]
# 1ur1 [('XYS XYP AHR', 'B', '1')]
# 3rdk [('XYS XYP XYP GCV', 'D', '1'), ('XYS XYP XYP GCV', 'C', '1')]
# 4qb6 [('XYP GCU', 'B', '1')]
# 1uxx [('XYP XYP XYP XYP XYP', 'A', '1')]
# 2y64 [('XYP XYP XYP XYP XYP', 'B', '1')]
# 2y24 [('XYP XYP GCV XYP', 'B', '1')]
# 1us2 [('XYP XYP XYP XYP', 'B', '1'), ('XYP XYP XYP XYP', 'C', '1')]
# 1i82 [('BGC BGC', 'B', '1')]
# 1xnk [('Z4U TWY TWY', 'C', '1'), ('Z4U TWY TWY', 'D', '1')]
# 1r87 [('XYP XYP', 'B', '1'), ('XYP XYP XYP', 'C', '1')]
# 1gny [('XYP XYP XYP XYP XYP', 'B', '1')]
# 2w68 [('BGC GAL SIA', 'F', '1'), ('BGC GAL SIA', 'E', '1'), ('BGC GAL SIA', 'D', '1')]
# 1ms9 [('BGC GAL', 'D', '1'), ('BGC GAL', 'C', '1')]
# 1ktw [('G4S DGS', 'C', '1')]
# 6ry7 [('BGC BGC', 'B', '1')]
# 3s7o [('LBV', 'A', '330')]
# 3vgf [('GLC GLC GLC', 'B', '1')]
# 1ogo [('BGC GLC', 'A', '1')]
# 5axh [('GLC GLC GLC GLC', 'C', '1'), ('BGC GLC GLC GLC GLC GLC', 'D', '1')]
# 2wdb [('MAN NAG', 'H', '1'), ('MAN NAG', 'E', '1'), ('MAN NAG', 'G', '1'), ('MAN NAG', 'F', '1')]
# 5hjo [('DGO Z61', 'G', '1'), ('DGO Z61', 'H', '1')]
# 2ebs [('BGC BGC BGC XYS BGC XYS XYS', 'C', '1'), ('BGC BGC BGC XYS BGC XYS XYS', 'D', '1')]
# 4d3s [('BOG', 'F', '1000'), ('BOG', 'H', '1000')]
# 4b9z [('GLC GLC AC1', 'B', '1')]
# 2nlr [('G2F SHG BGC BGC', 'B', '1')]
# 4yhg [('BGC BGC BGC', 'C', '1')]
# 3ach [('BGC BGC BGC BGC', 'B', '1')]
# 2bog [('MGL SGC BGC BGC', 'A', '1')]
# 1g9j [('SGC BGC SGC BGC SGC BGC SGC BGC', 'B', '1')]
# 1ia7 [('BGC BGC', 'B', '1')]
# 4u5i [('XYP XYP', 'C', '1'), ('XYP XYP', 'D', '1')]
# 1w3l [('BGC BGC OXZ', 'B', '1')]
# 4yzt [('BGC BGC BGC BGC', 'B', '1')]
# 1gu3 [('BGC BGC BGC BGC BGC', 'B', '1')]
# 1kwf [('BGC BGC BGC BGC BGC', 'B', '1'), ('BGC BGC BGC', 'A', '406')]
# 1g0c [('BGC BGC', 'B', '1')]
# 2wao [('BGC BGC BGC BGC BGC', 'B', '1')]
# 4fus [('BGC BGC', 'B', '1')]
# 1uu6 [('BGC BGC BGC BGC', 'B', '1')]
# 1js4 [('BGC', 'B', '6015'), ('BGC BGC', 'D', '1'), ('BGC BGC BGC', 'C', '1')]
# 3axx [('BGC BGC', 'F', '1'), ('BGC BGC', 'E', '1'), ('BGC BGC', 'D', '1')]
# 3ays [('BGC BGC BGC', 'B', '1')]
# 2jen [('GLC GLC BGC XYS BGC XYS', 'B', '1'), ('GLC GLC XYS XYS', 'A', '1273')]
# 4y7e [('BMA BMA BMA', '414', '1'), ('BMA BMA BMA', 'D', '1'), ('BMA BMA BMA BMA', 'A', '410'), ('BMA BMA BMA BMA BMA BMA BMA', 'C', '1')]
# 3amn [('GLC BGC', 'C', '1'), ('GLC BGC', 'E', '1'), ('BGC BGC', 'F', '1'), ('BGC BGC', 'D', '1')]
# 6r3m [('BGC BGC BGC BGC', 'B', '1'), ('GLC BGC BGC BGC', 'A', '209')]
# 3zq9 [('NOY BGC', 'A', '1519')]
# 1ece [('BGC BGC BGC BGC', 'C', '1'), ('BGC BGC BGC BGC', 'D', '1')]
# 6gl0 [('GLC BGC BGC', 'E', '1'), ('GLC BGC BGC', 'F', '1'), ('GLC BGC BGC', 'D', '1')]
# 2bwa [('GLC BGC', 'D', '1'), ('GLC BGC BGC', 'C', '1')]
# 4zz8 [('GCS GCS GCS', 'C', '1')]
# 5gm5 [('BGC BGC', 'I', '1'), ('BGC BGC', 'K', '1'), ('BGC BGC', 'J', '1'), ('BGC BGC', 'H', '1')]
# 4doe [('BGC BGC BGC', 'C', '1'), ('GLC BGC', 'B', '1')]
# 1ga2 [('BGC BGC', 'D', '1'), ('BGC BGC', 'E', '1'), ('BGC BGC BGC', 'C', '1')]
# 1j84 [('BGC BGC BGC BGC', 'B', '1')]
# 2e0p [('BGC BGC BGC BGC', 'B', '1')]
# 1cen [('BGC BGC', 'B', '1')]
# 3qxq [('BGC BGC BGC BGC BGC', 'H', '1'), ('BGC BGC BGC BGC BGC', 'E', '1'), ('BGC BGC BGC BGC BGC', 'G', '1'), ('BGC BGC BGC BGC BGC', 'F', '1')]
# 4bpz [('GLC BGC BGC', 'C', '1'), ('GLC BGC BGC', 'D', '1')]
# 4cte [('GS1 GS1', 'C', '1'), ('GS1 GS1 BGC', 'D', '1')]
# 3gd9 [('GLC BGC BGC BGC', 'B', '1')]
# 5h9y [('BGC BGC BGC BGC', 'C', '1'), ('BGC BGC BGC BGC BGC', 'B', '1')]
# 2od9 [('A1R NCA', 'A', '1001')]
# 4p7r [('NAG NAG NAG NAG', 'B', '1')]
# 2exk [('XYS XYS', 'F', '1'), ('XYS XYS', 'E', '1'), ('XYS XYS', 'G', '1'), ('XYS XYS', 'H', '1')]
# 6g09 [('XYP XYP', 'B', '1')]
# 2vno [('GAL FUC GAL', 'C', '1'), ('GAL FUC GAL', 'D', '1')]
# 2fv1 [('NDG GAD', 'D', '1'), ('NDG GAD', 'C', '1')]
# 5xcz [('GLC BGC', 'B', '1')]
# 4cd5 [('BMA MVL', 'A', '1422')]
# 5fks [('BGC BGC BGC XYS BGC XYS GAL', 'B', '1'), ('BGC BGC BGC XYS BGC XYS XYS GAL GAL', 'C', '1')]
# 2pi8 [('NAG NAG NAG NAG NAG NAG', 'H', '1'), ('NAG NAG NAG NAG NAG NAG', 'E', '1'), ('NAG NAG NAG NAG NAG NAG', 'G', '1'), ('NAG NAG NAG NAG NAG NAG', 'F', '1')]
# 3qef [('AHR AHR AHR', 'C', '1'), ('AHR AHR AHR AHR', 'D', '1')]
# 3ank [('NG6 GCD', 'B', '1')]
# 2d8l [('NGA GCD', 'B', '1')]
# 1hfu [('MAN MAN', 'B', '1'), ('NAG NAG', 'C', '1')]
# 4yoe [('A   G   U  ', 'E', '15')]
# 4xxh [('GLC G6P', 'D', '1'), ('GLC G6P', 'C', '1')]
# 3ct5 [('NAG NAG NAG', 'B', '1')]
# 5ysz [('BGC BGC', 'B', '1')]
# 7cdx [('GLC FRU', 'D', '1'), ('GLC FRU', 'C', '1')]
# 6nx3 [('BGC GAL', 'L', '1'), ('BGC GAL', 'J', '1'), ('BGC GAL', 'I', '1'), ('BGC GAL', 'K', '1'), ('BGC GAL', 'G', '1'), ('BGC GAL', 'H', '1')]
# 5t4j [('PLP ABU', 'B', '501')]
# 2f5t [('GLC GLC', 'A', '1')]
# 1f9p [('ESA ESA ESA', 'A', '101')]
# 2yhw [('BM3', 'A', '1718')]
# 1umi [('NDG NAG', 'B', '1')]
# 4bq4 [('GAL AAL GAL AAL', 'C', '1'), ('GAL AAL GAL AAL', 'D', '1')]
# 1urx [('AAL GAL AAL GAL AAL GAL AAL', 'C', '1'), ('GLA AAL GAL AAL', 'B', '1')]
# 2z8g [('BGC GLC GLC', 'C', '1'), ('BGC GLC GLC', 'D', '1')]
# 5z4a [('A   G   U  ', 'B', '-1')]
# 3zxk [('XYP XYP AHR XYP', 'C', '1'), ('XYP XYP AHR XYP', 'D', '1')]
# 5m1z [('6LW AHR', 'B', '1')]
# 2vrq [('XYP XYP AHR', 'F', '1'), ('XYP XYP AHR XYP', 'D', '1'), ('XYP XYP AHR XYP', 'E', '1')]
# 4n2z [('GLC BGC BGC', 'B', '1')]
# 3a72 [('AHR AHR', 'B', '1')]
# 3c7f [('XYP XYP XYP', 'B', '1')]
# 4cfp [('AMV NAG AMU NAG', 'D', '1'), ('AMV NAG AMU NAG', 'C', '1')]
# 4hjy [('NAG NAG NAG', 'D', '1'), ('NAG NAG NAG NAG NAG', 'C', '1')]
# 4cub [('NAG GAL', 'C', '1'), ('NAG GAL', 'D', '1')]
# 5mgd [('GLC GAL GAL', 'E', '1')]
# 2y4s [('GLC GLC GLC GLC GLC GLC GLC', 'B', '1')]
# 2j73 [('GLC GLC GLC', 'D', '1'), ('GLC GLC GLC GLC', 'C', '1')]
# 6j34 [('GLC GLC GLC', 'B', '1'), ('GLC GLC GLC', 'C', '1')]
# 2add [('GLC FRU', 'D', '1')]
# 3t12 [('GDP ALF', 'A', '197')]
# 3mg9 [('GHP 3MY 3FG GHP GHP OMY 3FG', 'B', '387'), ('GHP 3MY 3FG GHP GHP OMY 3FG', 'C', '387')]
# 1mxg [('GLC GLC AC1', 'B', '1'), ('GLC GLC AC1', 'C', '1'), ('GLC GLC AC1', 'D', '1')]
# 4xjc [('TTP', 'B', '201'), ('TTP', 'D', '201'), ('MG TTP', 'D', '202')]
# 2v5e [('GU4 YYJ', 'C', '1')]
# 1n1i [('HIS', 'C', '501')]
# 4ref [('3N0', 'A', '302')]
# 2hrl [('CEQ BGC NGA GAL SIA SIA', 'A', '206')]
# 5uff [('BGC GAL FUC', 'B', '1')]
# 1fwv [('MAG SGA FUC', 'B', '1')]
# 1gmn [('IDS SGN IDS SGN IDS', 'C', '1')]
# 5elt [('U   A   A   U  ', 'F', '1'), ('U   A   A   U  ', 'E', '0')]
# 3vq2 [('LP4 LP5 MYR DAO', 'D', '300'), ('LP4 LP5 MYR DAO', 'C', '300')]
# 4rga [('GYP GZL NAG', 'C', '1'), ('GYP GZL NAG', 'D', '1')]
# 5vkm [('GAL SIA', 'C', '1')]
# 4d3w [('NGA GAL', 'B', '1'), ('A2G GAL', 'B', '1')]
# 4oee [('IDY GNX', 'B', '1')]
# 3rsj [('GAL NGA GAL SIA', 'G', '1'), ('GAL SIA NGA GAL SIA', 'F', '1'), ('NGA GAL SIA', 'H', '1'), ('NGA GAL SIA', 'E', '1')]
# 4cov [('GAL GLA', 'B', '1')]
# 2b1q [('GLC GLC', 'B', '1')]
# 3wqt [('ANP', 'C', '502'), ('ANP', 'D', '503'), ('ANP', 'B', '502')]
# 3n17 [('NAG NAG', 'B', '1')]
# 4mb4 [('NAG NAG NAG NAG', 'B', '1')]
# 1llo [('NAA AMI NAA', 'B', '1')]
# 3a4x [('NDG NAG NAG NAG', 'D', '1'), ('NDG NAG NAG NAG', 'C', '1')]
# 3wh1 [('NAG NAG NAG NAG', 'B', '1')]
# 3w6c [('NAG NAG', 'H', '1'), ('NAG NAG', 'F', '1'), ('NAG NAG', 'G', '1'), ('NAG NAG', 'E', '1'), ('NAG NAG', 'K', '1'), ('NAG NAG', 'I', '1'), ('NAG NAG', 'J', '1')]
# 5xsw [('NDG NAG', 'C', '1'), ('NDG NAG', 'D', '1')]
# 1nlu [('IVA PHI TYB', 'B', '1'), ('IVA PHI TYB', 'C', '1')]
# 1pnf [('NDG NAG', 'B', '1')]
# 2i74 [('MAN MAN MAN MAN', 'C', '1'), ('MAN MAN MAN MAN', 'D', '1')]
# 4jzu [('GCP G  ', 'C', '1')]
# 2j1t [('NAG FUC GAL FUC', 'C', '1')]
# 6e20 [('NDG GAL', 'D', '1'), ('NDG GAL', 'C', '1')]
# 1oh3 [('GLC BGC BGC BGC BGC BGC', 'C', '1')]
# 3nbc [('BGC GAL', 'C', '1')]
# 2xju [('MAN MAN', 'B', '1')]
# 2wmi [('GAL FUC A2G', 'C', '1'), ('GAL FUC A2G', 'D', '1')]
# 1y3n [('MAV BEM', 'B', '1')]
# 1j1n [('MAV LGU MAV BEM', 'C', '1'), ('MAV LGU MAV BEM', 'D', '1')]
# 5bq5 [('ADP BEF', 'B', '301'), ('ADP BEF', 'C', '301'), ('ADP BEF', 'A', '301')]
# 2bmz [('MMA XYP', 'F', '1'), ('MMA XYP', 'C', '1'), ('MMA XYP', 'E', '1'), ('MMA XYP', 'D', '1')]
# 3a0e [('MAN MAN', 'B', '1')]
# 2d6m [('GLC GAL', 'C', '1'), ('GLC GAL', 'D', '1')]
# 4b4q [('GLC GAL NAG GAL FUC A2G', 'C', '1'), ('GLC GAL NAG GAL FUC A2G', 'D', '1')]
# 1jlx [('A2G MBN GAL', 'C', '1'), ('A2G MBN GAL', 'D', '1')]
# 2y9g [('GLC GAL', 'D', '1'), ('GLC GAL', 'B', '1'), ('BGC GAL', 'E', '1'), ('BGC GAL', 'C', '1')]
# 3qdt [('A2G GAL', 'D', '1'), ('A2G GAL', 'C', '1')]
# 5kiq [('NAG FUC GAL SIA', 'C', '1')]
# 4cp9 [('GAL CN8', 'A', '1123'), ('GAL CN8', 'B', '1124'), ('GAL CN8', 'C', '1124'), ('GAL CN8', 'D', '1124')]
# 3aqz [('BGC BGC BGC BGC BGC BGC', 'C', '1'), ('BGC BGC BGC BGC BGC BGC', 'D', '1')]
# 1eu8 [('GLC GLC', 'B', '1')]
# 1ule [('NAG GAL GLA', 'C', '1'), ('NAG GAL GLA', 'D', '1')]
# 5f7y [('GLC GAL NAG GAL FUC A2G', 'F', '1'), ('GLC GAL NAG GAL FUC A2G', 'E', '1')]
# 6t1d [('GLC GLA', 'N', '1'), ('GLC GLA', 'J', '1'), ('GLC GLA', 'H', '1'), ('GLC GLA', 'L', '1'), ('GLC GLA', 'M', '1'), ('GLC GLA', 'R', '1'), ('GLC GLA', 'I', '1'), ('GLC GLA', 'P', '1'), ('GLC GLA', 'Q', '1'), ('GLC GLA', 'K', '1'), ('GLC GLA', 'G', '1'), ('GLC GLA', 'O', '1')]
# 5v6f [('BMA MAN MAN', 'B', '1')]
# 2wmh [('GAL FUC', 'B', '1')]
# 5vyb [('BMA MAN MAN MAN MAN MAN MAN', 'B', '1')]
# 1c3m [('MAN MAN', 'B', '1')]
# 5gub [('NGA GCD', 'D', '1'), ('NGA GCD', 'F', '1'), ('NGA GCD', 'E', '1')]
# 3qdy [('A2G GAL', 'D', '1'), ('A2G GAL', 'C', '1'), ('NAG NAG', 'F', '1'), ('NAG NAG', 'E', '1')]
# 1jzn [('BGC GAL', 'F', '1'), ('BGC GAL', 'G', '1'), ('BGC GAL', 'J', '1'), ('BGC GAL', 'H', '1'), ('BGC GAL', 'I', '1')]
# 2it5 [('MAN MAN MAN', 'B', '1')]
# 2bs5 [('BGC GAL FUC', 'C', '1'), ('BGC GAL FUC', 'B', '1')]
# 6lfj [('MAN IPD MAN', 'A', '303'), ('IPD MAN', 'B', '302')]
# 6epy [('FRU GLC GLA', 'E', '1'), ('FRU GLC GLA', 'H', '1'), ('FRU GLC GLA', 'G', '1'), ('FRU GLC GLA', 'F', '1')]
# 2xfe [('GAL GAL', 'B', '1')]
# 3x00 [('ZOF ZOF EDN', 'D', '201'), ('ZOF EDN ZOF', 'B', '201')]
# 1en2 [('NAG NAG NAG NAG', 'B', '1')]
# 5kle [('BGC BGC BGC BGC BGC', 'B', '1')]
# 3lek [('NDG GAL FUC FUC', 'B', '1')]
# 5d63 [('GLA FUC GLA', 'D', '1'), ('GLA FUC GLA', 'C', '1'), ('GAL FUC GLA', 'B', '1')]
# 4m00 [('GLC FRU', 'B', '1')]
# 3wg3 [('NAG GAL FUC A2G', 'D', '1'), ('NAG GAL FUC A2G', 'C', '1')]
# 1ww5 [('BGC SGA', 'H', '1'), ('BGC SGA', 'E', '1'), ('BGC SGA', 'G', '1'), ('BGC SGA', 'F', '1')]
# 2zhl [('NAG GAL NAG GAL', 'F', '1'), ('NAG GAL NAG GAL', 'E', '1'), ('NAG GAL NAG GAL', 'G', '1'), ('NAG GAL NAG GAL', 'H', '1')]
# 5xfi [('NAG NAG BMA MAN MAN NAG GAL NAG', 'C', '1'), ('NAG NAG BMA MAN MAN NAG GAL NAG', 'D', '1')]
# 1k9j [('MAN MAN MAN NAG NAG', 'C', '1')]
# 2wt2 [('NAG GAL NAG GAL NAG GAL', 'D', '1'), ('NAG GAL NAG GAL NAG GAL', 'C', '1')]
# 3fax [('BGC GLC GLC', 'B', '1')]
# 5t7i [('BGC GAL NAG GAL', 'B', '1')]
# 1w9w [('BGC BGC GLC BGC BGC BGC', 'B', '1')]
# 1jif [('CU  BLM', 'A', '404'), ('CU  BLM', 'B', '403')]
# 5swb [('NAG BMA MAN MAN MAN MAN', 'E', '1'), ('NAG BMA MAN MAN MAN MAN', 'H', '1'), ('NAG BMA MAN MAN MAN MAN', 'F', '1'), ('NAG BMA MAN MAN MAN MAN', 'B', '1')]
# 2vbm [('RAM RAM NAG RAM', 'B', '1')]
# 1k7u [('NAG NAG', 'D', '1'), ('NAG NAG', 'C', '1')]
# 1k7t [('GAL NAG', 'D', '1'), ('GAL NAG', 'C', '1')]
# 3vyk [('MMA MAN NAG MAN NAG NAG', 'B', '1')]
# 4kzv [('GLC GLC', 'C', '1')]
# 6fuv [('BMA BMA BMA', 'B', '1')]
# 4cpb [('GAL CN8', 'B', '1123'), ('GAL CN8', 'A', '1123'), ('GAL CN8', 'D', '1124'), ('GAL CN8', 'C', '1123')]
# 2ox9 [('NAG FUC GAL', 'H', '1'), ('NAG FUC GAL', 'E', '1'), ('NAG FUC GAL', 'G', '1'), ('NAG FUC GAL', 'F', '1')]
# 3alt [('GLC GLA', 'H', '1'), ('GLC GLA', 'E', '1'), ('GLC GLA', 'G', '1'), ('GLC GLA', 'F', '1')]
# 1gui [('BGC BGC BGC BGC BGC BGC', 'B', '1')]
# 5f7n [('NAG GAL FUC FUC A2G', 'F', '1'), ('NAG GAL FUC FUC A2G', 'E', '1')]
# 1ulm [('NAG NAG NAG', 'C', '1'), ('NAG NAG NAG', 'D', '1')]
# 2cb8 [('MYA', 'B', '1089')]
# 6p2m [('BGC BGC BGC XYS XYS GAL GAL', 'B', '1')]
# 1elj [('GLC GLC GLC', 'B', '1')]
# 2xuz [('EB4 FE', 'A', '1300')]
# 2w47 [('GTR AQA', 'B', '1')]
# 6kug [('G   C   C   U  ', 'B', '1')]
# 6fx2 [('C4W NAG FUC BMA MAN MAN NAG GAL NAG', 'C', '1'), ('C4W NAG FUC BMA MAN NAG GAL', 'D', '1')]
# 6q79 [('DLY DTY DLY DLY DAL DLE ZDC', 'G', '2'), ('DLY DTY DLY DLY DAL DLE ZDC', 'F', '2')]
# 4xr8 [('GLC GLC', 'G', '1'), ('GLC GLC', 'E', '1')]
# 6rkj [('AHR AHR AHR AHR AHR AHR', 'B', '1')]
# 2xom [('GAL GAL GAL', 'B', '1')]
# 6g0x [('NDG NAG GLA NAG GLC RAM', 'B', '1')]
# 2r0h [('NAG NAG NAG', 'H', '1'), ('NAG NAG NAG', 'E', '1'), ('NAG NAG NAG', 'G', '1'), ('NAG NAG NAG', 'F', '1')]
# 3qdu [('NAG NAG', 'H', '1'), ('NAG NAG', 'E', '1'), ('NAG NAG', 'G', '1'), ('NAG NAG', 'F', '1')]
# 1jpc [('MAN MAN MAN', 'B', '1'), ('MAN MAN MAN', 'D', '1'), ('MAN MAN', 'C', '1')]
# 5iuc [('A2G GAL SIA', 'C', '1'), ('A2G GAL SIA', 'D', '1')]
# 3o0w [('MAN MAN MAN GLC', 'B', '1')]
# 6gx6 [('A   C   A   C  ', 'B', '1')]
# 1ehh [('NAG NAG NAG', 'C', '1'), ('NAG NAG NAG', 'D', '1')]
# 2uvj [('ADA ADA ADA', 'B', '1')]
# 4wvw [('GLC GAL SIA', 'B', '1')]
# 4uso [('NAG FUC GAL SIA', 'E', '1')]
# 4ylz [('BGC GAL NAG GAL', 'G', '1'), ('BGC GAL NAG GAL', 'F', '1'), ('BGC GAL NAG GAL', 'H', '1'), ('BGC GAL NAG GAL', 'E', '1')]
# 1npl [('MAN', 'E', '2'), ('MAN', 'E', '1'), ('MAN MAN', 'B', '1'), ('MAN MAN', 'D', '1'), ('MAN MAN', 'C', '1')]
# 3k00 [('GLC GLC GLC GLC', 'B', '1')]
# 1k7v [('BGC GAL NAG', 'C', '1'), ('BGC GAL NAG', 'D', '1')]
# 6xlp [('VJ4 KDO VJ1', 'B', '1')]
# 2j44 [('GLC GLC GLC', 'B', '1'), ('GLC GLC GLC GLC', 'C', '1')]
# 1sl6 [('NDG FUC GAL', 'L', '1'), ('NDG FUC GAL', 'J', '1'), ('NDG FUC GAL', 'I', '1'), ('NDG FUC GAL', 'K', '1'), ('NDG FUC GAL', 'G', '1'), ('NDG FUC GAL', 'H', '1')]
# 3s5x [('BMA MAN MAN MAN MAN', 'C', '1'), ('BMA MAN MAN MAN MAN', 'B', '1')]
# 2yfz [('BGC BGC BGC XYS GAL', 'B', '1')]
# 3qdx [('A2G GAL', 'D', '1'), ('A2G GAL', 'C', '1'), ('NAG NAG', 'F', '1'), ('NAG NAG', 'E', '1')]
# 3aqx [('BGC BGC BGC BGC BGC BGC', 'C', '1'), ('BGC BGC BGC BGC BGC BGC', 'D', '1')]
# 5f7u [('GLC GLC', 'E', '1'), ('GLC GLC', 'C', '1'), ('GLC GLC', 'D', '1'), ('GLC GLC GLC', 'F', '1'), ('GLC GLC GLC GLC', 'B', '1')]
# 2dcf [('ACA ACA', 'A', '501')]
# 5h40 [('BGC BGC', 'D', '1'), ('BGC BGC', 'C', '1')]
# 1m07 [('DA  DC  DG  DA', 'C', '1'), ('DA  DC  DG  DA', 'D', '1')]
# 2w39 [('BGC BGC', 'B', '1'), ('BGC LGC', 'B', '1')]
# 4g0a [('G   G   U', 'E', '1'), ('G   G   U', 'F', '1'), ('G   G   U', 'G', '1'), ('G   G   U', 'H', '1')]
# 1k1y [('GLC GLC', 'D', '1'), ('GLC GLC AC1', 'C', '1')]
# 4xvx [('P6G FDA', 'B', '401'), ('P33 FDA', 'A', '401')]
# 4ax7 [('BGC 4MU BGC', 'F', '1'), ('BGC 4MU BGC', 'H', '1'), ('BGC 4MU BGC BGC BGC', 'G', '1'), ('BGC 4MU BGC BGC BGC', 'E', '1')]
# 4xwm [('BGC BGC', 'C', '1'), ('BGC BGC', 'D', '1'), ('GLC BGC', 'B', '1')]
# 1rq5 [('BGC BGC BGC BGC', 'B', '1')]
# 4avo [('BGC BGC BGC BGC BGC BGC', 'B', '1')]
# 1fh8 [('XYP XIF', 'A', '601')]
# 4jjj [('BGC BGC BGC BGC BGC BGC', 'D', '1'), ('BGC BGC', 'B', '1'), ('GLC BGC', 'C', '1')]
# 4a05 [('BGC BGC', 'C', '1'), ('BGC BGC BGC BGC', 'D', '1')]
# 3u3y [('DG  DA  DC  DG', 'C', '1'), ('DG  DA  DC  DG', 'D', '1')]
# 6lcf [('FUB FUB', 'C', '1'), ('FUB FUB', 'D', '1')]
# 5g61 [('ZEE UEA FRU FRU FRU', 'E', '1'), ('ZEE UEA FRU FRU FRU', 'G', '1'), ('ZEE UEA FRU FRU FRU', 'F', '1'), ('ZEE UEA FRU FRU FRU', 'H', '1')]
# 3zkk [('XYP XYP XYP XYP', 'B', '1')]
# 2evl [('GAL SPH EIC', 'A', '300')]
# 4pft [('BMA BMA', 'D', '1'), ('BMA BMA', 'C', '1')]
# 2w7y [('GAL FUC A2G', 'C', '1'), ('GAL FUC A2G', 'D', '1')]
# 1dot [('NAG FUC', 'A', '692')]
# 3i5o [('BGC BGC BGC BGC BGC', 'C', '1'), ('BGC BGC BGC BGC BGC', 'D', '1')]
# 1js8 [('MAN MAN BMA', 'E', '1')]
# 6i5v [('BMA BMA BMA', 'B', '1')]
# 7bvt [('GLC GLC GLC', 'B', '1')]
# 4pfw [('MAN MAN BMA BMA BMA BMA', 'C', '1'), ('MAN MAN BMA BMA BMA BMA', 'D', '1')]
# 5yqw [('NAG NAG', 'B', '1')]
# 7c68 [('BGC BGC BGC BGC', 'C', '1'), ('BGC BGC BGC BGC', 'D', '1')]
# 6jb0 [('GLC GLC', 'B', '1')]
# 4g68 [('XYS XYP XYP', 'D', '1'), ('XYS XYP XYP', 'E', '1')]
# 6h0h [('GAL GAL', 'C', '1'), ('GAL GAL', 'D', '1'), ('GLA GAL', 'A', '903'), ('GLA GAL', 'B', '903')]
# 4zze [('GLC GLC GLC', 'D', '1'), ('GLC GLC GLC', 'C', '1')]
# 4uac [('GLC GLC AC1', 'B', '1')]
# 2z8e [('NGA GAL', 'C', '1'), ('NGA GAL', 'D', '1')]
# 1z0n [('GLC GLC GLC GLC GLC GLC GLC', 'F', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'E', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'D', '1')]
# 6e0o [('ATP A  ', 'B', '1'), ('ATP A  ', 'C', '1')]
# 5z8a [('PLP JIA', 'A', '501'), ('PLP JIA', 'B', '501')]
# 4yee [('GLC GLC GLC GLC GLC GLC GLC GLC', 'H', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'E', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'I', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'S', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'U', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'A', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'W', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'J', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'G', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'T', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'F', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'X', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'Z', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'C', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'V', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'B', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'D', '1'), ('GLC GLC GLC GLC GLC GLC GLC GLC', 'Y', '1')]
# 4ebz [('NAG NAG NAG NAG', 'F', '1')]
# 4yef [('GLC GLC GLC GLC GLC GLC GLC', 'K', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'N', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'L', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'J', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'I', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'M', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'H', '1')]
# 3lih [('FRU GLC GLA', 'B', '1')]
# 5gza [('MAN NAG NGA', 'A', '405')]
# 1dll [('BGC GAL', 'B', '1')]
# 6hwr [('H1Q', 'A', '527')]
# 5fmd [('GLC FRU FRU FRU', 'I', '1'), ('GLC FRU FRU FRU', 'J', '1')]
# 1w2t [('GLC FRU GLA', 'J', '1'), ('GLC FRU GLA', 'L', '1'), ('GLC FRU GLA', 'I', '1'), ('GLC FRU GLA', 'K', '1'), ('GLC FRU GLA', 'G', '1'), ('GLC FRU GLA', 'H', '1')]
# 7bwc [('GLC FRU', 'B', '1')]
# 5z74 [('GLC FRU', 'D', '1'), ('GLC FRU', 'C', '1')]
# 3m3e [('A2G NPO GAL', 'H', '1'), ('A2G NPO GAL', 'E', '1'), ('A2G NPO GAL', 'G', '1'), ('A2G NPO GAL', 'F', '1')]
# 3weo [('GLC GLC GLC GLC GLC GLC AC1', 'D', '1')]
# 6jr7 [('GLC GLC', 'G', '1'), ('GLC GLC', 'H', '1'), ('GLC GLC', 'E', '1'), ('GLC GLC', 'F', '1')]
# 2zq0 [('GLC GLC AC1', 'C', '1'), ('GLC GLC AC1', 'D', '1')]
# 4l2h [('AR6 AR6', 'A', '700')]
# 5cpz [('GAL NGA GAL SIA SIA', 'F', '1'), ('GAL NGA GAL SIA SIA', 'J', '1'), ('GAL NGA GAL SIA SIA', 'I', '1'), ('GAL NGA GAL SIA SIA', 'H', '1'), ('GAL NGA GAL SIA SIA', 'G', '1')]
# 1tyu [('RAM MAN GLA TYV RAM MAN GLA TYV', 'B', '1')]
# 4bh1 [('NAG GAL SIA', 'G', '1'), ('NAG GAL SIA', 'H', '1'), ('NAG GAL SIA', 'I', '1')]
# 2z8l [('NAG FUC GAL SIA', 'B', '1')]
# 4lsy [('FLC', 'B', '100')]
# 3dwq [('NGA POL GAL NGC AZI', 'H', '1'), ('NGA POL GAL NGC AZI', 'I', '1'), ('NGA POL GAL NGC AZI', 'F', '1'), ('NGA POL GAL NGC AZI', 'G', '1')]
# 4dxg [('NDG FUC GAL SIA', 'B', '1')]
# 1h2c [('U   G   A', 'R', '1')]
# 5u75 [('NDG FUC GAL SIA', 'B', '1')]
# 6jyn [('NAG GAL', 'E', '1'), ('NAG GAL', 'G', '1'), ('NAG GAL', 'F', '1'), ('NAG GAL', 'H', '1')]
# 1jsh [('GAL SIA', 'F', '1')]
# 1c4q [('BGC GAL GLA', 'F', '1'), ('BGC GAL GLA', 'G', '1'), ('BGC GAL GLA', 'J', '1'), ('BGC GAL GLA', 'H', '1'), ('BGC GAL GLA', 'I', '1')]
# 2g7c [('NAG GAL GLA', 'F', '1'), ('NAG GAL GLA', 'C', '1'), ('NAG GAL GLA', 'D', '1'), ('NAG GAL GLA', 'E', '1')]
# 2yft [('GLC FRU FRU', 'B', '1')]
# 4b1m [('FRU FRU', 'F', '1'), ('FRU FRU', 'E', '1'), ('FRU FRU', 'D', '1')]
# 5amc [('GLY NIY', 'A', '906'), ('GLY NIY', 'B', '906')]
# 3kll [('GLC GLC', 'E', '1'), ('GLC GLC', 'B', '1'), ('GLC GLC', 'C', '1'), ('GLC GLC', 'D', '1')]
# 4pxq [('SGN IDS SGN IDS SGN UAP', 'D', '1'), ('SGN IDS SGN IDS SGN UAP', 'C', '1')]
# 6i01 [('BDP GNS BDP GNS BDP GNS BDP', 'F', '1'), ('BDP GNS BDP GNS BDP GNS BDP', 'C', '1')]
# 5w7c [('DAO FTT', 'D', '609'), ('DAO FTT', 'C', '609')]
# 5aye [('BMA BMA', 'J', '1'), ('BMA BMA', 'H', '1'), ('BMA BMA', 'K', '1'), ('BMA BMA', 'I', '1'), ('BMA BMA', 'L', '1'), ('BMA BMA', 'G', '1')]
# 5uas [('83Y BDP 83Y GCD', 'D', '1'), ('83Y BDP 83Y GCD', 'C', '1')]
# 4ojz [('LGU MAV BEM', 'D', '1'), ('LGU MAV BEM', 'C', '1')]
# 7c8f [('BEM BEM', 'D', '1'), ('BEM BEM', 'C', '1')]
# 6a40 [('LGU LGU LGU LGU', 'B', '1')]
# 5olr [('RAM ADA RAM', 'D', '1'), ('RAM ADA RAM', 'E', '1'), ('RAM ADA RAM', 'F', '1')]
# 6d3u [('83Y BDP 83Y GCD', 'D', '1'), ('83Y BDP 83Y GCD', 'C', '1')]
# 6byt [('83Y BDP 83Y GCD', 'C', '1'), ('83Y BDP 83Y GCD', 'D', '1')]
# 5xgx [('DAS DLY', 'A', '403'), ('DAS DLY', 'B', '403')]
# 4d71 [('NAG GAL FUC A2G', 'B', '1')]
# 4btb [('PRO PRO PRO PRO PRO PRO PRO PRO PRO', 'C', '0')]
# 1mdb [('AMP DBH', 'A', '600')]
# 2art [('LPA AMP', 'A', '301')]
# 6iht [('GLY GLY SEP', 'X', '1')]
# 1uc2 [('GLC FRU', 'C', '1'), ('GLC FRU', 'D', '1')]
# 2a8t [('MGT ADN', 'A', '251'), ('MGT ADN', 'B', '251')]
# 2v1x [('ADP MG', 'A', '1593'), ('ADP MG', 'B', '1593')]
# 5dx9 [('GLC G6P', 'B', '1')]
# 5dxi [('GLC GLC', 'C', '1'), ('GLC GLC', 'D', '1')]
# 6vm6 [('A   A   A  ', 'J', '1'), ('A   A   A  ', 'G', '1'), ('A   A   A  ', 'H', '1'), ('A   A   A  ', 'I', '1'), ('A   A   A  ', 'K', '1')]
# 2ygm [('NAG GAL FUC GLA', 'C', '1'), ('NAG GAL FUC GLA', 'D', '1')]
# 5lfv [('NAG GAL SIA', 'E', '1')]
# 3r9v [('DXC', 'B', '1'), ('DXC', 'B', '323')]
# 6ub0 [('GLC BGC', 'B', '1')]
# 4x06 [('GLA FUC GLA', 'D', '1'), ('GLA FUC GLA', 'C', '1')]
# 6rt7 [('G   6MZ C   U  ', 'A', '1'), ('G   6MZ C   U  ', 'E', '1')]
# 3kyg [('5GP 5GP', 'A', '501'), ('5GP 5GP', 'A', '503'), ('5GP 5GP', 'B', '501'), ('5GP 5GP', 'B', '503')]
# 5mtt [('GLC GLC GLC GLC', 'B', '1'), ('GLC GLC GLC GLC', 'A', '405')]
# 5fhd [('ADP ALF', 'B', '501'), ('ADP ALF', 'A', '501')]
# 5zho [('GLA FUC A2G', 'B', '1')]
# 6aov [('NAG GAL NAG GAL SIA', 'F', '1')]
# 3aih [('BMA MAN MAN', 'C', '1'), ('BMA MAN MAN', 'D', '1')]
# 3s6x [('BGC GAL SIA', 'F', '1'), ('BGC GAL SIA', 'E', '1'), ('BGC GAL SIA', 'D', '1')]
# 4fch [('GLC GLC GLC GLC GLC GLC GLC', 'C', '1')]
# 5yrg [('BGC GLC', 'D', '1'), ('BGC GLC', 'C', '1')]
# 2xqo [('GLC BGC BGC', 'C', '1'), ('GLC BGC BGC', 'B', '1')]
# 4ds0 [('NAG GAL FUC A2G', 'B', '1')]
# 5lkc [('GLA FUC A2G', 'C', '1'), ('GLA FUC A2G', 'D', '1')]
# 3ubq [('NAG GAL SIA', 'N', '1'), ('GAL SIA', 'P', '1'), ('GAL SIA', 'Q', '1')]
# 6a56 [('BGC GAL', 'D', '1'), ('BGC GAL', 'C', '1')]
# 5c8p [('NAG NAG NAG', 'B', '1')]
# 2vuz [('NAG NAG BMA MAN MAN NAG NAG', 'B', '1')]
# 5jsd [('GAL 1GN BGC ACY GAL 1GN BGC ACY GAL 6PZ', 'G', '1'), ('GAL 1GN BGC ACY GAL 1GN BGC ACY GAL 6PZ', 'D', '1'), ('GAL 1GN BGC ACY GAL 1GN BGC ACY GAL 6PZ', 'H', '1'), ('1GN ACY GAL 1GN BGC ACY GAL BGC', 'E', '1')]
# 4wa2 [('NAG GAL SIA', 'P', '1'), ('NAG GAL SIA', 'G', '1'), ('NAG GAL SIA', 'I', '1'), ('NAG GAL SIA', 'K', '1')]
# 6er4 [('BGC GAL SIA', 'C', '1'), ('BGC GAL SIA', 'D', '1')]
# 4yg0 [('BGC GAL NAG GAL', 'B', '1')]
# 6lf2 [('BGC GAL NGA GAL', 'D', '1'), ('BGC GAL NGA GAL', 'C', '1')]
# 6tvb [('NAG GAL SIA', 'G', '1'), ('NAG GAL SIA', 'H', '1'), ('NAG GAL SIA', 'I', '1')]
# 4gk9 [('BMA MAN MAN MAN MAN', 'B', '1'), ('BMA MAN MAN MAN MAN', 'D', '1'), ('BMA MAN MAN MAN MAN', 'E', '1'), ('BMA MAN MAN MAN MAN', 'C', '1')]
# 4fer [('BGC BGC BGC BGC BGC BGC', 'C', '1')]
# 1a0t [('GLC FRU', 'E', '1'), ('GLC FRU', 'F', '1'), ('GLC FRU', 'A', '1'), ('GLC FRU', 'B', '1'), ('GLC FRU', 'C', '1'), ('GLC FRU', 'D', '1')]
# 4d5b [('GLC GLC GLC GLC GLC GLC', 'F', '1'), ('GLC GLC GLC GLC GLC GLC', 'C', '1'), ('GLC GLC GLC GLC GLC GLC', 'D', '1'), ('GLC GLC GLC GLC GLC GLC', 'E', '1')]
# 2hyv [('IDS SGN IDS SGN UAP', 'B', '1')]
# 5uf1 [('NAG GAL FUC', 'D', '1'), ('NAG GAL FUC', 'C', '1')]
# 6tj0 [('C2E', 'B', '601')]
# 6sce [('A   A   A   A  ', 'B', '1')]
# 3bwr [('BGC GAL SIA NGA GAL', 'H', '1'), ('BGC GAL SIA NGA GAL', 'F', '1'), ('BGC GAL SIA NGA GAL', 'G', '1')]
# 5fu3 [('BGC BGC BGC', 'D', '1'), ('BGC BGC BGC', 'C', '1')]
# 5ik5 [('4MU BDP XYS BDP XYS', 'A', '4013')]
# 5yrl [('GLC GLC', 'C', '1'), ('GLC GLC', 'D', '1')]
# 6b5q [('PPI CZS 2KY MLY 1XY', 'E', '1'), ('PPI CZS 2KY MLY 1XY', 'D', '1')]
# 5e76 [('BGC BGC BGC BGC XYS BGC XYS BGC BGC', 'B', '1')]
# 3vy6 [('BGC BGC', 'B', '1')]
# 3m3r [('GLC GLC GLC GLC GLC GLC GLC', 'H', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'I', '1')]
# 4wei [('GLC GAL', 'B', '1')]
# 4pos [('NAG GAL SIA', 'O', '1'), ('NAG GAL SIA', 'M', '1'), ('NAG GAL SIA', 'P', '1'), ('NAG GAL SIA', 'K', '1'), ('NAG GAL SIA', 'N', '1'), ('NAG GAL SIA', 'L', '1'), ('NAG GAL SIA', 'Q', '1'), ('NAG GAL SIA', 'S', '1'), ('NAG GAL SIA', 'R', '1')]
# 3gxa [('MET', 'D', '400'), ('MET', 'E', '500'), ('MET', 'F', '600')]
# 6c5k [('GP1 Z9M KDO KDO KDO', 'D', '1'), ('GP1 Z9M KDO KDO KDO', 'F', '1')]
# 5e7g [('BGC BGC BGC XYS BGC XYS BGC XYS BGC', 'B', '1')]
# 5lne [('A2G GAL', 'D', '1'), ('A2G GAL', 'C', '1')]
# 4i4s [('BGC GAL', 'E', '1'), ('BGC GAL', 'H', '1'), ('BGC GAL', 'F', '1'), ('BGC GAL', 'G', '1'), ('BGC GAL', 'I', '1')]
# 6ug7 [('BGC GAL GLA NGA GAL SIA', 'A', '1')]
# 4pi8 [('AMU NAG', 'B', '1')]
# 4lkk [('GAL SIA', 'C', '1')]
# 6sa8 [('LYS ARG LYS ARG LYS ARG LYS ARG LYS ARG', 'B', '1')]
# 3gxz [('BMA MAN MAN MAN', 'D', '1'), ('NAG NAG BMA MAN MAN MAN MAN MAN MAN MAN', 'C', '1')]
# 4yg6 [('BGC GAL NAG GAL', 'E', '1'), ('BGC GAL NAG GAL', 'G', '1'), ('BGC GAL NAG GAL', 'F', '1'), ('NAG GAL', 'H', '1')]
# 5vhc [('BEF ADP', 'D', '1102')]
# 4x1z [('NDG GAL FUC', 'C', '1'), ('NDG GAL FUC', 'D', '1')]
# 5cb7 [('A2G GAL FUC', 'B', '304'), ('GLA FUC A2G', 'D', '1'), ('GLA FUC A2G', 'C', '1')]
# 5t7n [('GLC GLC GLC GLC', 'B', '1')]
# 4ryl [('3ZG', 'A', '601')]
# 5b2d [('GLC GAL SIA', 'C', '1'), ('GLC GAL SIA', 'D', '1')]
# 6y5y [('BGC GAL SIA', 'R', '1'), ('BGC GAL SIA', 'L', '1'), ('BGC GAL SIA', 'N', '1'), ('BGC GAL SIA', 'T', '1'), ('BGC GAL SIA', 'S', '1'), ('BGC GAL SIA', 'Q', '1'), ('GLC GAL SIA', 'O', '1'), ('GLC GAL SIA', 'M', '1'), ('GLC GAL SIA', 'P', '1'), ('GLC GAL SIA', 'K', '1')]
# 6r41 [('GAL BGC SIA', 'B', '1')]
# 4mj0 [('SIA SIA', 'I', '1'), ('SIA SIA', 'G', '1'), ('BGC GAL SIA SIA', 'F', '1'), ('GAL SIA SIA', 'H', '1')]
# 5yrj [('BGC GLC', 'D', '1'), ('BGC GLC', 'C', '1')]
# 4rm0 [('NDG GAL FUC', 'D', '1'), ('NAG GAL FUC', 'C', '1')]
# 4fe9 [('GLC GLC GLC GLC', 'C', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'B', '1')]
# 4tz5 [('BGC BGC BGC BGC BGC', 'D', '1'), ('BGC BGC BGC BGC BGC', 'F', '1'), ('BGC BGC BGC BGC BGC BGC', 'E', '1'), ('BGC BGC BGC BGC BGC BGC', 'C', '1')]
# 3pun [('NDG FUC GAL FUC', 'D', '1'), ('NDG FUC GAL FUC', 'C', '1')]
# 1u4l [('SGN UAP', 'C', '1')]
# 4zno [('GLC FRU', 'C', '1'), ('GLC FRU', 'D', '1')]
# 3tii [('ANP', 'B', '710'), ('ANP MG', 'A', '700')]
# 4ouj [('GLC GAL', 'C', '1'), ('GLC GAL', 'D', '1')]
# 4tu8 [('DU  DU  DU  DU  BRU DA  DU ', 'E', '1'), ('DU  DU  DU  DU  BRU DA  DU ', 'P', '1')]
# 6wma [('DC  DC ', 'B', '1')]
# 6dmf [('BGC BGC BGC BGC BGC BGC', 'L', '1'), ('BGC BGC BGC BGC BGC BGC', 'Q', '1'), ('BGC BGC BGC BGC BGC BGC', 'M', '1'), ('BGC BGC BGC BGC BGC BGC', 'R', '1'), ('BGC BGC BGC BGC BGC BGC', 'N', '1'), ('BGC BGC BGC BGC BGC BGC', 'T', '1'), ('BGC BGC BGC BGC BGC BGC', 'S', '1'), ('BGC BGC BGC BGC BGC BGC', 'P', '1'), ('BGC BGC BGC BGC BGC BGC', 'O', '1'), ('BGC BGC BGC BGC BGC', 'K', '1')]
# 5jop [('NAG GAL BGC GAL', 'B', '1'), ('NAG GAL BGC GAL', 'A', '1')]
# 5aei [('LYS ARG LYS ARG LYS ARG LYS ARG LYS ARG', 'F', '1'), ('LYS ARG LYS ARG LYS ARG LYS ARG LYS ARG', 'E', '1'), ('LYS ARG LYS ARG LYS ARG LYS ARG LYS ARG', 'D', '1')]
# 4fbv [('BMA MAN MAN MAN MAN', 'B', '1'), ('BMA MAN MAN MAN MAN', 'C', '1')]
# 2yp9 [('SIA CMO', 'A', '1508')]
# 2jkg [('PRO PRO PRO PRO PRO PRO PRO PRO', 'P', '0')]
# 4rdl [('NDG FUC GAL FUC', 'C', '1'), ('NDG FUC GAL FUC', 'D', '1')]
# 3vv1 [('FUC GAL', 'D', '1'), ('FUC GAL', 'C', '1')]
# 5vx9 [('BGC GAL NAG GAL FUC', 'B', '1')]
# 3m7s [('BGC BGC', 'B', '1')]
# 3ll2 [('MAN MAN MAN MAN MAN MAN MAN MAN', 'B', '1')]
# 5xfh [('BMA MAN MAN NAG GAL NAG', 'C', '1')]
# 4b8v [('NDG NAG NAG NAG', 'C', '1')]
# 6bn0 [('NAG NAG NAG NAG NAG NAG', 'E', '1'), ('NAG NAG NAG NAG NAG NAG', 'G', '1'), ('NAG NAG NAG NAG NAG NAG', 'F', '1'), ('NAG NAG NAG NAG NAG NAG', 'H', '1')]
# 6q4z [('MAN BMA', 'D', '1'), ('MAN BMA', 'C', '1')]
# 5kti [('GLC GLC 6X6', 'B', '1')]
# 6ubb [('BGC BGC', 'M', '1'), ('BGC BGC', 'R', '1'), ('BGC BGC', 'L', '1'), ('BGC BGC', 'S', '1'), ('BGC BGC', 'P', '1'), ('BGC BGC', 'Q', '1'), ('BGC BGC', 'T', '1'), ('BGC BGC', 'K', '1'), ('BGC BGC', 'N', '1'), ('BGC BGC', 'O', '1')]
# 2p39 [('GU4 YYJ', 'B', '1')]
# 3o01 [('DXC', 'B', '1')]
# 4lo2 [('BGC GAL', 'D', '1'), ('BGC GAL', 'E', '1')]
# 3r6k [('GAL FUC GLA', 'B', '1')]
# 5n1x [('8HH', 'B', '201'), ('8HH', 'B', '202'), ('8HH', 'D', '201'), ('8HH', 'C', '201')]
# 2dur [('MAN MAN', 'C', '1'), ('MAN MAN', 'D', '1')]
# 1g5n [('SGN IDS SGN UAP', 'C', '1'), ('SGN IDS SGN UAP', 'B', '1')]
# 6k2z [('GLC GAL', 'D', '1'), ('BGC GAL', 'C', '1')]
# 4g9z [('G   C   C   C  ', 'E', '4'), ('G   G   G   C  ', 'F', '4')]
# 6yuq [('BMX BMX BMX BM3', 'A', '404')]
# 3tv3 [('MAN AML MAN MAN MAN MAN MAN MAN MAN', 'A', '1')]
# 5vx5 [('BGC GAL NAG GAL FUC', 'B', '1')]
# 6c5j [('GP1 Z9M KDO KDO KDO', 'A', '1')]
# 4g8r [('96P', 'B', '403'), ('96P', 'B', '402')]
# 7d2a [('LGU MAW', 'C', '1')]
# 6bhq [('NAG NAG FUL BMA MAN MAN NAG GAL', 'D', '1')]
# 5yrf [('GLC GLC', 'A', '201'), ('GLC GLC', 'C', '1')]
# 4fem [('GLC GLC GLC GLC GLC GLC', 'B', '1')]
# 4r9w [('ZDO IDS SUS BDP SGN', 'C', '1')]
# 6fi2 [('DJB DJB DJE', 'B', '1')]
# 6b3p [('GLC GLC GLC GLC', 'F', '1'), ('GLC GLC GLC GLC', 'C', '1'), ('GLC GLC GLC', 'D', '1'), ('GLC GLC GLC', 'E', '1')]
# 2uwn [('GU4 YYJ', 'B', '1')]
# 3kyf [('5GP 5GP', 'A', '501'), ('5GP 5GP', 'A', '503')]
# 2hyr [('BGC GLC', 'H', '1'), ('BGC GLC', 'F', '1'), ('BGC GLC', 'D', '1'), ('BGC GLC', 'G', '1'), ('BGC GLC', 'C', '1'), ('BGC GLC', 'E', '1')]
# 3f5a [('NAG GAL SIA', 'B', '1')]
# 1af6 [('GLC FRU', 'F', '1'), ('GLC FRU', 'E', '1'), ('GLC FRU', 'D', '1')]
# 3ck8 [('GLC GLC GLC GLC GLC GLC GLC', 'D', '1'), ('GLC GLC GLC GLC GLC GLC GLC', 'C', '1')]
# 5yse [('GLC BGC BGC BGC', 'C', '1'), ('GLC BGC BGC BGC', 'D', '1')]
# 1p99 [('GLY MET', 'A', '300')]
# 4we5 [('NAG NAG BMA', 'D', '1')]
# 3qrc [('GU4 YYJ', 'C', '1'), ('GU4 YYJ', 'D', '1')]
# 2x2t [('NGA GAL', 'B', '1')]
# 5udk [('ATP A   A   A  ', 'B', '1')]
# 2r85 [('AMP', 'A', '400'), ('AMP', 'A', '401'), ('AMP', 'B', '400'), ('AMP', 'B', '401')]
# 3wbd [('SIA SIA SIA SIA SIA SIA SIA', 'C', '1')]
# 5b0r [('BMA BMA', 'C', '1'), ('BMA BMA', 'D', '1'), ('MAN BMA', 'D', '1'), ('MAN BMA', 'C', '1')]
# 4mby [('GAL SIA', 'N', '1'), ('GAL SIA', 'O', '1'), ('GAL SIA', 'P', '1'), ('GAL SIA', 'M', '1'), ('GAL SIA', 'L', '1'), ('GAL SIA', 'K', '1'), ('GAL SIA', 'Q', '1'), ('BGC GAL SIA', 'R', '1'), ('BGC GAL SIA', 'S', '1')]
# 4r9f [('BMA BMA', 'B', '1')]
# 3dy0 [('IDS SGN IDS SGN IDS', 'C', '1')]
# 4odv [('GP1 Z9M', 'A', '1')]
# 2zhp [('BY6 CU', 'A', '301'), ('BY6 CU', 'B', '401')]
# 6h9y [('NAG GAL', 'C', '1')]
# 5vmc [('NAG GAL SIA', 'J', '1'), ('NAG GAL SIA', 'H', '1'), ('NAG GAL SIA', 'L', '1')]
# 5f7r [('GLC GLC', 'C', '1'), ('GLC GLC', 'B', '1')]
# 5yri [('GLC GLC', 'A', '201'), ('GLC GLC', 'C', '1')]
# 6is5 [('GLC GAL FUC A2G', 'H', '1'), ('GLC GAL FUC A2G', 'E', '1'), ('GLC GAL FUC A2G', 'G', '1'), ('GLC GAL FUC A2G', 'F', '1')]
# 4p25 [('NAG FUC GAL FUC', 'F', '1'), ('NAG FUC GAL FUC', 'E', '1'), ('NAG FUC GAL FUC', 'G', '1'), ('NAG FUC GAL FUC', 'H', '1')]
# 4gc1 [('MAN MAN', 'D', '1'), ('MAN MAN', 'C', '1')]
# 6rs9 [('XYP XYP XYP XYP', 'C', '1')]
# 3v0w [('KDO KDO GM0 GM0 GLC GMH GLC GLA GLC PA1', 'A', '1')]
# 5mdr [('NAG NAG NAG NAG NAG NAG', 'L', '1'), ('NAG NAG NAG NAG NAG NAG', 'I', '1'), ('NAG NAG NAG NAG NAG NAG', 'G', '1'), ('NAG NAG NAG NAG NAG NAG', 'K', '1'), ('NAG NAG NAG NAG NAG NAG', 'J', '1'), ('NAG NAG NAG NAG NAG NAG', 'H', '1')]
# 3qmk [('SGN IDS SGN IDS', 'C', '1')]
# 5t0b [('NAG GAL SIA', 'G', '1')]
# 5f7v [('GLC GLC GLC GLC', 'B', '1')]
# 4zh7 [('GAL NAG GAL FUC FUC', 'B', '1')]
# 4ojp [('GLC GLC', 'F', '1'), ('GLC GLC', 'D', '1'), ('GLC GLC', 'E', '1')]
# 4p6a [('MAN MAN MAN', 'C', '1'), ('MAN MAN MAN', 'B', '1'), ('MAN MAN MAN', 'D', '1')]
# 5ufc [('NAG GAL FUC', 'E', '1'), ('NAG GAL FUC', 'D', '1'), ('NAG GAL FUC', 'F', '1')]
# 6yud [('A   A   A   A  ', 'M', '1'), ('A   A   A   A  ', 'P', '1'), ('A   A   A   A  ', 'O', '1'), ('A   A   A   A  ', 'Q', '1'), ('A   A   A   A  ', 'K', '1')]
# 6uaw [('BGC BGC BGC', 'B', '1')]
# 2wr9 [('MAN MAN', 'F', '1'), ('MAN MAN', 'E', '1')]
# 3zqe [('DXC', 'B', '1079')]
# 3hp8 [('GLC FRU', 'C', '1'), ('GLC FRU', 'F', '1'), ('GLC FRU', 'E', '1'), ('GLC FRU', 'D', '1')]
# 2rdk [('MAN MAN', 'D', '1'), ('MAN MAN', 'C', '1')]
# 2mpr [('BGC GLC GLC', 'F', '1'), ('BGC GLC GLC', 'E', '1'), ('BGC GLC GLC', 'D', '1')]
# 5cs2 [('54C WLU ALA WPA VAL MLE WVL', 'B', '1')]
# 4a3x [('BGC GAL', 'B', '1')]
# 4m44 [('GAL NAG GAL SIA', 'R', '1'), ('GAL NAG GAL SIA', 'N', '1'), ('GAL NAG GAL SIA', 'J', '1')]
# 5hca [('BGC', 'A', '407')]
# 3lsj [('COA PLM', 'B', '222'), ('PLM COA', 'A', '221')]
# 2hyq [('MAN MAN', 'F', '1'), ('MAN MAN', 'H', '1'), ('MAN MAN', 'C', '1'), ('MAN MAN', 'G', '1'), ('MAN MAN', 'D', '1'), ('MAN MAN', 'E', '1')]
# 1oh2 [('GLC FRU', 'B', '1'), ('GLC FRU', 'E', '1'), ('GLC FRU', 'F', '1'), ('GLC FRU', 'D', '1'), ('GLC FRU', 'C', '1'), ('GLC FRU', 'A', '1')]
# 4odt [('GP1 Z9M', 'A', '1')]
# 2wn2 [('A2G GAL', 'A', '301'), ('A2G GAL', 'B', '301'), ('A2G GAL', 'C', '301'), ('NGA GAL', 'F', '1'), ('NGA GAL', 'E', '1'), ('NGA GAL', 'D', '1')]
# 6haj [('EVB', 'B', '101')]
# 2obt [('GAL FUC GLA', 'B', '1')]
# 5oca [('TWD TWA', 'C', '1')]

# %%
MOAD_subset_data_df.query('ID in @missing_lig_pdbs') # weird sugars or peptide ligands
# Out:
#          dataset    ID chains n_chains n_ress ligs  n_ligs chain_lens
# 6     bMOAD_filt  3njv     []       []     []   []       0         {}
# 54    bMOAD_filt  5yjw     []       []     []   []       0         {}
# 84    bMOAD_filt  6o7b     []       []     []   []       0         {}
# 87    bMOAD_filt  6tug     []       []     []   []       0         {}
# 89    bMOAD_filt  6n6a     []       []     []   []       0         {}
# ...          ...   ...    ...      ...    ...  ...     ...        ...
# 6596  bMOAD_filt  4odt     []       []     []   []       0         {}
# 6605  bMOAD_filt  2wn2     []       []     []   []       0         {}
# 6606  bMOAD_filt  6haj     []       []     []   []       0         {}
# 6608  bMOAD_filt  2obt     []       []     []   []       0         {}
# 6615  bMOAD_filt  5oca     []       []     []   []       0         {}
#
# [736 rows x 8 columns]

# %%
MOAD_subset_data_df_filt = MOAD_subset_data_df.query('n_ligs > 0').copy().reset_index(drop = True)

# %%
MOAD_subset_data_df_filt.head(5)
# Out:
#       dataset    ID                chains      n_chains            n_ress  \
# 0  bMOAD_filt  2pa7      [{B, A}, {B, A}]        [2, 2]          [15, 14]
# 1  bMOAD_filt  2hk1  [{A}, {B}, {C}, {D}]  [1, 1, 1, 1]  [17, 17, 16, 18]
# 2  bMOAD_filt  4q0p                 [{A}]           [1]              [18]
# 3  bMOAD_filt  2qun            [{A}, {B}]        [1, 1]          [20, 20]
# 4  bMOAD_filt  2nxw      [{B, A}, {B, A}]        [2, 2]          [29, 29]
#
#                    ligs  n_ligs                                chain_lens
# 0            [TYD, TYD]       2                      {'A': 135, 'B': 134}
# 1  [FUD, FUD, FUD, FUD]       4  {'A': 283, 'B': 283, 'C': 283, 'D': 283}
# 2                 [0MK]       1                                {'A': 249}
# 3            [FUD, FUD]       2                      {'A': 290, 'B': 290}
# 4            [TPP, TPP]       2                      {'A': 537, 'B': 529}

# %%
MOAD_subset_data_df_filt.shape
# Out:
# (5899, 8)

# %%
MOAD_subset_data_df_filt.to_pickle("./results/DATASETS/bMOAD_filt_df.pkl")
